# %%
import http.client

conn = http.client.HTTPSConnection("tennis-live-data.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "57fcc65541msh4841dc21fef332dp1f0486jsn7e8c59408325",
    'X-RapidAPI-Host': "tennis-live-data.p.rapidapi.com"
    }

conn.request("GET", "/players/ATP", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"meta":{"title":"Live Tennis API - Players By Tour: ATP","description":"List of Players in Specified Tour","fields":{"id":"Integer - player_id","first_name":"String","last_name":"String","full_name":"String","country":"String"}},"results":{"players":[{"id":89304,"first_name":"Novak","last_name":"Djokovic","full_name":"Novak Djokovic","country":"Serbia"},{"id":86928,"first_name":"Rafael","last_name":"Nadal","full_name":"Rafael Nadal","country":"Spain"},{"id":342990,"first_name":"Alexander","last_name":"Zverev","full_name":"Alexander Zverev","country":"Germany"},{"id":91668,"first_name":"Potro","last_name":"Del","full_name":"Potro Del","country":"Argentina"},{"id":93378,"first_name":"Kevin","last_name":"Anderson","full_name":"Kevin Anderson","country":"South Africa"},{"id":86064,"first_name":"Roger","last_name":"Federer","full_name":"Roger Federer","country":"Switzerland"},{"id":94410,"first_name":"Kei","last_name":"Nishikori","full_name":"Kei Nishikori","country":"Japan"},{"id":262500,"first_name":"Dominic","last_name":"Thiem","full_name":"Dominic Thiem","country":"Austria"},{"id":96732,"first_name":"John","last_name":"Isner","full_name":"John Isner","country":"USA"},{"id":92334,"first_name":"Marin","last_name":"Cilic","full_name":"Marin Cilic","country":"Croatia"},{"id":540492,"first_name":"Karen","last_name":"Khachanov","full_name":"Karen Khachanov","country":"Russia"},{"id":734208,"first_name":"Stefanos","last_name":"Tsitsipas","full_name":"Stefanos Tsitsipas","country":"Greece"},{"id":387492,"first_name":"Borna","last_name":"Coric","full_name":"Borna Coric","country":"Croatia"},{"id":108678,"first_name":"Milos","last_name":"Raonic","full_name":"Milos Raonic","country":"Canada"},{"id":92616,"first_name":"Fabio","last_name":"Fognini","full_name":"Fabio Fognini","country":"Italy"},{"id":981036,"first_name":"Daniil","last_name":"Medvedev","full_name":"Daniil Medvedev","country":"Russia"},{"id":346230,"first_name":"Lucas","last_name":"Pouille","full_name":"Lucas Pouille","country":"France"},{"id":100332,"first_name":"Agut","last_name":"Bautista","full_name":"Agut Bautista","country":"Spain"},{"id":267306,"first_name":"Marco","last_name":"Cecchinato","full_name":"Marco Cecchinato","country":"Italy"},{"id":291606,"first_name":"Diego","last_name":"Schwartzman","full_name":"Diego Schwartzman","country":"Argentina"},{"id":155040,"first_name":"David","last_name":"Goffin","full_name":"David Goffin","country":"Belgium"},{"id":157236,"first_name":"Nikoloz","last_name":"Basilashvili","full_name":"Nikoloz Basilashvili","country":"Georgia"},{"id":244812,"first_name":"Busta","last_name":"Carreno","full_name":"Busta Carreno","country":"Spain"},{"id":141498,"first_name":"Grigor","last_name":"Dimitrov","full_name":"Grigor Dimitrov","country":"Bulgaria"},{"id":707508,"first_name":"Denis","last_name":"Shapovalov","full_name":"Denis Shapovalov","country":"Canada"},{"id":86940,"first_name":"Fernando","last_name":"Verdasco","full_name":"Fernando Verdasco","country":"Spain"},{"id":86496,"first_name":"Richard","last_name":"Gasquet","full_name":"Richard Gasquet","country":"France"},{"id":1207446,"first_name":"Minaur","last_name":"De","full_name":"Minaur De","country":"Australia"},{"id":392304,"first_name":"Kyle","last_name":"Edmund","full_name":"Kyle Edmund","country":"United Kingdom"},{"id":606618,"first_name":"Frances","last_name":"Tiafoe","full_name":"Frances Tiafoe","country":"USA"},{"id":88428,"first_name":"Gilles","last_name":"Simon","full_name":"Gilles Simon","country":"France"},{"id":87756,"first_name":"Philipp","last_name":"Kohlschreiber","full_name":"Philipp Kohlschreiber","country":"Germany"},{"id":89076,"first_name":"Gael","last_name":"Monfils","full_name":"Gael Monfils","country":"France"},{"id":230970,"first_name":"Steve","last_name":"Johnson","full_name":"Steve Johnson","country":"USA"},{"id":94986,"first_name":"Jeremy","last_name":"Chardy","full_name":"Jeremy Chardy","country":"France"},{"id":198702,"first_name":"John","last_name":"Mil ...

# %%
import json
dictData = json.loads(data.decode("utf-8"))

print(dictData)
# Out:
# {'meta': {'title': 'Live Tennis API - Players By Tour: ATP', 'description': 'List of Players in Specified Tour', 'fields': {'id': 'Integer - player_id', 'first_name': 'String', 'last_name': 'String', 'full_name': 'String', 'country': 'String'}}, 'results': {'players': [{'id': 89304, 'first_name': 'Novak', 'last_name': 'Djokovic', 'full_name': 'Novak Djokovic', 'country': 'Serbia'}, {'id': 86928, 'first_name': 'Rafael', 'last_name': 'Nadal', 'full_name': 'Rafael Nadal', 'country': 'Spain'}, {'id': 342990, 'first_name': 'Alexander', 'last_name': 'Zverev', 'full_name': 'Alexander Zverev', 'country': 'Germany'}, {'id': 91668, 'first_name': 'Potro', 'last_name': 'Del', 'full_name': 'Potro Del', 'country': 'Argentina'}, {'id': 93378, 'first_name': 'Kevin', 'last_name': 'Anderson', 'full_name': 'Kevin Anderson', 'country': 'South Africa'}, {'id': 86064, 'first_name': 'Roger', 'last_name': 'Federer', 'full_name': 'Roger Federer', 'country': 'Switzerland'}, {'id': 94410, 'first_name': 'Kei', 'last_name': 'Nishikori', 'full_name': 'Kei Nishikori', 'country': 'Japan'}, {'id': 262500, 'first_name': 'Dominic', 'last_name': 'Thiem', 'full_name': 'Dominic Thiem', 'country': 'Austria'}, {'id': 96732, 'first_name': 'John', 'last_name': 'Isner', 'full_name': 'John Isner', 'country': 'USA'}, {'id': 92334, 'first_name': 'Marin', 'last_name': 'Cilic', 'full_name': 'Marin Cilic', 'country': 'Croatia'}, {'id': 540492, 'first_name': 'Karen', 'last_name': 'Khachanov', 'full_name': 'Karen Khachanov', 'country': 'Russia'}, {'id': 734208, 'first_name': 'Stefanos', 'last_name': 'Tsitsipas', 'full_name': 'Stefanos Tsitsipas', 'country': 'Greece'}, {'id': 387492, 'first_name': 'Borna', 'last_name': 'Coric', 'full_name': 'Borna Coric', 'country': 'Croatia'}, {'id': 108678, 'first_name': 'Milos', 'last_name': 'Raonic', 'full_name': 'Milos Raonic', 'country': 'Canada'}, {'id': 92616, 'first_name': 'Fabio', 'last_name': 'Fognini', 'full_name': 'Fabio Fognini', 'country': 'Italy'}, {'id': 981036, 'first_name': 'Daniil', 'last_name': 'Medvedev', 'full_name': 'Daniil Medvedev', 'country': 'Russia'}, {'id': 346230, 'first_name': 'Lucas', 'last_name': 'Pouille', 'full_name': 'Lucas Pouille', 'country': 'France'}, {'id': 100332, 'first_name': 'Agut', 'last_name': 'Bautista', 'full_name': 'Agut Bautista', 'country': 'Spain'}, {'id': 267306, 'first_name': 'Marco', 'last_name': 'Cecchinato', 'full_name': 'Marco Cecchinato', 'country': 'Italy'}, {'id': 291606, 'first_name': 'Diego', 'last_name': 'Schwartzman', 'full_name': 'Diego Schwartzman', 'country': 'Argentina'}, {'id': 155040, 'first_name': 'David', 'last_name': 'Goffin', 'full_name': 'David Goffin', 'country': 'Belgium'}, {'id': 157236, 'first_name': 'Nikoloz', 'last_name': 'Basilashvili', 'full_name': 'Nikoloz Basilashvili', 'country': 'Georgia'}, {'id': 244812, 'first_name': 'Busta', 'last_name': 'Carreno', 'full_name': 'Busta Carreno', 'country': 'Spain'}, {'id': 141498, 'first_name': 'Grigor', 'last_name': 'Dimitrov', 'full_name': 'Grigor Dimitrov', 'country': 'Bulgaria'}, {'id': 707508, 'first_name': 'Denis', 'last_name': 'Shapovalov', 'full_name': 'Denis Shapovalov', 'country': 'Canada'}, {'id': 86940, 'first_name': 'Fernando', 'last_name': 'Verdasco', 'full_name': 'Fernando Verdasco', 'country': 'Spain'}, {'id': 86496, 'first_name': 'Richard', 'last_name': 'Gasquet', 'full_name': 'Richard Gasquet', 'country': 'France'}, {'id': 1207446, 'first_name': 'Minaur', 'last_name': 'De', 'full_name': 'Minaur De', 'country': 'Australia'}, {'id': 392304, 'first_name': 'Kyle', 'last_name': 'Edmund', 'full_name': 'Kyle Edmund', 'country': 'United Kingdom'}, {'id': 606618, 'first_name': 'Frances', 'last_name': 'Tiafoe', 'full_name': 'Frances Tiafoe', 'country': 'USA'}, {'id': 88428, 'first_name': 'Gilles', 'last_name': 'Simon', 'full_name': 'Gilles Simon', 'country': 'France'}, {'id': 87756, 'first_name': 'Philipp', 'last_name': 'Kohlschreiber', 'full_name': 'Philipp Kohlschreiber', 'country': 'Germany'}, {'id': 89076, 'f ...

# %%
DataList = []
for i in dictData['results']['players']:
    DataList.append((i['id'], i['first_name'], i['last_name'], i['full_name'], i['country']))
print(DataList)
# Out:
# [(89304, 'Novak', 'Djokovic', 'Novak Djokovic', 'Serbia'), (86928, 'Rafael', 'Nadal', 'Rafael Nadal', 'Spain'), (342990, 'Alexander', 'Zverev', 'Alexander Zverev', 'Germany'), (91668, 'Potro', 'Del', 'Potro Del', 'Argentina'), (93378, 'Kevin', 'Anderson', 'Kevin Anderson', 'South Africa'), (86064, 'Roger', 'Federer', 'Roger Federer', 'Switzerland'), (94410, 'Kei', 'Nishikori', 'Kei Nishikori', 'Japan'), (262500, 'Dominic', 'Thiem', 'Dominic Thiem', 'Austria'), (96732, 'John', 'Isner', 'John Isner', 'USA'), (92334, 'Marin', 'Cilic', 'Marin Cilic', 'Croatia'), (540492, 'Karen', 'Khachanov', 'Karen Khachanov', 'Russia'), (734208, 'Stefanos', 'Tsitsipas', 'Stefanos Tsitsipas', 'Greece'), (387492, 'Borna', 'Coric', 'Borna Coric', 'Croatia'), (108678, 'Milos', 'Raonic', 'Milos Raonic', 'Canada'), (92616, 'Fabio', 'Fognini', 'Fabio Fognini', 'Italy'), (981036, 'Daniil', 'Medvedev', 'Daniil Medvedev', 'Russia'), (346230, 'Lucas', 'Pouille', 'Lucas Pouille', 'France'), (100332, 'Agut', 'Bautista', 'Agut Bautista', 'Spain'), (267306, 'Marco', 'Cecchinato', 'Marco Cecchinato', 'Italy'), (291606, 'Diego', 'Schwartzman', 'Diego Schwartzman', 'Argentina'), (155040, 'David', 'Goffin', 'David Goffin', 'Belgium'), (157236, 'Nikoloz', 'Basilashvili', 'Nikoloz Basilashvili', 'Georgia'), (244812, 'Busta', 'Carreno', 'Busta Carreno', 'Spain'), (141498, 'Grigor', 'Dimitrov', 'Grigor Dimitrov', 'Bulgaria'), (707508, 'Denis', 'Shapovalov', 'Denis Shapovalov', 'Canada'), (86940, 'Fernando', 'Verdasco', 'Fernando Verdasco', 'Spain'), (86496, 'Richard', 'Gasquet', 'Richard Gasquet', 'France'), (1207446, 'Minaur', 'De', 'Minaur De', 'Australia'), (392304, 'Kyle', 'Edmund', 'Kyle Edmund', 'United Kingdom'), (606618, 'Frances', 'Tiafoe', 'Frances Tiafoe', 'USA'), (88428, 'Gilles', 'Simon', 'Gilles Simon', 'France'), (87756, 'Philipp', 'Kohlschreiber', 'Philipp Kohlschreiber', 'Germany'), (89076, 'Gael', 'Monfils', 'Gael Monfils', 'France'), (230970, 'Steve', 'Johnson', 'Steve Johnson', 'USA'), (94986, 'Jeremy', 'Chardy', 'Jeremy Chardy', 'France'), (198702, 'John', 'Millman', 'John Millman', 'Australia'), (88650, 'Andreas', 'Seppi', 'Andreas Seppi', 'Italy'), (95910, 'Martin', 'Klizan', 'Martin Klizan', 'Slovakia'), (226722, 'Joao', 'Sousa', 'Joao Sousa', 'Portugal'), (816264, 'Taylor', 'Fritz', 'Taylor Fritz', 'USA'), (537804, 'Nicolas', 'Jarry', 'Nicolas Jarry', 'Chile'), (235416, 'Dusan', 'Lajovic', 'Dusan Lajovic', 'Serbia'), (95130, 'Malek', 'Jaziri', 'Malek Jaziri', 'Tunisia'), (267330, 'Pierre', 'Herbert', 'Pierre Herbert', 'France'), (98466, 'Matthew', 'Ebden', 'Matthew Ebden', 'Australia'), (95376, 'Adrian', 'Mannarino', 'Adrian Mannarino', 'France'), (286632, 'Marton', 'Fucsovics', 'Marton Fucsovics', 'Hungary'), (91818, 'Sam', 'Querrey', 'Sam Querrey', 'USA'), (93402, 'Leonardo', 'Mayer', 'Leonardo Mayer', 'Argentina'), (499278, 'Hyeon', 'Chung', 'Hyeon Chung', 'South Korea'), (278358, 'Jan', 'Struff', 'Jan Struff', 'Germany'), (295044, 'Damir', 'Dzumhur', 'Damir Dzumhur', 'Bosnia & Herzegovina'), (676710, 'Matteo', 'Berrettini', 'Matteo Berrettini', 'Italy'), (96264, 'Robin', 'Haase', 'Robin Haase', 'Netherlands'), (100110, 'Mikhail', 'Kukushkin', 'Mikhail Kukushkin', 'Kazakhstan'), (97974, 'Marius', 'Copil', 'Marius Copil', 'Romania'), (87300, 'Stan', 'Wawrinka', 'Stan Wawrinka', 'Switzerland'), (133320, 'Benoit', 'Paire', 'Benoit Paire', 'France'), (219582, 'Denis', 'Kudla', 'Denis Kudla', 'USA'), (146520, 'Guido', 'Pella', 'Guido Pella', 'Argentina'), (526152, 'Jordan', 'Thompson', 'Jordan Thompson', 'Australia'), (97176, 'Peter', 'Gojowczyk', 'Peter Gojowczyk', 'Germany'), (86802, 'Feliciano', 'Lopez', 'Feliciano Lopez', 'Spain'), (575622, 'Cameron', 'Norrie', 'Cameron Norrie', 'United Kingdom'), (228144, 'Aljaz', 'Bedene', 'Aljaz Bedene', 'Slovenia'), (355698, 'Yoshihito', 'Nishioka', 'Yoshihito Nishioka', 'Japan'), (374952, 'Nick', 'Kyrgios', 'Nick Kyrgios', 'Australia'), (96078, 'Mischa', 'Zverev', 'Mischa Zverev', 'Germany'), (291804, ' ...

# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
import pandas as pd
column_names=["id","first_name","last_name", "full_name", "country"]
df=pd.DataFrame(DataList,columns=column_names)
print(df.head)
# Out:
# <bound method NDFrame.head of           id first_name last_name         full_name         country
# 0      89304      Novak  Djokovic    Novak Djokovic          Serbia
# 1      86928     Rafael     Nadal      Rafael Nadal           Spain
# 2     342990  Alexander    Zverev  Alexander Zverev         Germany
# 3      91668      Potro       Del         Potro Del       Argentina
# 4      93378      Kevin  Anderson    Kevin Anderson    South Africa
# ..       ...        ...       ...               ...             ...
# 896  1196940    Eduardo   Ribeiro   Eduardo Ribeiro          Brazil
# 897  1735050      Giles    Hussey      Giles Hussey  United Kingdom
# 898  2057862       Mili  Poljicak     Mili Poljicak         Croatia
# 899  1930746     Arthur      Fery       Arthur Fery  United Kingdom
# 900  1796898     Philip   Sekulic    Philip Sekulic       Australia
#
# [901 rows x 5 columns]>

# %%
import cx_Oracle
from cx_Oracle import DatabaseError
connection = cx_Oracle.connect(user="system", password="ADMIN",
                               dsn="192.168.56.1:1521/xepdb1",
                               encoding="UTF-8")
if conn:
    print("cx_Oracle version:", cx_Oracle.version)
    print("Database version:", cx_Oracle.version)
    print("Client version:", cx_Oracle.clientversion())
# Out:
# cx_Oracle version: 8.3.0
# Database version: 8.3.0
# Client version: (21, 3, 0, 0, 0)

# %%
pip install cx_Oracle
# Out:
# Collecting cx_Oracle
#   Downloading cx_Oracle-8.3.0-cp38-cp38-win_amd64.whl (219 kB)
# Installing collected packages: cx-Oracle
# Successfully installed cx-Oracle-8.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import cx_Oracle as orcCon
from cx_Oracle import DatabaseError
try:
    conn = orcCon.connect(user="system", password="ADMIN",
                               dsn="192.168.56.1:1521/xe",
                               encoding="UTF-8")
    if conn:
        print("cx_Oracle version:", orcCon.version)
        print("Database version:", conn.version)
        print("Client version:", orcCon.clientversion())
        
        # Now execute the sqlquery 
        cursor = conn.cursor()
        print("You're connected.................")
        
        # Drop table if exists
        print('Droping raw_players_from_live_api table if exists............')
        cursor.execute("BEGIN EXECUTE IMMEDIATE 'DROP TABLE raw_players_from_live_api'; EXCEPTION WHEN OTHERS THEN NULL; END;")
        
        print('Creating table raw_players_from_live_api............')
        cursor.execute("CREATE TABLE raw_players_from_live_api (id number, first_name varchar(500), last_name varchar(500), full_name varchar(500),country varchar(500))")
        print("raw_players_from_live_api table is created..............")
except DatabaseError as e:
    err, = e.args
    print("Oracle-Error-Code:", err.code)
    print("Oracle-Error-Message:", err.message)
finally:
    cursor.close()
    conn.close()
# Out:
# cx_Oracle version: 8.3.0
# Database version: 21.3.0.0.0
# Client version: (21, 3, 0, 0, 0)
# You're connected.................
# Droping raw_players_from_live_api table if exists............
# Creating table raw_players_from_live_api............
# raw_players_from_live_api table is created..............

# %%
import cx_Oracle as orcCon
from cx_Oracle import DatabaseError
try:
    #orcCon.connect('username/password@localhost')
    conn = orcCon.connect(user="system", password="ADMIN",
                               dsn="192.168.56.1:1521/xe",
                               encoding="UTF-8")
    if conn:
        print("cx_Oracle version:", orcCon.version)
        print("Database version:", conn.version)
        print("Client version:", orcCon.clientversion())
        cursor = conn.cursor()
        print("You're connected: ")
        print('Inserting data into table....')
        for i,row in df.iterrows():
            sql = "INSERT INTO raw_players_from_live_api(id,first_name,last_name,full_name,country) VALUES(:1,:2,:3,:4,:5)"
            cursor.execute(sql, tuple(row))
        # the connection is not autocommitted by default, so we must commit to save our changes
        conn.commit()
        print("Record inserted succesfully")
except DatabaseError as e:
    err, = e.args
    print("Oracle-Error-Code:", err.code)
    print("Oracle-Error-Message:", err.message)
finally:
    cursor.close()
    conn.close()
# Out:
# cx_Oracle version: 8.3.0
# Database version: 21.3.0.0.0
# Client version: (21, 3, 0, 0, 0)
# You're connected:
# Inserting data into table....
# Record inserted succesfully

# %%
conn = orcCon.connect(user="system", password="ADMIN",
                               dsn="192.168.56.1:1521/xe",
                               encoding="UTF-8")
cursor = conn.cursor()    
# Execute query
sql = "SELECT * FROM raw_players_from_live_api"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
    
cursor.close()
conn.close()
# Out:
# (89304, 'Novak', 'Djokovic', 'Novak Djokovic', 'Serbia')
# (86928, 'Rafael', 'Nadal', 'Rafael Nadal', 'Spain')
# (342990, 'Alexander', 'Zverev', 'Alexander Zverev', 'Germany')
# (91668, 'Potro', 'Del', 'Potro Del', 'Argentina')
# (93378, 'Kevin', 'Anderson', 'Kevin Anderson', 'South Africa')
# (86064, 'Roger', 'Federer', 'Roger Federer', 'Switzerland')
# (94410, 'Kei', 'Nishikori', 'Kei Nishikori', 'Japan')
# (262500, 'Dominic', 'Thiem', 'Dominic Thiem', 'Austria')
# (96732, 'John', 'Isner', 'John Isner', 'USA')
# (92334, 'Marin', 'Cilic', 'Marin Cilic', 'Croatia')
# (540492, 'Karen', 'Khachanov', 'Karen Khachanov', 'Russia')
# (734208, 'Stefanos', 'Tsitsipas', 'Stefanos Tsitsipas', 'Greece')
# (387492, 'Borna', 'Coric', 'Borna Coric', 'Croatia')
# (108678, 'Milos', 'Raonic', 'Milos Raonic', 'Canada')
# (92616, 'Fabio', 'Fognini', 'Fabio Fognini', 'Italy')
# (981036, 'Daniil', 'Medvedev', 'Daniil Medvedev', 'Russia')
# (346230, 'Lucas', 'Pouille', 'Lucas Pouille', 'France')
# (100332, 'Agut', 'Bautista', 'Agut Bautista', 'Spain')
# (267306, 'Marco', 'Cecchinato', 'Marco Cecchinato', 'Italy')
# (291606, 'Diego', 'Schwartzman', 'Diego Schwartzman', 'Argentina')
# (155040, 'David', 'Goffin', 'David Goffin', 'Belgium')
# (157236, 'Nikoloz', 'Basilashvili', 'Nikoloz Basilashvili', 'Georgia')
# (244812, 'Busta', 'Carreno', 'Busta Carreno', 'Spain')
# (141498, 'Grigor', 'Dimitrov', 'Grigor Dimitrov', 'Bulgaria')
# (707508, 'Denis', 'Shapovalov', 'Denis Shapovalov', 'Canada')
# (86940, 'Fernando', 'Verdasco', 'Fernando Verdasco', 'Spain')
# (86496, 'Richard', 'Gasquet', 'Richard Gasquet', 'France')
# (1207446, 'Minaur', 'De', 'Minaur De', 'Australia')
# (392304, 'Kyle', 'Edmund', 'Kyle Edmund', 'United Kingdom')
# (606618, 'Frances', 'Tiafoe', 'Frances Tiafoe', 'USA')
# (88428, 'Gilles', 'Simon', 'Gilles Simon', 'France')
# (87756, 'Philipp', 'Kohlschreiber', 'Philipp Kohlschreiber', 'Germany')
# (89076, 'Gael', 'Monfils', 'Gael Monfils', 'France')
# (230970, 'Steve', 'Johnson', 'Steve Johnson', 'USA')
# (94986, 'Jeremy', 'Chardy', 'Jeremy Chardy', 'France')
# (198702, 'John', 'Millman', 'John Millman', 'Australia')
# (88650, 'Andreas', 'Seppi', 'Andreas Seppi', 'Italy')
# (95910, 'Martin', 'Klizan', 'Martin Klizan', 'Slovakia')
# (226722, 'Joao', 'Sousa', 'Joao Sousa', 'Portugal')
# (816264, 'Taylor', 'Fritz', 'Taylor Fritz', 'USA')
# (537804, 'Nicolas', 'Jarry', 'Nicolas Jarry', 'Chile')
# (235416, 'Dusan', 'Lajovic', 'Dusan Lajovic', 'Serbia')
# (95130, 'Malek', 'Jaziri', 'Malek Jaziri', 'Tunisia')
# (267330, 'Pierre', 'Herbert', 'Pierre Herbert', 'France')
# (98466, 'Matthew', 'Ebden', 'Matthew Ebden', 'Australia')
# (95376, 'Adrian', 'Mannarino', 'Adrian Mannarino', 'France')
# (286632, 'Marton', 'Fucsovics', 'Marton Fucsovics', 'Hungary')
# (91818, 'Sam', 'Querrey', 'Sam Querrey', 'USA')
# (93402, 'Leonardo', 'Mayer', 'Leonardo Mayer', 'Argentina')
# (499278, 'Hyeon', 'Chung', 'Hyeon Chung', 'South Korea')
# (278358, 'Jan', 'Struff', 'Jan Struff', 'Germany')
# (295044, 'Damir', 'Dzumhur', 'Damir Dzumhur', 'Bosnia & Herzegovina')
# (676710, 'Matteo', 'Berrettini', 'Matteo Berrettini', 'Italy')
# (96264, 'Robin', 'Haase', 'Robin Haase', 'Netherlands')
# (100110, 'Mikhail', 'Kukushkin', 'Mikhail Kukushkin', 'Kazakhstan')
# (97974, 'Marius', 'Copil', 'Marius Copil', 'Romania')
# (87300, 'Stan', 'Wawrinka', 'Stan Wawrinka', 'Switzerland')
# (133320, 'Benoit', 'Paire', 'Benoit Paire', 'France')
# (219582, 'Denis', 'Kudla', 'Denis Kudla', 'USA')
# (146520, 'Guido', 'Pella', 'Guido Pella', 'Argentina')
# (526152, 'Jordan', 'Thompson', 'Jordan Thompson', 'Australia')
# (97176, 'Peter', 'Gojowczyk', 'Peter Gojowczyk', 'Germany')
# (86802, 'Feliciano', 'Lopez', 'Feliciano Lopez', 'Spain')
# (575622, 'Cameron', 'Norrie', 'Cameron Norrie', 'United Kingdom')
# (228144, 'Aljaz', 'Bedene', 'Aljaz Bedene', 'Slovenia')
# (355698, 'Yoshihito', 'Nishioka', 'Yoshihito Nishioka', 'Japan')
# (374952, 'Nick', 'Kyrgios', 'Nick Kyrgios', 'Australia')
# (96078, 'Mischa', 'Zverev', 'Mischa Zverev', 'Germany')
# (291804, 'Taro', 'Daniel', 'Taro Daniel', 'Japan')
# (283782, 'Guido', 'Andreozzi', 'Guido Andreozzi', 'Argentina')
# (100944, 'Vinolas', 'Ramos', 'Vinolas Ramos', 'Spain')
# (137832, 'Filip', 'Krajinovic', 'Filip Krajinovic', 'Serbia')
# (953388, 'Hubert', 'Hurkacz', 'Hubert Hurkacz', 'Poland')
# (306858, 'Baena', 'Carballes', 'Baena Carballes', 'Spain')
# (220080, 'Tennys', 'Sandgren', 'Tennys Sandgren', 'USA')
# (429972, 'Maximilian', 'Marterer', 'Maximilian Marterer', 'Germany')
# (211014, 'Federico', 'Delbonis', 'Federico Delbonis', 'Argentina')
# (87174, 'Ivo', 'Karlovic', 'Ivo Karlovic', 'Croatia')
# (87072, 'Tomáš', 'Berdych', 'Tomáš Berdych', 'Czech Republic')
# (758148, 'Jaume', 'Munar', 'Jaume Munar', 'Spain')
# (535932, 'Ilya', 'Ivashka', 'Ilya Ivashka', 'Belarus')
# (380640, 'Mackenzie', 'Mcdonald', 'Mackenzie Mcdonald', 'USA')
# (92604, 'Pablo', 'Andujar', 'Pablo Andujar', 'Spain')
# (94362, 'Ernests', 'Gulbis', 'Ernests Gulbis', 'Latvia')
# (99102, 'Thomas', 'Fabbiano', 'Thomas Fabbiano', 'Italy')
# (102492, 'Bernard', 'Tomic', 'Bernard Tomic', 'Australia')
# (230460, 'Bradley', 'Klahn', 'Bradley Klahn', 'USA')
# (583398, 'Laslo', 'Djere', 'Laslo Djere', 'Serbia')
# (342138, 'Jozef', 'Kovalik', 'Jozef Kovalik', 'Slovakia')
# (267294, 'Radu', 'Albot', 'Radu Albot', 'Moldova')
# (1112340, 'Ugo', 'Humbert', 'Ugo Humbert', 'France')
# (94746, 'Pablo', 'Cuevas', 'Pablo Cuevas', 'Uruguay')
# (137412, 'Ryan', 'Harrison', 'Ryan Harrison', 'USA')
# (100686, 'Vasek', 'Pospisil', 'Vasek Pospisil', 'Canada')
# (387432, 'Cristian', 'Garin', 'Cristian Garin', 'Chile')
# (102114, 'Evgeny', 'Donskoy', 'Evgeny Donskoy', 'Russia')
# (251154, 'Jiri', 'Vesely', 'Jiri Vesely', 'Czech Republic')
# (782412, 'Reilly', 'Opelka', 'Reilly Opelka', 'USA')
# (108408, 'Mirza', 'Basic', 'Mirza Basic', 'Bosnia & Herzegovina')
# (640542, 'Andrey', 'Rublev', 'Andrey Rublev', 'Russia')
# (107940, 'Pedro', 'Sousa', 'Pedro Sousa', 'Portugal')
# (109302, 'Prajnesh', 'Gunneswaran', 'Prajnesh Gunneswaran', 'India')
# (87918, 'Lopez', 'Garcia', 'Lopez Garcia', 'Spain')
# (137748, 'Ricardas', 'Berankis', 'Ricardas Berankis', 'Lithuania')
# (94470, 'Denis', 'Istomin', 'Denis Istomin', 'Uzbekistan')
# (1152090, 'Aliassime', 'Auger', 'Aliassime Auger', 'Canada')
# (285630, 'Thiago', 'Monteiro', 'Thiago Monteiro', 'Brazil')
# (248238, 'Jack', 'Sock', 'Jack Sock', 'USA')
# (93420, 'Marcel', 'Granollers', 'Marcel Granollers', 'Spain')
# (788664, 'Michael', 'Mmoh', 'Michael Mmoh', 'USA')
# (946860, 'Lloyd', 'Harris', 'Lloyd Harris', 'South Africa')
# (283794, 'Juan', 'Londero', 'Juan Londero', 'Argentina')
# (629094, 'Lorenzo', 'Sonego', 'Lorenzo Sonego', 'Italy')
# (89496, 'Paolo', 'Lorenzi', 'Paolo Lorenzi', 'Italy')
# (380688, 'Jason', 'Jung', 'Jason Jung', 'Chinese Taipei')
# (501978, 'Elias', 'Ymer', 'Elias Ymer', 'Sweden')
# (231114, 'Marco', 'Trungelliti', 'Marco Trungelliti', 'Argentina')
# (1191564, 'Miomir', 'Kecmanovic', 'Miomir Kecmanovic', 'Serbia')
# (343746, 'Hugo', 'Dellien', 'Hugo Dellien', 'Bolivia')
# (608802, 'Jared', 'Donaldson', 'Jared Donaldson', 'USA')
# (97056, 'Peter', 'Polansky', 'Peter Polansky', 'Canada')
# (526080, 'Yannick', 'Maden', 'Yannick Maden', 'Germany')
# (217812, 'Stefano', 'Travaglia', 'Stefano Travaglia', 'Italy')
# (771324, 'Alexei', 'Popyrin', 'Alexei Popyrin', 'Australia')
# (96252, 'Maceiras', 'Menendez', 'Maceiras Menendez', 'Spain')
# (715500, 'Casper', 'Ruud', 'Casper Ruud', 'Norway')
# (94836, 'Lukas', 'Lacko', 'Lukas Lacko', 'Slovakia')
# (88644, 'Marcos', 'Baghdatis', 'Marcos Baghdatis', 'Cyprus')
# (350226, 'Alex', 'Bolt', 'Alex Bolt', 'Australia')
# (238368, 'Jason', 'Kubler', 'Jason Kubler', 'Australia')
# (332574, 'Bjorn', 'Fratangelo', 'Bjorn Fratangelo', 'USA')
# (102036, 'Ruben', 'Bemelmans', 'Ruben Bemelmans', 'Belgium')
# (353274, 'Ramkumar', 'Ramanathan', 'Ramkumar Ramanathan', 'India')
# (427692, 'Thanasi', 'Kokkinakis', 'Thanasi Kokkinakis', 'Australia')
# (89334, 'Carlos', 'Berlocq', 'Carlos Berlocq', 'Argentina')
# (89430, 'Sergiy', 'Stakhovsky', 'Sergiy Stakhovsky', 'Ukraine')
# (544800, 'Quentin', 'Halys', 'Quentin Halys', 'France')
# (91872, 'Simone', 'Bolelli', 'Simone Bolelli', 'Italy')
# (96534, 'Silva', 'Dutra', 'Silva Dutra', 'Brazil')
# (97728, 'Lukas', 'Rosol', 'Lukas Rosol', 'Czech Republic')
# (107766, 'Tatsuma', 'Ito', 'Tatsuma Ito', 'Japan')
# (102120, 'Henri', 'Laaksonen', 'Henri Laaksonen', 'Switzerland')
# (1050096, 'Corentin', 'Moutet', 'Corentin Moutet', 'France')
# (91398, 'Matthias', 'Bachinger', 'Matthias Bachinger', 'Germany')
# (568494, 'Antoine', 'Hoang', 'Antoine Hoang', 'France')
# (376752, 'Constant', 'Lestienne', 'Constant Lestienne', 'France')
# (229110, 'Facundo', 'Bagnis', 'Facundo Bagnis', 'Argentina')
# (86436, 'David', 'Ferrer', 'David Ferrer', 'Spain')
# (261540, 'Jurgen', 'Zopp', 'Jurgen Zopp', 'Estonia')
# (390108, 'Noah', 'Rubin', 'Noah Rubin', 'USA')
# (137814, 'Yuki', 'Bhambri', 'Yuki Bhambri', 'India')
# (303774, 'Gianluigi', 'Quinzi', 'Gianluigi Quinzi', 'Italy')
# (107004, 'Luca', 'Vanni', 'Luca Vanni', 'Italy')
# (355836, 'Dennis', 'Novak', 'Dennis Novak', 'Austria')
# (402936, 'Gregoire', 'Barrere', 'Gregoire Barrere', 'France')
# (652266, 'Kamil', 'Majchrzak', 'Kamil Majchrzak', 'Poland')
# (1185108, 'Christopher', 'Eubanks', 'Christopher Eubanks', 'USA')
# (99054, 'Yuichi', 'Sugita', 'Yuichi Sugita', 'Japan')
# (287862, 'Yannick', 'Hanfmann', 'Yannick Hanfmann', 'Germany')
# (776220, 'Dominik', 'Koepfer', 'Dominik Koepfer', 'Germany')
# (295710, 'Egor', 'Gerasimov', 'Egor Gerasimov', 'Belarus')
# (463350, 'Pedro', 'Martinez', 'Pedro Martinez', 'Spain')
# (98262, 'Daniel', 'Evans', 'Daniel Evans', 'United Kingdom')
# (398832, 'Brayden', 'Schnur', 'Brayden Schnur', 'Canada')
# (374436, 'Oscar', 'Otte', 'Oscar Otte', 'Germany')
# (505530, 'Filippo', 'Baldi', 'Filippo Baldi', 'Italy')
# (101010, 'Alessandro', 'Giannessi', 'Alessandro Giannessi', 'Italy')
# (484002, 'Marc', 'Polmans', 'Marc Polmans', 'Australia')
# (355872, 'Salvatore', 'Caruso', 'Salvatore Caruso', 'Italy')
# (278352, 'Yasutaka', 'Uchiyama', 'Yasutaka Uchiyama', 'Japan')
# (980892, 'Alexander', 'Bublik', 'Alexander Bublik', 'Kazakhstan')
# (307950, 'Darian', 'King', 'Darian King', 'Barbados')
# (438108, 'Pedja', 'Krstin', 'Pedja Krstin', 'Serbia')
# (446646, 'Nikola', 'Milojevic', 'Nikola Milojevic', 'Serbia')
# (96354, 'Andrea', 'Arnaboldi', 'Andrea Arnaboldi', 'Italy')
# (500394, 'Sebastian', 'Ofner', 'Sebastian Ofner', 'Austria')
# (194808, 'Hiroki', 'Moriya', 'Hiroki Moriya', 'Japan')
# (232770, 'Roberto', 'Quiroz', 'Roberto Quiroz', 'Ecuador')
# (314784, 'Alexey', 'Vatutin', 'Alexey Vatutin', 'Russia')
# (99330, 'James', 'Ward', 'James Ward', 'United Kingdom')
# (146502, 'Andrej', 'Martin', 'Andrej Martin', 'Slovakia')
# (1254630, 'Rudolf', 'Molleker', 'Rudolf Molleker', 'Germany')
# (943824, 'Yosuke', 'Watanuki', 'Yosuke Watanuki', 'Japan')
# (87888, 'Gilles', 'Müller', 'Gilles Müller', 'Luxembourg')
# (98148, 'Daniel', 'Brands', 'Daniel Brands', 'Germany')
# (92820, 'Viktor', 'Troicki', 'Viktor Troicki', 'Serbia')
# (95586, 'Tim', 'Smyczek', 'Tim Smyczek', 'USA')
# (451434, 'Mats', 'Moraing', 'Mats Moraing', 'Germany')
# (88776, 'Traver', 'Gimeno', 'Traver Gimeno', 'Spain')
# (96972, 'Horacio', 'Zeballos', 'Horacio Zeballos', 'Argentina')
# (152754, 'Aleksandr', 'Nedovyesov', 'Aleksandr Nedovyesov', 'Kazakhstan')
# (252924, 'Stefano', 'Napolitano', 'Stefano Napolitano', 'Italy')
# (268266, 'Facundo', 'Arguello', 'Facundo Arguello', 'Argentina')
# (912300, 'Mikael', 'Ymer', 'Mikael Ymer', 'Sweden')
# (329742, 'Kimmer', 'Coppejans', 'Kimmer Coppejans', 'Belgium')
# (87060, 'Nicolas', 'Mahut', 'Nicolas Mahut', 'France')
# (1200966, 'Jurij', 'Rodionov', 'Jurij Rodionov', 'Austria')
# (831288, 'Tommy', 'Paul', 'Tommy Paul', 'USA')
# (355956, 'Adam', 'Pavlasek', 'Adam Pavlasek', 'Czech Republic')
# (252186, 'Mohamed', 'Safwat', 'Mohamed Safwat', 'Egypt')
# (87450, 'Stéphane', 'Robert', 'Stéphane Robert', 'France')
# (229662, 'Greef', 'De', 'Greef De', 'Belgium')
# (94434, 'Donald', 'Young', 'Donald Young', 'USA')
# (86022, 'Tommy', 'Robredo', 'Tommy Robredo', 'Spain')
# (152742, 'Blaz', 'Rola', 'Blaz Rola', 'Slovenia')
# (482958, 'Ernesto', 'Escobedo', 'Ernesto Escobedo', 'USA')
# (416712, 'Matteo', 'Donati', 'Matteo Donati', 'Italy')
# (230346, 'Ze', 'Zhang', 'Ze Zhang', 'China')
# (313668, 'Mitchell', 'Krueger', 'Mitchell Krueger', 'USA')
# (90552, 'Jo', 'Tsonga', 'Jo Tsonga', 'France')
# (734220, 'Tallon', 'Griekspoor', 'Tallon Griekspoor', 'Netherlands')
# (1186866, 'Jay', 'Clarke', 'Jay Clarke', 'United Kingdom')
# (343974, 'Joao', 'Domingues', 'Joao Domingues', 'Portugal')
# (102240, 'John', 'Smith', 'John Smith', 'Australia')
# (97704, 'Blaz', 'Kavcic', 'Blaz Kavcic', 'Slovenia')
# (150156, 'Sergio', 'Gutiérrez-Ferrol', 'Sergio Gutiérrez-Ferrol', 'Spain')
# (94446, 'Go', 'Soeda', 'Go Soeda', 'Japan')
# (95760, 'Tobias', 'Kamke', 'Tobias Kamke', 'Germany')
# (233460, 'Filip', 'Horansky', 'Filip Horansky', 'Slovakia')
# (487638, 'Calvin', 'Hemery', 'Calvin Hemery', 'France')
# (311028, 'Marcelo', 'Arevalo', 'Marcelo Arevalo', 'El Salvador')
# (645762, 'Maxime', 'Janvier', 'Maxime Janvier', 'France')
# (96888, 'Thomaz', 'Bellucci', 'Thomaz Bellucci', 'Brazil')
# (417012, 'Gianluca', 'Mager', 'Gianluca Mager', 'Italy')
# (90768, 'Andy', 'Murray', 'Andy Murray', 'United Kingdom')
# (141996, 'Federico', 'Gaio', 'Federico Gaio', 'Italy')
# (291768, 'Lorenzo', 'Giustino', 'Lorenzo Giustino', 'Italy')
# (552456, 'Daniel', 'Galan', 'Daniel Galan', 'Colombia')
# (600594, 'Gian', 'Moroni', 'Gian Moroni', 'Italy')
# (355920, 'Viktor', 'Galovic', 'Viktor Galovic', 'Croatia')
# (795360, 'Zdenek', 'Kolar', 'Zdenek Kolar', 'Czech Republic')
# (219570, 'Kevin', 'Krawietz', 'Kevin Krawietz', None)
# (95598, 'Dustin', 'Brown', 'Dustin Brown', 'Germany')
# (107922, 'Guilherme', 'Clezar', 'Guilherme Clezar', 'Brazil')
# (944748, 'Fokina', 'Davidovich', 'Fokina Davidovich', 'Spain')
# (585894, 'Soonwoo', 'Kwon', 'Soonwoo Kwon', 'South Korea')
# (96414, 'Thiemo', 'de Bakker', 'Thiemo de Bakker', 'Netherlands')
# (297972, 'Filip', 'Peliwo', 'Filip Peliwo', 'Poland')
# (238278, 'James', 'Duckworth', 'James Duckworth', 'Australia')
# (91812, 'Dudi', 'Sela', 'Dudi Sela', 'Israel')
# (562182, 'Duckhee', 'Lee', 'Duckhee Lee', 'South Korea')
# (312402, 'Christian', 'Harrison', 'Christian Harrison', 'USA')
# (296166, 'Gleb', 'Sakharov', 'Gleb Sakharov', 'France')
# (306876, 'Perez', 'Lopez', 'Perez Lopez', 'Spain')
# (396528, 'Nicolas', 'Kicker', 'Nicolas Kicker', 'Argentina')
# (95160, 'Gastao', 'Elias', 'Gastao Elias', 'Portugal')
# (254286, 'Marcos', 'Giron', 'Marcos Giron', 'USA')
# (1171500, 'Nicola', 'Kuhn', 'Nicola Kuhn', 'Germany')
# (102054, 'Uladzimir', 'Ignatik', 'Uladzimir Ignatik', 'Belarus')
# (319110, 'Cem', 'Ilkel', 'Cem Ilkel', 'Turkey')
# (93192, 'Santiago', 'Giraldo', 'Santiago Giraldo', 'Colombia')
# (446658, 'Enzo', 'Couacaud', 'Enzo Couacaud', 'France')
# (307866, 'Subervi', 'Cid', 'Subervi Cid', 'Dominican Republic')
# (248850, 'Schepper', 'De', 'Schepper De', 'France')
# (300846, 'Norbert', 'Gombos', 'Norbert Gombos', 'Slovakia')
# (146484, 'Gerald', 'Melzer', 'Gerald Melzer', 'Austria')
# (535896, 'Jc', 'Aragone', 'Jc Aragone', 'USA')
# (145866, 'Attila', 'Balazs', 'Attila Balazs', 'Hungary')
# (540672, 'Nino', 'Serdarusic', 'Nino Serdarusic', 'Croatia')
# (389532, 'Saketh', 'Myneni', 'Saketh Myneni', 'India')
# (320910, 'Daniel', 'Masur', 'Daniel Masur', 'Germany')
# (262488, 'Zhe', 'Li', 'Zhe Li', 'China')
# (566922, 'Benjamin', 'Bonzi', 'Benjamin Bonzi', 'France')
# (144030, 'Matteo', 'Viola', 'Matteo Viola', 'Italy')
# (286746, 'Maverick', 'Banes', 'Maverick Banes', 'Australia')
# (271584, 'Dennis', 'Novikov', 'Dennis Novikov', 'USA')
# (381864, 'Thai', 'Kwiatkowski', 'Thai Kwiatkowski', 'USA')
# (329430, 'Evgeny', 'Karlovskiy', 'Evgeny Karlovskiy', 'Russia')
# (495486, 'Kaichi', 'Uchida', 'Kaichi Uchida', 'Japan')
# (314346, 'Scott', 'Griekspoor', 'Scott Griekspoor', 'Netherlands')
# (486546, 'Johan', 'Tatlot', 'Johan Tatlot', 'France')
# (350238, 'Mathias', 'Bourgue', 'Mathias Bourgue', 'France')
# (1160580, 'Fernandez', 'Hernandez', 'Fernandez Hernandez', 'Dominican Republic')
# (428028, 'Martinez', 'Vilella', 'Martinez Vilella', 'Spain')
# (472770, 'Lucas', 'Miedler', 'Lucas Miedler', 'Austria')
# (651402, 'Miralles', 'Zapata', 'Miralles Zapata', 'Spain')
# (443934, 'Pedro', 'Cachin', 'Pedro Cachin', 'Argentina')
# (597534, 'Yunseong', 'Chung', 'Yunseong Chung', 'South Korea')
# (814728, 'Elliot', 'Benchetrit', 'Elliot Benchetrit', 'Morocco')
# (747960, 'Max', 'Purcell', 'Max Purcell', 'Australia')
# (214938, 'Laurynas', 'Grigelis', 'Laurynas Grigelis', 'Lithuania')
# (346566, 'Goncalo', 'Oliveira', 'Goncalo Oliveira', 'Portugal')
# (102108, 'Tsung', 'Yang', 'Tsung Yang', 'Chinese Taipei')
# (327450, 'Federico', 'Coria', 'Federico Coria', 'Argentina')
# (141600, 'Roberto', 'Marcora', 'Roberto Marcora', 'Italy')
# (307122, 'Danilo', 'Petrovic', 'Danilo Petrovic', 'Serbia')
# (283788, 'Olmedo', 'Ortega', 'Olmedo Ortega', 'Spain')
# (651366, 'Carlos', 'Taberner', 'Carlos Taberner', 'Spain')
# (633654, 'Jan', 'Choinski', 'Jan Choinski', 'United Kingdom')
# (86562, 'Jurgen', 'Melzer', 'Jurgen Melzer', 'Austria')
# (1262886, 'Jeffrey', 'Wolf', 'Jeffrey Wolf', 'USA')
# (707208, 'Sasikumar', 'Mukund', 'Sasikumar Mukund', 'India')
# (499590, 'Akira', 'Santillan', 'Akira Santillan', 'Australia')
# (246288, 'Tomislav', 'Brkic', 'Tomislav Brkic', 'Bosnia & Herzegovina')
# (484362, 'Collin', 'Altamirano', 'Collin Altamirano', 'USA')
# (319290, 'Kevin', 'King', 'Kevin King', 'USA')
# (347322, 'Alexander', 'Sarkissian', 'Alexander Sarkissian', 'USA')
# (526860, 'Mikael', 'Torpegaard', 'Mikael Torpegaard', 'Denmark')
# (251280, 'Ante', 'Pavic', 'Ante Pavic', None)
# (286596, 'Liam', 'Broady', 'Liam Broady', 'United Kingdom')
# (271560, 'Loore', 'De', 'Loore De', 'Belgium')
# (286614, 'Tristan', 'Lamasine', 'Tristan Lamasine', 'France')
# (143406, 'Evan', 'King', 'Evan King', 'USA')
# (826872, 'Ulises', 'Blanch', 'Ulises Blanch', 'USA')
# (262578, 'Andrea', 'Collarini', 'Andrea Collarini', 'Argentina')
# (92814, 'Aldin', 'Setkic', 'Aldin Setkic', 'Bosnia & Herzegovina')
# (217800, 'Steven', 'Diez', 'Steven Diez', 'Canada')
# (229680, 'Martin', 'Cuevas', 'Martin Cuevas', 'Uruguay')
# (1165128, 'Yibing', 'Wu', 'Yibing Wu', 'China')
# (99720, 'Victor', 'Estrella Burgos', 'Victor Estrella Burgos', 'Dominican Republic')
# (431712, 'Sebastian', 'Fanselow', 'Sebastian Fanselow', 'Germany')
# (334734, 'Renzo', 'Olivo', 'Renzo Olivo', 'Argentina')
# (90600, 'Steve', 'Darcis', 'Steve Darcis', 'Belgium')
# (1197978, 'Mate', 'Valkusz', 'Mate Valkusz', 'Hungary')
# (338178, 'Jelle', 'Sels', 'Jelle Sels', 'Netherlands')
# (101844, 'Herrera', 'Gomez', 'Herrera Gomez', 'Spain')
# (98958, 'Vincent', 'Millot', 'Vincent Millot', 'France')
# (308418, 'Evan', 'Song', 'Evan Song', 'USA')
# (1219560, 'Pavel', 'Kotov', 'Pavel Kotov', 'Russia')
# (305094, 'Denis', 'Yevseyev', 'Denis Yevseyev', 'Kazakhstan')
# (138348, 'Di', 'Wu', 'Di Wu', 'China')
# (364140, 'Vaclav', 'Safranek', 'Vaclav Safranek', 'Czech Republic')
# (290796, 'Tak Khunn', 'Wang', 'Tak Khunn Wang', 'France')
# (403836, 'Dragos', 'Dima', 'Dragos Dima', 'Romania')
# (797016, 'Vera', 'Barrios', 'Vera Barrios', 'Chile')
# (337782, 'Lara', 'Ojeda', 'Lara Ojeda', 'Spain')
# (398916, 'Silva', 'Ferreira', 'Silva Ferreira', 'Portugal')
# (277566, 'Maximilian', 'Neuchrist', 'Maximilian Neuchrist', 'Austria')
# (88404, 'Frank', 'Dancevic', 'Frank Dancevic', 'Canada')
# (157230, 'Emilio', 'Gomez', 'Emilio Gomez', 'Ecuador')
# (749592, 'Roman', 'Safiullin', 'Roman Safiullin', 'Russia')
# (1201578, 'Roy', 'Smith', 'Roy Smith', 'USA')
# (306066, 'Dimitar', 'Kuzmanov', 'Dimitar Kuzmanov', 'Bulgaria')
# (102288, 'Rubin', 'Statham', 'Rubin Statham', 'New Zealand')
# (481278, 'Bradley', 'Mousley', 'Bradley Mousley', 'Australia')
# (462054, 'Stefan', 'Kozlov', 'Stefan Kozlov', 'USA')
# (97962, 'Alejandro', 'Gonzalez', 'Alejandro Gonzalez', 'Colombia')
# (561594, 'Andrea', 'Pellegrino', 'Andrea Pellegrino', 'Italy')
# (749508, 'Borna', 'Gojo', 'Borna Gojo', 'Croatia')
# (91686, 'David', 'Guez', 'David Guez', 'France')
# (226830, 'Purkiss', 'Boluda', 'Purkiss Boluda', 'Spain')
# (934116, 'Renta', 'Tokuda', 'Renta Tokuda', 'Japan')
# (269778, 'Miljan', 'Zekic', 'Miljan Zekic', 'Serbia')
# (533964, 'Alexandre', 'Muller', 'Alexandre Muller', 'France')
# (433500, 'Juan', 'Varillas', 'Juan Varillas', 'Peru')
# (374940, 'Andrew', 'Harris', 'Andrew Harris', 'Australia')
# (1065876, 'Yusuke', 'Takahashi', 'Yusuke Takahashi', 'Japan')
# (205602, 'Dayne', 'Kelly', 'Dayne Kelly', 'Australia')
# (789408, 'Sumit', 'Nagal', 'Sumit Nagal', 'India')
# (313770, 'Tim', 'Puetz', 'Tim Puetz', 'Germany')
# (870792, 'Alex', 'Molcan', 'Alex Molcan', 'Slovakia')
# (144066, 'Sergey', 'Betov', 'Sergey Betov', 'Belarus')
# (714852, 'Blake', 'Ellis', 'Blake Ellis', 'Australia')
# (352290, 'Michael', 'Redlicki', 'Michael Redlicki', 'USA')
# (297990, 'Antoine', 'Escoffier', 'Antoine Escoffier', 'France')
# (888564, 'Zihao', 'Xia', 'Zihao Xia', 'China')
# (444594, 'Jared', 'Hiltzik', 'Jared Hiltzik', 'USA')
# (101478, 'Franko', 'Škugor', 'Franko Škugor', 'Croatia')
# (1097814, 'Makoto', 'Ochi', 'Makoto Ochi', 'Japan')
# (238284, 'Luke', 'Saville', 'Luke Saville', 'Australia')
# (454890, 'Zhizhen', 'Zhang', 'Zhizhen Zhang', 'China')
# (870684, 'Marc', 'Huesler', 'Marc Huesler', 'Switzerland')
# (607350, 'Ryan', 'Shane', 'Ryan Shane', 'USA')
# (154110, 'Yan', 'Bai', 'Yan Bai', 'China')
# (97200, 'Gonzalo', 'Escobar', 'Gonzalo Escobar', 'Ecuador')
# (747948, 'Aleksandar', 'Vukic', 'Aleksandar Vukic', 'Australia')
# (983988, 'Tung', 'Wu', 'Tung Wu', 'Chinese Taipei')
# (252918, 'Ji', 'Nam', 'Ji Nam', 'South Korea')
# (337746, 'Andrea', 'Basso', 'Andrea Basso', 'Italy')
# (652614, 'Benjamin', 'Hassan', 'Benjamin Hassan', 'Lebanon')
# (1234782, 'Zsombor', 'Piros', 'Zsombor Piros', 'Hungary')
# (763260, 'Daniel', 'Altmaier', 'Daniel Altmaier', 'Germany')
# (577446, 'Viktor', 'Durasovic', 'Viktor Durasovic', 'Norway')
# (307812, 'Jan', 'Satral', 'Jan Satral', 'Czech Republic')
# (644154, 'Hugo', 'Grenier', 'Hugo Grenier', 'France')
# (89400, 'Harri', 'Heliovaara', 'Harri Heliovaara', 'Finland')
# (639366, 'Sadio', 'Doumbia', 'Sadio Doumbia', 'France')
# (393468, 'Pedro', 'Sakamoto', 'Pedro Sakamoto', 'Brazil')
# (632262, 'Petros', 'Chrysochos', 'Petros Chrysochos', 'Cyprus')
# (305418, 'Dmitry', 'Popko', 'Dmitry Popko', 'Kazakhstan')
# (88950, 'Teimuraz', 'Gabashvili', 'Teimuraz Gabashvili', 'Russia')
# (490074, 'Johannes', 'Haerteis', 'Johannes Haerteis', 'Germany')
# (141288, 'Jeremy', 'Jahn', 'Jeremy Jahn', 'Germany')
# (91638, 'Daniel', 'Muñoz de la Nava', 'Daniel Muñoz de la Nava', 'Spain')
# (1272912, 'Alen', 'Avidzba', 'Alen Avidzba', 'Russia')
# (306612, 'Batalla', 'Roca', 'Batalla Roca', 'Spain')
# (894612, 'Khumoyun', 'Sultanov', 'Khumoyun Sultanov', 'Uzbekistan')
# (458178, 'Arjun', 'Kadhe', 'Arjun Kadhe', 'India')
# (1123428, 'Alexis', 'Galarneau', 'Alexis Galarneau', 'Canada')
# (344226, 'Andrew', 'Whittington', 'Andrew Whittington', 'Australia')
# (448422, 'Tom', 'Jomby', 'Tom Jomby', 'France')
# (729648, 'Joao', 'Menezes', 'Joao Menezes', 'Brazil')
# (326310, 'Alessandro', 'Bega', 'Alessandro Bega', 'Italy')
# (97164, 'Illya', 'Marchenko', 'Illya Marchenko', 'Ukraine')
# (312810, 'Julian', 'Lenz', 'Julian Lenz', 'Germany')
# (98172, 'Brydan', 'Klein', 'Brydan Klein', 'United Kingdom')
# (476586, 'Harry', 'Bourchier', 'Harry Bourchier', 'Australia')
# (142554, 'Gerard', 'Granollers', 'Gerard Granollers', 'Spain')
# (141300, 'Guillermo', 'Olaso', 'Guillermo Olaso', 'Spain')
# (313728, 'Shuichi', 'Sekiguchi', 'Shuichi Sekiguchi', 'Japan')
# (459102, 'Ivan', 'Gakhov', 'Ivan Gakhov', 'Russia')
# (313476, 'N', 'Balaji', 'N Balaji', 'India')
# (252996, 'Sekou', 'Bangoura', 'Sekou Bangoura', 'USA')
# (96750, 'João', 'Souza', 'João Souza', 'Brazil')
# (660666, 'Youssef', 'Hossam', 'Youssef Hossam', 'Egypt')
# (1004232, 'Emil', 'Ruusuvuori', 'Emil Ruusuvuori', 'Finland')
# (476826, 'Jacob', 'Grills', 'Jacob Grills', 'Australia')
# (921876, 'João', 'Monteiro', 'João Monteiro', 'Portugal')
# (1225998, 'Chien-Hsun', 'Lo', 'Chien-Hsun Lo', 'Chinese Taipei')
# (149070, 'Alexander', 'Ward', 'Alexander Ward', 'United Kingdom')
# (939996, 'Rigele', 'Te', 'Rigele Te', 'China')
# (319860, 'Ivan', 'Nedelko', 'Ivan Nedelko', 'Russia')
# (97170, 'Andreas', 'Haider-Maurer', 'Andreas Haider-Maurer', 'Austria')
# (614478, 'Rijthoven', 'Van', 'Rijthoven Van', 'Netherlands')
# (381648, 'Arthur', 'Rinderknech', 'Arthur Rinderknech', 'France')
# (271548, 'Jordi', 'Samper-Montaña', 'Jordi Samper-Montaña', 'Spain')
# (287814, 'Tobias', 'Simon', 'Tobias Simon', 'Germany')
# (341946, 'Martinavarro', 'Artunedo', 'Martinavarro Artunedo', 'Spain')
# (1025688, 'Zizou', 'Bergs', 'Zizou Bergs', 'Belgium')
# (267834, 'Cristian', 'Rodriguez', 'Cristian Rodriguez', 'Colombia')
# (486258, 'Hoang', 'Ly', 'Hoang Ly', 'Vietnam')
# (96408, 'Igor', 'Sijsling', 'Igor Sijsling', 'Netherlands')
# (261828, 'Markus', 'Eriksson', 'Markus Eriksson', 'Sweden')
# (659718, 'Liam', 'Caruana', 'Liam Caruana', 'Italy')
# (1127364, 'Evan', 'Furness', 'Evan Furness', 'France')
# (758424, 'Corentin', 'Denolly', 'Corentin Denolly', 'France')
# (354798, 'Lloyd', 'Glasspool', 'Lloyd Glasspool', 'United Kingdom')
# (1066128, 'Cosano', 'Barranco', 'Cosano Barranco', 'Spain')
# (1211094, 'Raul', 'Brancaccio', 'Raul Brancaccio', 'Italy')
# (320898, 'Marvin', 'Netuschil', 'Marvin Netuschil', 'Germany')
# (287808, 'Albano', 'Olivetti', 'Albano Olivetti', 'France')
# (279738, 'Takanyi', 'Garanganga', 'Takanyi Garanganga', 'Zimbabwe')
# (359916, 'Wishaya', 'Trongcharoenchaikul', 'Wishaya Trongcharoenchaikul', 'Thailand')
# (636930, 'Valle', 'Dalla', 'Valle Dalla', 'Italy')
# (629814, 'Gijs', 'Brouwer', 'Gijs Brouwer', 'Netherlands')
# (313224, 'Hugo', 'Nys', 'Hugo Nys', 'Monaco')
# (363024, 'Aslan', 'Karatsev', 'Aslan Karatsev', 'Russia')
# (419724, 'Martin', 'Redlicki', 'Martin Redlicki', 'USA')
# (328410, 'Riccardo', 'Bonadio', 'Riccardo Bonadio', 'Italy')
# (93300, 'Máximo', 'Gonzalez', 'Máximo Gonzalez', 'Argentina')
# (807672, 'William', 'Blumberg', 'William Blumberg', 'USA')
# (95124, 'Lamine', 'Ouahab', 'Lamine Ouahab', 'Morocco')
# (393660, 'Sidharth', 'Rawat', 'Sidharth Rawat', 'India')
# (151146, 'Austin', 'Krajicek', 'Austin Krajicek', 'USA')
# (403596, 'Fabrizio', 'Ornago', 'Fabrizio Ornago', 'Italy')
# (1231890, 'Alafia', 'Ayeni', 'Alafia Ayeni', 'USA')
# (1268028, 'Harrison', 'Adams', 'Harrison Adams', 'USA')
# (329862, 'Hernan', 'Casanova', 'Hernan Casanova', 'Argentina')
# (638106, 'Fabien', 'Reboul', 'Fabien Reboul', 'France')
# (358188, 'Miliaan', 'Niesten', 'Miliaan Niesten', 'Netherlands')
# (967584, 'Wild', 'Seyboth', 'Wild Seyboth', 'Brazil')
# (748404, 'Edan', 'Leshem', 'Edan Leshem', 'Israel')
# (359628, 'Bastian', 'Malla', 'Bastian Malla', 'Chile')
# (1262952, 'Patrick', 'Kypson', 'Patrick Kypson', 'USA')
# (312354, 'Karue', 'Sell', 'Karue Sell', 'Brazil')
# (490590, 'Gregoire', 'Jacq', 'Gregoire Jacq', 'France')
# (155046, 'Yannick', 'Mertens', 'Yannick Mertens', 'Belgium')
# (574818, 'Andrea', 'Vavassori', 'Andrea Vavassori', 'Italy')
# (581922, 'Ji Hoon', 'Son', 'Ji Hoon Son', 'South Korea')
# (291876, 'Patricio', 'Heras', 'Patricio Heras', 'Argentina')
# (296028, 'Yannick', 'Jankovits', 'Yannick Jankovits', 'France')
# (1337742, 'Chauvinc', 'Cornut', 'Chauvinc Cornut', 'France')
# (683886, 'Juan', 'Ficovich', 'Juan Ficovich', 'Argentina')
# (1176744, 'Carabelli', 'Ugo', 'Carabelli Ugo', 'Argentina')
# (1242216, 'Chun', 'Tseng', 'Chun Tseng', 'Chinese Taipei')
# (1082688, 'Louis', 'Wessels', 'Louis Wessels', 'Germany')
# (307056, 'Edoardo', 'Eremin', 'Edoardo Eremin', 'Italy')
# (569562, 'Ronnie', 'Schneider', 'Ronnie Schneider', 'USA')
# (1415592, 'Michael', 'Vrbensky', 'Michael Vrbensky', 'Czech Republic')
# (433392, 'Altug', 'Celikbilek', 'Altug Celikbilek', 'Turkey')
# (667182, 'Orlando', 'Luz', 'Orlando Luz', 'Brazil')
# (326946, 'Juan Ignacio', 'Galarza', 'Juan Ignacio Galarza', 'Argentina')
# (916332, 'Tom', 'Fawcett', 'Tom Fawcett', 'USA')
# (97500, 'Konstantin', 'Kravchuk', 'Konstantin Kravchuk', 'Russia')
# (227292, 'Alejandro', 'Gomez', 'Alejandro Gomez', 'Colombia')
# (106404, 'Peter', 'Torebko', 'Peter Torebko', 'Germany')
# (684450, 'Lopez', 'Pena', 'Lopez Pena', 'Argentina')
# (298122, 'Riccardo', 'Bellotti', 'Riccardo Bellotti', 'Italy')
# (784464, 'Manuel', 'Sánchez', 'Manuel Sánchez', 'Mexico')
# (1123326, 'Lucas', 'Catarina', 'Lucas Catarina', 'Monaco')
# (317526, 'Robin', 'Kern', 'Robin Kern', 'Germany')
# (213474, 'Felipe', 'Mantilla', 'Felipe Mantilla', 'Colombia')
# (306666, 'Alexander', 'Lazov', 'Alexander Lazov', 'Bulgaria')
# (1192800, 'Colin', 'Sinclair', 'Colin Sinclair', 'Northern Mariana Islands')
# (96096, 'Frederik', 'Nielsen', 'Frederik Nielsen', 'Denmark')
# (1302828, 'Yuta', 'Shimizu', 'Yuta Shimizu', 'Japan')
# (364416, 'Karim', 'Maamoun', 'Karim Maamoun', 'Egypt')
# (1307016, 'Francesco', 'Forti', 'Francesco Forti', 'Italy')
# (606954, 'Alex', 'Rybakov', 'Alex Rybakov', 'USA')
# (1228596, 'Jacopo', 'Berrettini', 'Jacopo Berrettini', 'Italy')
# (714912, 'Thomas', 'Fancutt', 'Thomas Fancutt', 'Australia')
# (497598, 'Evan', 'Hoyt', 'Evan Hoyt', 'United Kingdom')
# (221928, 'Pavel', 'Krainik', 'Pavel Krainik', 'Canada')
# (578982, 'Riccardo', 'Balzerani', 'Riccardo Balzerani', 'Italy')
# (420384, 'Pietro', 'Rondoni', 'Pietro Rondoni', 'Italy')
# (1242312, 'Brandon', 'Holt', 'Brandon Holt', 'USA')
# (95574, 'Marc', 'Sieber', 'Marc Sieber', 'Germany')
# (137736, 'Ruan', 'Roelofse', 'Ruan Roelofse', 'South Africa')
# (727044, 'Jules', 'Okala', 'Jules Okala', 'France')
# (89814, 'Ti', 'Chen', 'Ti Chen', 'Chinese Taipei')
# (1360842, 'Maxime', 'Cressy', 'Maxime Cressy', 'USA')
# (458958, 'Daniel', 'Nguyen', 'Daniel Nguyen', 'USA')
# (614046, 'De', 'Van', 'De Van', 'Netherlands')
# (1198824, 'Alexandar', 'Lazarov', 'Alexandar Lazarov', 'Bulgaria')
# (87324, 'Janko', 'Tipsarevic', 'Janko Tipsarevic', 'Serbia')
# (857400, 'Baptiste', 'Crepatte', 'Baptiste Crepatte', 'France')
# (1239432, 'Jannik', 'Sinner', 'Jannik Sinner', 'Italy')
# (446010, 'Matias', 'Descotte', 'Matias Descotte', 'Argentina')
# (229092, 'Facundo', 'Mena', 'Facundo Mena', 'Argentina')
# (727104, 'Manuel', 'Guinard', 'Manuel Guinard', 'France')
# (273210, 'Gonzalo', 'Lama', 'Gonzalo Lama', 'Chile')
# (851304, 'Geoffrey', 'Blancaneaux', 'Geoffrey Blancaneaux', 'France')
# (665034, 'San', 'Lopez', 'San Lopez', 'Spain')
# (1050432, 'Giovanni', 'Fonio', 'Giovanni Fonio', 'Italy')
# (1566102, 'Lorenzo', 'Musetti', 'Lorenzo Musetti', 'Italy')
# (870744, 'Matteo', 'Martineau', 'Matteo Martineau', 'France')
# (96528, 'Alexandr', 'Dolgopolov', 'Alexandr Dolgopolov', 'Ukraine')
# (1164828, 'Kirill', 'Kivattsev', 'Kirill Kivattsev', 'Russia')
# (1175052, 'Sebastian', 'Korda', 'Sebastian Korda', 'USA')
# (574986, 'Julian', 'Ocleppo', 'Julian Ocleppo', 'Italy')
# (416184, 'Skander', 'Mansouri', 'Skander Mansouri', 'Tunisia')
# (612918, 'Alejandro', 'Tabilo', 'Alejandro Tabilo', 'Chile')
# (750468, 'Ben', 'Patael', 'Ben Patael', 'Israel')
# (366216, 'Lucas', 'Gomez', 'Lucas Gomez', 'Mexico')
# (223266, 'Sandro', 'Ehrat', 'Sandro Ehrat', 'Switzerland')
# (1429812, 'Tomas', 'Machac', 'Tomas Machac', 'Czech Republic')
# (336114, 'Alexander', 'Ritschard', 'Alexander Ritschard', 'Switzerland')
# (304782, 'Peter', 'Heller', 'Peter Heller', 'Germany')
# (396024, 'Laurent', 'Lokoli', 'Laurent Lokoli', 'France')
# (326298, 'Sanjar', 'Fayziev', 'Sanjar Fayziev', 'Uzbekistan')
# (290466, 'Alexander', 'Zhurbin', 'Alexander Zhurbin', 'Russia')
# (448206, 'Pavel', 'Nejedly', 'Pavel Nejedly', 'Czech Republic')
# (272406, 'Raymond', 'Sarmiento', 'Raymond Sarmiento', 'USA')
# (1196280, 'Luca', 'Giacomini', 'Luca Giacomini', 'Italy')
# (1235448, 'Hugo', 'Gaston', 'Hugo Gaston', 'France')
# (300234, 'Marco', 'Bortolotti', 'Marco Bortolotti', 'Italy')
# (1528464, 'Jiri', 'Lehecka', 'Jiri Lehecka', 'Czech Republic')
# (692790, 'Evgenii', 'Tiurnev', 'Evgenii Tiurnev', 'Russia')
# (606570, 'Jordi', 'Arconada', 'Jordi Arconada', 'USA')
# (917412, 'Patrik', 'Rikl', 'Patrik Rikl', 'Czech Republic')
# (1326084, 'Francisco', 'Cerundolo', 'Francisco Cerundolo', 'Argentina')
# (401256, 'Shintaro', 'Imai', 'Shintaro Imai', 'Japan')
# (1423140, 'Giulio', 'Zeppieri', 'Giulio Zeppieri', 'Italy')
# (1323234, 'Paul', 'Jubb', 'Paul Jubb', 'United Kingdom')
# (981828, 'Lukas', 'Klein', 'Lukas Klein', 'Slovakia')
# (638154, 'Lucas', 'Gerch', 'Lucas Gerch', 'Germany')
# (289362, 'Da', 'Dutra', 'Da Dutra', 'Brazil')
# (1278336, 'Sam', 'Riffice', 'Sam Riffice', 'USA')
# (142032, 'Cedrik', 'Stebe', 'Cedrik Stebe', 'Germany')
# (336534, 'Aleksandre', 'Metreveli', 'Aleksandre Metreveli', 'Georgia')
# (463746, 'Jeroen', 'Vanneste', 'Jeroen Vanneste', 'Belgium')
# (1142298, 'John', 'Mcnally', 'John Mcnally', 'USA')
# (980640, 'Fajing', 'Sun', 'Fajing Sun', 'China')
# (566934, 'Christopher', 'Heyman', 'Christopher Heyman', 'Belgium')
# (349338, 'Christopher', 'Oconnell', 'Christopher Oconnell', 'Australia')
# (383766, 'Lobato', 'Esteve', 'Lobato Esteve', 'Spain')
# (95196, 'Frederico', 'Gil', 'Frederico Gil', 'Portugal')
# (430224, 'Nicolas', 'Alvarez', 'Nicolas Alvarez', 'Peru')
# (952500, 'Alves', 'Meligeni', 'Alves Meligeni', 'Brazil')
# (1196382, 'Vit', 'Kopriva', 'Vit Kopriva', 'Czech Republic')
# (259578, 'Christian', 'Lindell', 'Christian Lindell', 'Sweden')
# (515274, 'Gonzalo', 'Villanueva', 'Gonzalo Villanueva', 'Argentina')
# (1016988, 'Tomas', 'Etcheverry', 'Tomas Etcheverry', 'Argentina')
# (102402, 'Maxime', 'Chazal', 'Maxime Chazal', 'France')
# (401484, 'Maxime', 'Hamou', 'Maxime Hamou', 'France')
# (445806, 'Matias', 'Zukas', 'Matias Zukas', 'Argentina')
# (1161876, 'Izquierdo', 'Sanchez', 'Izquierdo Sanchez', 'Spain')
# (1304796, 'Rio', 'Noguchi', 'Rio Noguchi', 'Japan')
# (547452, 'Ryan', 'Peniston', 'Ryan Peniston', 'United Kingdom')
# (353898, 'Bague', 'Toledo', 'Bague Toledo', 'Spain')
# (1552506, 'Jack', 'Draper', 'Jack Draper', 'United Kingdom')
# (313590, 'Diego', 'Hidalgo', 'Diego Hidalgo', 'Ecuador')
# (893832, 'Mathieu', 'Perchicot', 'Mathieu Perchicot', 'France')
# (261534, 'Agustin', 'Velotti', 'Agustin Velotti', 'Argentina')
# (688998, 'Alexander', 'Erler', 'Alexander Erler', 'Austria')
# (355002, 'Ronald', 'Slobodchikov', 'Ronald Slobodchikov', 'Russia')
# (1123320, 'Nicolas', 'Mejia', 'Nicolas Mejia', 'Colombia')
# (487662, 'Oscar', 'Gutierrez', 'Oscar Gutierrez', 'Brazil')
# (1151250, 'Jenson', 'Brooksby', 'Jenson Brooksby', 'USA')
# (290550, 'Sanz', 'Perez', 'Sanz Perez', 'Spain')
# (1151064, 'Dan', 'Added', 'Dan Added', 'France')
# (616914, 'Niels', 'Lootsma', 'Niels Lootsma', 'Netherlands')
# (383106, 'Nik', 'Razborsek', 'Nik Razborsek', 'Slovenia')
# (1034904, 'Aziz', 'Dougaz', 'Aziz Dougaz', 'Tunisia')
# (832356, 'Jordan', 'Correia', 'Jordan Correia', 'Brazil')
# (581166, 'Benjamin', 'Lock', 'Benjamin Lock', 'Zimbabwe')
# (1323258, 'Aidan', 'Mchugh', 'Aidan Mchugh', 'United Kingdom')
# (379500, 'Martins', 'Podzus', 'Martins Podzus', 'Latvia')
# (584214, 'Michail', 'Pervolarakis', 'Michail Pervolarakis', 'Greece')
# (596274, 'Mariano', 'Kestelboim', 'Mariano Kestelboim', 'Argentina')
# (378552, 'Nerman', 'Fatic', 'Nerman Fatic', 'Bosnia & Herzegovina')
# (464898, 'Danylo', 'Kalenichenko', 'Danylo Kalenichenko', 'Ukraine')
# (108414, 'Eduardo', 'Struvay', 'Eduardo Struvay', 'Colombia')
# (288348, 'Cheong-Eui', 'Kim', 'Cheong-Eui Kim', 'South Korea')
# (621762, 'Michael', 'Geerts', 'Michael Geerts', 'Belgium')
# (289206, 'Quentin', 'Robert', 'Quentin Robert', 'France')
# (1119288, 'Artem', 'Dubrivnyy', 'Artem Dubrivnyy', 'Russia')
# (1119786, 'Ergi', 'Kirkin', 'Ergi Kirkin', 'Turkey')
# (278238, 'Maximiliano', 'Estevez', 'Maximiliano Estevez', 'Argentina')
# (320982, 'Alessandro', 'Petrone', 'Alessandro Petrone', 'Italy')
# (486474, 'Gonzalez', 'Vivero', 'Gonzalez Vivero', 'Spain')
# (1085688, 'Rayane', 'Roumane', 'Rayane Roumane', 'France')
# (1016928, 'Genaro', 'Olivieri', 'Genaro Olivieri', 'Argentina')
# (1296936, 'Sho', 'Shimabukuro', 'Sho Shimabukuro', 'Japan')
# (1207392, 'Marko', 'Miladinovic', 'Marko Miladinovic', 'Serbia')
# (927432, 'Vladyslav', 'Orlov', 'Vladyslav Orlov', 'Ukraine')
# (635850, 'Jumpei', 'Yamasaki', 'Jumpei Yamasaki', 'Japan')
# (587874, 'Seong', 'Hong', 'Seong Hong', 'South Korea')
# (1225986, 'Yu', 'Hsu', 'Yu Hsu', 'Chinese Taipei')
# (1466532, 'Jong', 'De', 'Jong De', 'Netherlands')
# (599610, 'Nicolae', 'Frunza', 'Nicolae Frunza', 'Romania')
# (1171086, 'Yshai', 'Oliel', 'Yshai Oliel', 'Israel')
# (457590, 'Rafael', 'Matos', 'Rafael Matos', 'Brazil')
# (972876, 'Evan', 'Zhu', 'Evan Zhu', 'USA')
# (237492, 'Bruno', 'Santanna', 'Bruno Santanna', 'Brazil')
# (1655550, 'Carlos', 'Alcaraz', 'Carlos Alcaraz', 'Spain')
# (1380306, 'Filip', 'Jianu', 'Filip Jianu', 'Romania')
# (326874, 'Wilson', 'Leite', 'Wilson Leite', 'Brazil')
# (1542558, 'Daniel', 'Michalski', 'Daniel Michalski', 'Poland')
# (685194, 'Adam', 'Moundir', 'Adam Moundir', 'Morocco')
# (1235838, 'Kacper', 'Zuk', 'Kacper Zuk', 'Poland')
# (457518, 'Bogdan', 'Bobrov', 'Bogdan Bobrov', 'Russia')
# (1413468, 'Brandon', 'Nakashima', 'Brandon Nakashima', 'USA')
# (1330848, 'Sebastian', 'Baez', 'Sebastian Baez', 'Argentina')
# (689322, 'Johan', 'Nikles', 'Johan Nikles', 'Switzerland')
# (473286, 'Matija', 'Pecotic', 'Matija Pecotic', 'Croatia')
# (954144, 'Ricardo', 'Rodríguez', 'Ricardo Rodríguez', 'Venezuela')
# (1586244, 'Acosta', 'Diaz', 'Acosta Diaz', 'Argentina')
# (1493178, 'Juan', 'Cerundolo', 'Juan Cerundolo', 'Argentina')
# (363696, 'David', 'Poljak', 'David Poljak', 'Czech Republic')
# (462042, 'Marko', 'Tepavac', 'Marko Tepavac', 'Serbia')
# (679338, 'Salminen', 'Niklas', 'Salminen Niklas', 'Finland')
# (1466508, 'Alexey', 'Zakharov', 'Alexey Zakharov', 'Russia')
# (1121322, 'Nick', 'Hardt', 'Nick Hardt', 'Dominican Republic')
# (352230, 'Nick', 'Chappell', 'Nick Chappell', 'USA')
# (696294, 'Gage', 'Brymer', 'Gage Brymer', 'USA')
# (327186, 'Jorge', 'Panta', 'Jorge Panta', 'Peru')
# (593898, 'Alexandru', 'Jecan', 'Alexandru Jecan', 'Romania')
# (664254, 'David', 'Pichler', 'David Pichler', 'Austria')
# (87840, 'Yen-Hsun', 'Lu', 'Yen-Hsun Lu', 'China')
# (1615758, 'Jonas', 'Forejtek', 'Jonas Forejtek', 'Czech Republic')
# (326334, 'Blake', 'Mott', 'Blake Mott', 'Australia')
# (1215444, 'Marek', 'Gengel', 'Marek Gengel', 'Czech Republic')
# (571566, 'Strong', 'Kirchheimer', 'Strong Kirchheimer', 'USA')
# (1493088, 'Harold', 'Mayot', 'Harold Mayot', 'France')
# (137730, 'Jerzy', 'Janowicz', 'Jerzy Janowicz', 'Poland')
# (1125660, 'Aleksandar', 'Kovacevic', 'Aleksandar Kovacevic', 'USA')
# (859692, 'Gabriel', 'Petit', 'Gabriel Petit', 'France')
# (1074972, 'Thomas', 'Laurent', 'Thomas Laurent', 'France')
# (243252, 'Nikola', 'Cacic', 'Nikola Cacic', 'Serbia')
# (205596, 'Mao', 'Gong', 'Mao Gong', 'China')
# (1439286, 'Ryan', 'Nijboer', 'Ryan Nijboer', None)
# (1283886, 'Jakub', 'Paul', 'Jakub Paul', 'Switzerland')
# (1041036, 'Austin', 'Rapp', 'Austin Rapp', 'USA')
# (1597566, 'Del', 'Huertas', 'Del Huertas', 'Peru')
# (1263156, 'Bart', 'Stevens', 'Bart Stevens', None)
# (308082, 'Jr', 'Damm', 'Jr Damm', 'USA')
# (1783206, 'Toby', 'Kodat', 'Toby Kodat', 'USA')
# (1239624, 'Clement', 'Tabur', 'Clement Tabur', 'France')
# (1189350, 'Sergey', 'Fomin', 'Sergey Fomin', 'Uzbekistan')
# (981252, 'Mats', 'Hermans', 'Mats Hermans', None)
# (1409388, 'Lopez', 'Winter', 'Lopez Winter', 'Spain')
# (1235406, 'Piotr', 'Matuszewski', 'Piotr Matuszewski', 'Poland')
# (1792782, 'Shintaro', 'Mochizuki', 'Shintaro Mochizuki', 'Japan')
# (1309566, 'Fabian', 'Marozsan', 'Fabian Marozsan', 'Hungary')
# (1327278, 'Ray', 'Ho', 'Ray Ho', None)
# (352710, 'Min', 'Song', 'Min Song', 'South Korea')
# (1251996, 'Sem', 'Verbeek', 'Sem Verbeek', None)
# (353946, 'Matej', 'Sabanov', 'Matej Sabanov', None)
# (590490, 'Karol', 'Drzewiecki', 'Karol Drzewiecki', 'Poland')
# (296154, 'Scott', 'Puodziunas', 'Scott Puodziunas', 'Australia')
# (672378, 'Szymon', 'Walkow', 'Szymon Walkow', 'Poland')
# (462078, 'Gornes', 'Martos', 'Gornes Martos', 'Spain')
# (91662, 'Toshihide', 'Matsui', 'Toshihide Matsui', 'Japan')
# (311322, 'Xin', 'Gao', 'Xin Gao', 'China')
# (297300, 'Vladyslav', 'Manafov', 'Vladyslav Manafov', 'Ukraine')
# (225834, 'Federico', 'Zeballos', 'Federico Zeballos', 'Bolivia')
# (98964, 'Jonathan', 'Eysseric', 'Jonathan Eysseric', 'France')
# (291888, 'Nicolas', 'Barrientos', 'Nicolas Barrientos', 'Colombia')
# (676842, 'Jan', 'Zielinski', 'Jan Zielinski', 'Poland')
# (322566, 'N', 'Prashanth', 'N Prashanth', 'India')
# (305112, 'Timur', 'Khabibulin', 'Timur Khabibulin', 'Kazakhstan')
# (556686, 'Brandon', 'Walkin', 'Brandon Walkin', 'Australia')
# (971220, 'Del', 'Huertas', 'Del Huertas', 'Peru')
# (935172, 'Courtney', 'Lock', 'Courtney Lock', None)
# (831168, 'Runhao', 'Hua', 'Runhao Hua', 'China')
# (300900, 'Calum', 'Puttergill', 'Calum Puttergill', 'Australia')
# (749616, 'Grigoriy', 'Lomakin', 'Grigoriy Lomakin', 'Kazakhstan')
# (590706, 'Malfeito', 'Pla', 'Malfeito Pla', 'Spain')
# (1137246, 'Julian', 'Bradley', 'Julian Bradley', 'Ireland')
# (433776, 'Nicolas', 'Arreche', 'Nicolas Arreche', 'Argentina')
# (465930, 'Victor', 'Cornea', 'Victor Cornea', 'Romania')
# (1181586, 'Petr', 'Nouza', 'Petr Nouza', 'Czech Republic')
# (150138, 'Inigo', 'Cervantes', 'Inigo Cervantes', 'Spain')
# (305934, 'Alexander', 'Igoshin', 'Alexander Igoshin', 'Russia')
# (726744, 'Simon', 'Freund', 'Simon Freund', 'Sweden')
# (683346, 'Ivan', 'Liutarevich', 'Ivan Liutarevich', 'Belarus')
# (374472, 'Luke', 'Johnson', 'Luke Johnson', 'United Kingdom')
# (557082, 'George', 'Goldhoff', 'George Goldhoff', 'USA')
# (1038708, 'Anis', 'Ghorbel', 'Anis Ghorbel', 'Tunisia')
# (312828, 'Luis', 'Patino', 'Luis Patino', 'Mexico')
# (952980, 'Rhett', 'Purcell', 'Rhett Purcell', 'New Zealand')
# (337638, 'Maxime', 'Tchoutakian', 'Maxime Tchoutakian', 'France')
# (636210, 'Florian', 'Lakat', 'Florian Lakat', 'France')
# (765888, 'Francisco', 'Cabral', 'Francisco Cabral', None)
# (393648, 'Franco', 'Agamenone', 'Franco Agamenone', 'Italy')
# (1337664, 'Justin', 'Butsch', 'Justin Butsch', 'USA')
# (917196, 'Oleg', 'Prihodko', 'Oleg Prihodko', 'Ukraine')
# (291624, 'Goncalo', 'Falcao', 'Goncalo Falcao', None)
# (556014, 'Luca', 'Castelnuovo', 'Luca Castelnuovo', None)
# (298014, 'Alexander', 'Pavlioutchenkov', 'Alexander Pavlioutchenkov', 'Russia')
# (532800, 'Hawkins', 'Findel', 'Hawkins Findel', 'United Kingdom')
# (465018, 'Kai', 'Wehnelt', 'Kai Wehnelt', None)
# (543888, 'Maxim', 'Ratniuk', 'Maxim Ratniuk', 'Russia')
# (470478, 'Franco', 'Feitt', 'Franco Feitt', 'Argentina')
# (1138290, 'Glenn', 'Smits', 'Glenn Smits', None)
# (669666, 'Campos', 'Barroso', 'Campos Barroso', 'Spain')
# (857748, 'James', 'Frawley', 'James Frawley', 'Australia')
# (419472, 'Filip', 'Bergevi', 'Filip Bergevi', 'Sweden')
# (89286, 'Jaroslav', 'Pospisil', 'Jaroslav Pospisil', 'Czech Republic')
# (662802, 'Peter', 'Bothwell', 'Peter Bothwell', 'Ireland')
# (975636, 'Luca', 'Gelhardt', 'Luca Gelhardt', None)
# (605274, 'Jose', 'Bendeck', 'Jose Bendeck', 'Colombia')
# (342942, 'Sanchis', 'Jorda', 'Sanchis Jorda', 'Spain')
# (1375662, 'Timofey', 'Skatov', 'Timofey Skatov', 'Kazakhstan')
# (1242498, 'Duje', 'Ajdukovic', 'Duje Ajdukovic', 'Croatia')
# (472470, 'Elmar', 'Ejupovic', 'Elmar Ejupovic', 'Germany')
# (1304706, 'Valero', 'Gimeno', 'Valero Gimeno', 'Spain')
# (750048, 'Nuno', 'Borges', 'Nuno Borges', 'Portugal')
# (600426, 'Vitaliy', 'Sachko', 'Vitaliy Sachko', 'Ukraine')
# (1329102, 'Thiago', 'Tirante', 'Thiago Tirante', 'Argentina')
# (1698432, 'Holger', 'Rune', 'Holger Rune', 'Denmark')
# (1252956, 'Adrian', 'Andreev', 'Adrian Andreev', 'Bulgaria')
# (146856, 'Andrey', 'Kuznetsov', 'Andrey Kuznetsov', 'Russia')
# (814680, 'Lucas', 'Poullain', 'Lucas Poullain', 'France')
# (1605474, 'Kyrian', 'Jacquet', 'Kyrian Jacquet', 'France')
# (1778226, 'Dominic', 'Stricker', 'Dominic Stricker', 'Switzerland')
# (1392354, 'Emilio', 'Nava', 'Emilio Nava', 'USA')
# (1328046, 'Georgii', 'Kravchenko', 'Georgii Kravchenko', 'Ukraine')
# (1304700, 'Tiffon', 'Martin', 'Tiffon Martin', 'Spain')
# (1642092, 'Cobolli', 'Flavio', 'Cobolli Flavio', 'Italy')
# (1278354, 'Oliver', 'Crawford', 'Oliver Crawford', 'USA')
# (1726830, 'Arthur', 'Cazaux', 'Arthur Cazaux', 'France')
# (1762470, 'Zane', 'Khan', 'Zane Khan', 'USA')
# (1628238, 'De', 'Pucinelli', 'De Pucinelli', 'Brazil')
# (1112616, 'Taverna', 'Rodriguez', 'Taverna Rodriguez', 'Argentina')
# (1470672, 'Anton', 'Matusevich', 'Anton Matusevich', 'United Kingdom')
# (727080, 'Alexis', 'Gautier', 'Alexis Gautier', 'France')
# (683442, 'De', 'Moreno', 'De Moreno', 'USA')
# (1361010, 'Marvin', 'Moller', 'Marvin Moller', 'Germany')
# (1235946, 'Varona', 'Alvarez', 'Varona Alvarez', 'Spain')
# (1586076, 'Alexander', 'Shevchenko', 'Alexander Shevchenko', 'Russia')
# (1523064, 'Nicholas', 'Ionel', 'Nicholas Ionel', 'Romania')
# (1395702, 'Oleksii', 'Krutykh', 'Oleksii Krutykh', 'Ukraine')
# (1375320, 'Otto', 'Virtanen', 'Otto Virtanen', 'Finland')
# (1238988, 'Govind', 'Nanda', 'Govind Nanda', 'USA')
# (1560744, 'Dalibor', 'Svrcina', 'Dalibor Svrcina', 'Czech Republic')
# (1172028, 'Dragos', 'Madaras', 'Dragos Madaras', 'Sweden')
# (459090, 'Azorin', 'Vidal', 'Azorin Vidal', 'Spain')
# (683166, 'Antoine', 'Bellier', 'Antoine Bellier', 'Switzerland')
# (1589880, 'De', 'Pucinelli', 'De Pucinelli', 'Brazil')
# (1298940, 'Filip', 'Misolic', 'Filip Misolic', 'Austria')
# (1789494, 'Zachary', 'Svajda', 'Zachary Svajda', 'USA')
# (1424724, 'Rinky', 'Hijikata', 'Rinky Hijikata', 'Australia')
# (971256, 'Felix', 'Corwin', 'Felix Corwin', 'USA')
# (1848516, 'Luciano', 'Darderi', 'Luciano Darderi', 'Italy')
# (1797240, 'Matteo', 'Arnaldi', 'Matteo Arnaldi', 'Italy')
# (1707114, 'Eric', 'Vanshelboim', 'Eric Vanshelboim', 'Ukraine')
# (1735410, 'Luca', 'Nardi', 'Luca Nardi', 'Italy')
# (1361640, 'Junior', 'Klier', 'Junior Klier', 'Brazil')
# (1276584, 'Da', 'Reis', 'Da Reis', 'Brazil')
# (1137288, 'Tiago', 'Cacao', 'Tiago Cacao', 'Portugal')
# (944376, 'Mats', 'Rosenkranz', 'Mats Rosenkranz', 'Germany')
# (678858, 'Mateus', 'Alves', 'Mateus Alves', 'Brazil')
# (1463562, 'Titouan', 'Droguet', 'Titouan Droguet', 'France')
# (339474, 'Pawel', 'Cias', 'Pawel Cias', 'Poland')
# (1207500, 'Yan', 'Bondarevskiy', 'Yan Bondarevskiy', 'Russia')
# (981312, 'Facundo', 'Juarez', 'Facundo Juarez', 'Argentina')
# (1181544, 'Jover', 'Sanchez', 'Jover Sanchez', 'Spain')
# (864624, 'Alexander', 'Weis', 'Alexander Weis', 'Italy')
# (1402212, 'Gauthier', 'Onclin', 'Gauthier Onclin', 'Belgium')
# (395964, 'Juan', 'Paz', 'Juan Paz', 'Argentina')
# (1532532, 'Francisco', 'Comesana', 'Francisco Comesana', 'Argentina')
# (1262988, 'Vasil', 'Kirkov', 'Vasil Kirkov', 'USA')
# (1398768, 'Dane', 'Sweeny', 'Dane Sweeny', 'Australia')
# (312426, 'Naoki', 'Nakagawa', 'Naoki Nakagawa', 'Japan')
# (1450320, 'Yanki', 'Erel', 'Yanki Erel', 'Turkey')
# (1123392, 'Christian', 'Langmo', 'Christian Langmo', 'USA')
# (1148652, 'Damien', 'Wenger', 'Damien Wenger', 'Switzerland')
# (1815504, 'Gustavo', 'Heide', 'Gustavo Heide', 'Brazil')
# (1771080, 'Alibek', 'Kachmazov', 'Alibek Kachmazov', 'Russia')
# (492954, 'Igor', 'Marcondes', 'Igor Marcondes', 'Brazil')
# (671034, 'Billy', 'Harris', 'Billy Harris', 'United Kingdom')
# (1894656, 'Juan', 'Torres', 'Juan Torres', 'Argentina')
# (1307310, 'Gabriel', 'Decamps', 'Gabriel Decamps', 'Brazil')
# (2010624, 'Assche', 'Van', 'Assche Van', 'France')
# (953484, 'Valentin', 'Vacherot', 'Valentin Vacherot', 'Monaco')
# (981180, 'Edoardo', 'Lavagno', 'Edoardo Lavagno', 'Italy')
# (1249362, 'Henri', 'Squire', 'Henri Squire', 'Germany')
# (1276866, 'Stuart', 'Parker', 'Stuart Parker', 'United Kingdom')
# (922968, 'Moez', 'Echargui', 'Moez Echargui', 'Tunisia')
# (1337760, 'Alastair', 'Gray', 'Alastair Gray', 'United Kingdom')
# (1137252, 'Hady', 'Habib', 'Hady Habib', 'Lebanon')
# (1228668, 'Mateus', 'Alves', 'Mateus Alves', 'Brazil')
# (486282, 'Jonathan', 'Mridha', 'Jonathan Mridha', 'Sweden')
# (1360872, 'Luca', 'Potenza', 'Luca Potenza', 'Italy')
# (296514, 'Li', 'Tu', 'Li Tu', 'Australia')
# (2133168, 'Ouden', 'Den', 'Ouden Den', 'Netherlands')
# (1392366, 'Keegan', 'Smith', 'Keegan Smith', 'USA')
# (1505154, 'Canas', 'Moro', 'Canas Moro', 'Spain')
# (2031012, 'Arthur', 'Fils', 'Arthur Fils', 'France')
# (1553460, 'Francesco', 'Passaro', 'Francesco Passaro', 'Italy')
# (1392282, 'Omni', 'Kumar', 'Omni Kumar', 'USA')
# (2093130, 'Juncheng', 'Shang', 'Juncheng Shang', 'China')
# (1788354, 'Felix', 'Gill', 'Felix Gill', 'United Kingdom')
# (1396692, 'Beibit', 'Zhukayev', 'Beibit Zhukayev', 'Kazakhstan')
# (2036712, 'Lukas', 'Neumayer', 'Lukas Neumayer', 'Austria')
# (1133676, 'Andrey', 'Chepelev', 'Andrey Chepelev', 'Russia')
# (1930740, 'Leandro', 'Riedi', 'Leandro Riedi', 'Switzerland')
# (1594860, 'Lavallen', 'Lingua', 'Lavallen Lingua', 'Argentina')
# (1181532, 'Cezar', 'Cretu', 'Cezar Cretu', 'Romania')
# (1207476, 'Montagud', 'Lopez', 'Montagud Lopez', 'Spain')
# (1766034, 'Mattia', 'Bellucci', 'Mattia Bellucci', 'Italy')
# (1213098, 'Charles', 'Broom', 'Charles Broom', 'United Kingdom')
# (1956678, 'Matteo', 'Gigante', 'Matteo Gigante', 'Italy')
# (1928436, 'Hamad', 'Mededovic', 'Hamad Mededovic', 'Serbia')
# (492810, 'Velasco', 'Dellien', 'Velasco Dellien', 'Bolivia')
# (997200, 'Timo', 'Stodder', 'Timo Stodder', 'Germany')
# (1723098, 'Roman', 'Burruchaga', 'Roman Burruchaga', 'Argentina')
# (1204674, 'Ugo', 'Blanchet', 'Ugo Blanchet', 'France')
# (1304688, 'Pujolras', 'Marti', 'Pujolras Marti', 'Spain')
# (475710, 'Gergely', 'Madarasz', 'Gergely Madarasz', 'Hungary')
# (1950858, 'Ruggeri', 'Vincent', 'Ruggeri Vincent', 'Italy')
# (99396, 'Jose', 'Pereira', 'Jose Pereira', 'Brazil')
# (1532706, 'Valentin', 'Royer', 'Valentin Royer', 'France')
# (1704588, 'Dias', 'Boscardin', 'Dias Boscardin', 'Brazil')
# (1652838, 'Tristan', 'Schoolkate', 'Tristan Schoolkate', 'Australia')
# (1930752, 'Jones', 'Pinnington', 'Jones Pinnington', 'United Kingdom')
# (1566114, 'Francesco', 'Maestrelli', 'Francesco Maestrelli', 'Italy')
# (1718964, 'Martin', 'Krumich', 'Martin Krumich', 'Czech Republic')
# (870660, 'Remy', 'Bertola', 'Remy Bertola', 'Switzerland')
# (1652814, 'Andrew', 'Paulson', 'Andrew Paulson', 'Czech Republic')
# (748260, 'Daniel', 'Cukierman', 'Daniel Cukierman', 'Israel')
# (2312922, 'Ben', 'Shelton', 'Ben Shelton', 'USA')
# (476814, 'Omar', 'Jasika', 'Omar Jasika', 'Australia')
# (630138, 'Kyle', 'Seelig', 'Kyle Seelig', 'USA')
# (832284, 'Giovanni', 'Oradini', 'Giovanni Oradini', 'Italy')
# (1586160, 'Ruiz', 'Llamas', 'Ruiz Llamas', 'Spain')
# (1628346, 'Mariano', 'Navone', 'Mariano Navone', 'Argentina')
# (1525374, 'Bu', 'Yunchaokete', 'Bu Yunchaokete', 'China')
# (108564, 'Daniel', 'Cox', 'Daniel Cox', 'United Kingdom')
# (1389732, 'Clement', 'Chidekh', 'Clement Chidekh', 'France')
# (1278468, 'Mathys', 'Erhard', 'Mathys Erhard', 'France')
# (1642086, 'Terence', 'Atmane', 'Terence Atmane', 'France')
# (1389384, 'Stefan', 'Palosi', 'Stefan Palosi', 'Romania')
# (2036724, 'James', 'Mccabe', 'James Mccabe', 'Australia')
# (2133162, 'Raphael', 'Collignon', 'Raphael Collignon', 'Belgium')
# (1844358, 'Daniel', 'Rincon', 'Daniel Rincon', 'Spain')
# (1747590, 'Dominik', 'Palan', 'Dominik Palan', 'Czech Republic')
# (2044458, 'Wayenburg', 'Gueymard', 'Wayenburg Gueymard', 'France')
# (1854438, 'Jerome', 'Kym', 'Jerome Kym', 'Switzerland')
# (1734888, 'Perricard', 'Mpetshi', 'Perricard Mpetshi', 'France')
# (1433214, 'Oleksandr', 'Ovcharenko', 'Oleksandr Ovcharenko', 'Ukraine')
# (1983240, 'Henry', 'Patten', 'Henry Patten', 'United Kingdom')
# (1133634, 'Quentin', 'Folliot', 'Quentin Folliot', 'France')
# (1734906, 'Peter', 'Fajta', 'Peter Fajta', 'Hungary')
# (1750572, 'Gianmarco', 'Ferrari', 'Gianmarco Ferrari', 'Italy')
# (2092218, 'Marko', 'Topo', 'Marko Topo', 'Germany')
# (1553874, 'Hernandez', 'Alex', 'Hernandez Alex', 'Mexico')
# (1341090, 'Liam', 'Draxl', 'Liam Draxl', 'Canada')
# (1199190, 'Ezekiel', 'Clark', 'Ezekiel Clark', 'USA')
# (1263258, 'Jurgen', 'Briand', 'Jurgen Briand', 'France')
# (1911444, 'Timo', 'Legout', 'Timo Legout', 'France')
# (1239456, 'Jaimee', 'Angele', 'Jaimee Angele', 'France')
# (1782846, 'Valerio', 'Aboian', 'Valerio Aboian', 'Argentina')
# (1680918, 'Gabriel', 'Diallo', 'Gabriel Diallo', 'Canada')
# (1328310, 'Juan', 'Otegui', 'Juan Otegui', 'Argentina')
# (1663086, 'Max', 'Houkes', 'Max Houkes', 'Netherlands')
# (2033352, 'Aguilar', 'Merida', 'Aguilar Merida', 'Spain')
# (2005770, 'Ethan', 'Quinn', 'Ethan Quinn', 'USA')
# (1844310, 'Abedallah', 'Shelbayh', 'Abedallah Shelbayh', 'Jordan')
# (2057022, 'Maks', 'Kasnikowski', 'Maks Kasnikowski', 'Poland')
# (1016964, 'Leonardo', 'Aboian', 'Leonardo Aboian', 'Argentina')
# (2303958, 'Mark', 'Lajal', 'Mark Lajal', 'Estonia')
# (2044464, 'Robin', 'Bertrand', 'Robin Bertrand', 'France')
# (1540836, 'Cannon', 'Kingsley', 'Cannon Kingsley', 'USA')
# (1344240, 'Federico', 'Arnaboldi', 'Federico Arnaboldi', 'Italy')
# (644910, 'Ignacio', 'Monzon', 'Ignacio Monzon', 'Argentina')
# (388764, 'Daniele', 'Capecchi', 'Daniele Capecchi', 'Italy')
# (1245462, 'Adam', 'Walton', 'Adam Walton', 'Australia')
# (916368, 'Karl', 'Friberg', 'Karl Friberg', 'Sweden')
# (1931700, 'Eliakim', 'Coulibaly', 'Eliakim Coulibaly', 'Ivory Coast')
# (330414, 'Jules', 'Marie', 'Jules Marie', 'France')
# (1385418, 'Rimpei', 'Kawakami', 'Rimpei Kawakami', 'Japan')
# (1801770, 'Max', 'Rehberg', 'Max Rehberg', 'Germany')
# (2264190, 'Marcello', 'Serafini', 'Marcello Serafini', 'Italy')
# (1196940, 'Eduardo', 'Ribeiro', 'Eduardo Ribeiro', 'Brazil')
# (1735050, 'Giles', 'Hussey', 'Giles Hussey', 'United Kingdom')
# (2057862, 'Mili', 'Poljicak', 'Mili Poljicak', 'Croatia')
# (1930746, 'Arthur', 'Fery', 'Arthur Fery', 'United Kingdom')
# (1796898, 'Philip', 'Sekulic', 'Philip Sekulic', 'Australia')

# %%
import http.client

conn = http.client.HTTPSConnection("tennis-live-data.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "57fcc65541msh4841dc21fef332dp1f0486jsn7e8c59408325",
    'X-RapidAPI-Host': "tennis-live-data.p.rapidapi.com"
    }

conn.request("GET", "/matches-by-date/2022-10-26", headers=headers)

res = conn.getresponse()
data_match = res.read()

print(data_match.decode("utf-8"))
# Out:
# {"meta":{"title":"Live Tennis API - All Matches on 2022-10-26","description":"List of matches for given date with results accross all tournaments","fields":{"tournament":{"id":"Integer - unique tournament_id for use querying other endpoints","name":"String","city":"String","country":"String","surface":"String - tournament surface type i.e Clay, Hard Indoor, Hard Outdoor, Grass","code":"String - tour_code","start_date":"Date - YYYY-MM-DD","end_date":"Date - YYYY-MM-DD","season":"Integer - tour_season_id"},"match":{"id":"Integer","status":"String - notstarted, finished, inprogress","title":"String - match title","home_id":"Integer","home_player":"String - abbreviated home player name","away_id":"Integer","away_player":"String - abbreviated away player name","date":"Timestamp - ISO 8061 - always UTC","court":"String - can be blank","round_id":"Integer","round_name":"String"},"home_or_away":{"first_name":"String","last_name":"String","full_name":"String","country":"String - full country name","ranking":"Integer - 0=unranked"},"result":{"winner_id":"Integer - player_id of winning player","result_description":"String - Ended=normal result, Walkover=losing player didn't contest match, Retired=losing player retired before match finished","home_sets":"String - home player sets won","away_sets":"String - away player sets won","home_set1":"String - home player games won during set 1","away_set1":"String - away player games won during set 1","home_set2":"String - home player games won during set 2","away_set2":"String - away player games won during set 2","home_set3":"String - home player games won during set 3 - will not be set if match didn't go to 3 sets","away_set3":"String - away player games won during set 3 - will not be set if match didn't go to 3 sets","home_set4":"String - home player games won during set 4 - will not be set if match didn't go to 4 sets","away_set4":"String - away player games won during set 4 - will not be set if match didn't go to 4 sets","home_set5":"String - home player games won during set 5 - will not be set if match didn't go to 5 sets","away_set5":"String - away player games won during set 5 - will not be set if match didn't go to 5 sets","home_tb1":"Integer - home player tie break score set 1 - will not be set if there was no tie breaker in set 1","away_tb1":"Integer - away player tie break score set 1 - will not be set if there was no tie breaker in set 1","home_tb2":"Integer - home player tie break score set 2 - will not be set if there was no tie breaker in set 2","away_tb2":"Integer - away player tie break score set 2 - will not be set if there was no tie breaker in set 2","home_tb3":"Integer - home player tie break score set 3 - will not be set if there was no tie breaker in set 3","away_tb3":"Integer - away player tie break score set 3 - will not be set if there was no tie breaker in set 3","home_tb4":"Integer - home player tie break score set 4 - will not be set if there was no tie breaker in set 4","away_tb4":"Integer - away player tie break score set 4 - will not be set if there was no tie breaker in set 4","home_tb5":"Integer - home player tie break score set 5 - will not be set if there was no tie breaker in set 5","away_tb5":"Integer - away player tie break score set 5 - will not be set if there was no tie breaker in set 5"}}},"results":[{"tournament":{"id":1582,"name":"Erste Bank Open","city":"Vienna","country":"Austria","surface":"Indoor Hard","code":"ATP","start_date":"2022-10-24","end_date":"2022-10-30","season":2022,"country_code":"AUT"},"matches":[{"id":30547,"status":"notstarted","title":"Gar\u00edn C. - Sinner J.","home_id":387432,"home_player":"Gar\u00edn C.","away_id":1239432,"away_player":"Sinner J.","date":"2022-10-26T12:00:00+00:00","court":"Center Court","round_id":31,"round_name":"Round of 32","home":{"first_name":"Cristian","last_name":"Garin","full_name":"Cristian Garin","country":"Chile","ranking":86},"away":{"first_name":"Jannik","last_name":"Sinner","full_name":"Jannik Si ...

# %%
from datetime import datetime
datetime.today().strftime('%Y-%m-%d')
# Out:
# '2022-10-26'

# %%
import http.client

conn = http.client.HTTPSConnection("tennis-live-data.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "57fcc65541msh4841dc21fef332dp1f0486jsn7e8c59408325",
    'X-RapidAPI-Host': "tennis-live-data.p.rapidapi.com"
    }

req_str = "/matches-by-date/" + datetime.today().strftime('%Y-%m-%d')

conn.request("GET", req_str , headers=headers)

res = conn.getresponse()
data_match_example = res.read()

print(data_match_example.decode("utf-8"))
# Out:
# {"meta":{"title":"Live Tennis API - All Matches on 2022-10-26","description":"List of matches for given date with results accross all tournaments","fields":{"tournament":{"id":"Integer - unique tournament_id for use querying other endpoints","name":"String","city":"String","country":"String","surface":"String - tournament surface type i.e Clay, Hard Indoor, Hard Outdoor, Grass","code":"String - tour_code","start_date":"Date - YYYY-MM-DD","end_date":"Date - YYYY-MM-DD","season":"Integer - tour_season_id"},"match":{"id":"Integer","status":"String - notstarted, finished, inprogress","title":"String - match title","home_id":"Integer","home_player":"String - abbreviated home player name","away_id":"Integer","away_player":"String - abbreviated away player name","date":"Timestamp - ISO 8061 - always UTC","court":"String - can be blank","round_id":"Integer","round_name":"String"},"home_or_away":{"first_name":"String","last_name":"String","full_name":"String","country":"String - full country name","ranking":"Integer - 0=unranked"},"result":{"winner_id":"Integer - player_id of winning player","result_description":"String - Ended=normal result, Walkover=losing player didn't contest match, Retired=losing player retired before match finished","home_sets":"String - home player sets won","away_sets":"String - away player sets won","home_set1":"String - home player games won during set 1","away_set1":"String - away player games won during set 1","home_set2":"String - home player games won during set 2","away_set2":"String - away player games won during set 2","home_set3":"String - home player games won during set 3 - will not be set if match didn't go to 3 sets","away_set3":"String - away player games won during set 3 - will not be set if match didn't go to 3 sets","home_set4":"String - home player games won during set 4 - will not be set if match didn't go to 4 sets","away_set4":"String - away player games won during set 4 - will not be set if match didn't go to 4 sets","home_set5":"String - home player games won during set 5 - will not be set if match didn't go to 5 sets","away_set5":"String - away player games won during set 5 - will not be set if match didn't go to 5 sets","home_tb1":"Integer - home player tie break score set 1 - will not be set if there was no tie breaker in set 1","away_tb1":"Integer - away player tie break score set 1 - will not be set if there was no tie breaker in set 1","home_tb2":"Integer - home player tie break score set 2 - will not be set if there was no tie breaker in set 2","away_tb2":"Integer - away player tie break score set 2 - will not be set if there was no tie breaker in set 2","home_tb3":"Integer - home player tie break score set 3 - will not be set if there was no tie breaker in set 3","away_tb3":"Integer - away player tie break score set 3 - will not be set if there was no tie breaker in set 3","home_tb4":"Integer - home player tie break score set 4 - will not be set if there was no tie breaker in set 4","away_tb4":"Integer - away player tie break score set 4 - will not be set if there was no tie breaker in set 4","home_tb5":"Integer - home player tie break score set 5 - will not be set if there was no tie breaker in set 5","away_tb5":"Integer - away player tie break score set 5 - will not be set if there was no tie breaker in set 5"}}},"results":[{"tournament":{"id":1582,"name":"Erste Bank Open","city":"Vienna","country":"Austria","surface":"Indoor Hard","code":"ATP","start_date":"2022-10-24","end_date":"2022-10-30","season":2022,"country_code":"AUT"},"matches":[{"id":30547,"status":"finished","title":"Gar\u00edn C. - Sinner J.","home_id":387432,"home_player":"Gar\u00edn C.","away_id":1239432,"away_player":"Sinner J.","date":"2022-10-26T12:00:00+00:00","court":"Center Court","round_id":31,"round_name":"Round of 32","home":{"first_name":"Cristian","last_name":"Garin","full_name":"Cristian Garin","country":"Chile","ranking":86},"away":{"first_name":"Jannik","last_name":"Sinner","full_name":"Jannik Sinn ...

# %%
import json
dictDataMatch = json.loads(data_match_example.decode("utf-8"))

print(dictDataMatch)
# Out:
# {'meta': {'title': 'Live Tennis API - All Matches on 2022-10-26', 'description': 'List of matches for given date with results accross all tournaments', 'fields': {'tournament': {'id': 'Integer - unique tournament_id for use querying other endpoints', 'name': 'String', 'city': 'String', 'country': 'String', 'surface': 'String - tournament surface type i.e Clay, Hard Indoor, Hard Outdoor, Grass', 'code': 'String - tour_code', 'start_date': 'Date - YYYY-MM-DD', 'end_date': 'Date - YYYY-MM-DD', 'season': 'Integer - tour_season_id'}, 'match': {'id': 'Integer', 'status': 'String - notstarted, finished, inprogress', 'title': 'String - match title', 'home_id': 'Integer', 'home_player': 'String - abbreviated home player name', 'away_id': 'Integer', 'away_player': 'String - abbreviated away player name', 'date': 'Timestamp - ISO 8061 - always UTC', 'court': 'String - can be blank', 'round_id': 'Integer', 'round_name': 'String'}, 'home_or_away': {'first_name': 'String', 'last_name': 'String', 'full_name': 'String', 'country': 'String - full country name', 'ranking': 'Integer - 0=unranked'}, 'result': {'winner_id': 'Integer - player_id of winning player', 'result_description': "String - Ended=normal result, Walkover=losing player didn't contest match, Retired=losing player retired before match finished", 'home_sets': 'String - home player sets won', 'away_sets': 'String - away player sets won', 'home_set1': 'String - home player games won during set 1', 'away_set1': 'String - away player games won during set 1', 'home_set2': 'String - home player games won during set 2', 'away_set2': 'String - away player games won during set 2', 'home_set3': "String - home player games won during set 3 - will not be set if match didn't go to 3 sets", 'away_set3': "String - away player games won during set 3 - will not be set if match didn't go to 3 sets", 'home_set4': "String - home player games won during set 4 - will not be set if match didn't go to 4 sets", 'away_set4': "String - away player games won during set 4 - will not be set if match didn't go to 4 sets", 'home_set5': "String - home player games won during set 5 - will not be set if match didn't go to 5 sets", 'away_set5': "String - away player games won during set 5 - will not be set if match didn't go to 5 sets", 'home_tb1': 'Integer - home player tie break score set 1 - will not be set if there was no tie breaker in set 1', 'away_tb1': 'Integer - away player tie break score set 1 - will not be set if there was no tie breaker in set 1', 'home_tb2': 'Integer - home player tie break score set 2 - will not be set if there was no tie breaker in set 2', 'away_tb2': 'Integer - away player tie break score set 2 - will not be set if there was no tie breaker in set 2', 'home_tb3': 'Integer - home player tie break score set 3 - will not be set if there was no tie breaker in set 3', 'away_tb3': 'Integer - away player tie break score set 3 - will not be set if there was no tie breaker in set 3', 'home_tb4': 'Integer - home player tie break score set 4 - will not be set if there was no tie breaker in set 4', 'away_tb4': 'Integer - away player tie break score set 4 - will not be set if there was no tie breaker in set 4', 'home_tb5': 'Integer - home player tie break score set 5 - will not be set if there was no tie breaker in set 5', 'away_tb5': 'Integer - away player tie break score set 5 - will not be set if there was no tie breaker in set 5'}}}, 'results': [{'tournament': {'id': 1582, 'name': 'Erste Bank Open', 'city': 'Vienna', 'country': 'Austria', 'surface': 'Indoor Hard', 'code': 'ATP', 'start_date': '2022-10-24', 'end_date': '2022-10-30', 'season': 2022, 'country_code': 'AUT'}, 'matches': [{'id': 30547, 'status': 'finished', 'title': 'Garín C. - Sinner J.', 'home_id': 387432, 'home_player': 'Garín C.', 'away_id': 1239432, 'away_player': 'Sinner J.', 'date': '2022-10-26T12:00:00+00:00', 'court': 'Center Court', 'round_id': 31, 'round_name': 'Round of 32', 'home': {'first_name': 'Cristian', 'last_name ...

# %%
DataMatchList = []
for j in range(0, len(dictDataMatch['results'])):
    for i in dictDataMatch['results'][j]['matches']:
        DataMatchList.append((i['id'], i['title'], i['home_id'], i['away_id'], i['date'], dictDataMatch['results'][j]['tournament']['name']+ ' , ' +i['round_name']))
print(DataMatchList)
# Out:
# [(30547, 'Garín C. - Sinner J.', 387432, 1239432, '2022-10-26T12:00:00+00:00', 'Erste Bank Open , Round of 32'), (30548, 'Griekspoor T. - Giron M.', 734220, 254286, '2022-10-26T11:00:00+00:00', 'Erste Bank Open , Round of 32'), (30550, 'Medvedev D. - Basilashvili N.', 981036, 157236, '2022-10-26T15:30:00+00:00', 'Erste Bank Open , Round of 32'), (30551, 'Novak D. - Tsitsipas S.', 355836, 734208, '2022-10-26T13:30:00+00:00', 'Erste Bank Open , Round of 32'), (30582, 'Evans D. - Khachanov K.', 98262, 540492, '2022-10-26T12:35:00+00:00', 'Erste Bank Open , Round of 16'), (30583, 'Shapovalov D. - Fritz T.', 707508, 816264, '2022-10-26T16:50:00+00:00', 'Erste Bank Open , Round of 16'), (30568, 'Auger-Aliassime F. - Hüsler M.', 1152090, 870684, '2022-10-26T15:30:00+00:00', 'Swiss Indoors Basel , Round of 32'), (30571, 'Brooksby J. - Humbert U.', 1151250, 1112340, '2022-10-26T11:00:00+00:00', 'Swiss Indoors Basel , Round of 32'), (30574, 'de Minaur A. - Rune H.', 1207446, 1698432, '2022-10-26T11:00:00+00:00', 'Swiss Indoors Basel , Round of 32'), (30577, 'Ramos-Viñolas A. - Musetti L.', 100944, 1566102, '2022-10-26T13:00:00+00:00', 'Swiss Indoors Basel , Round of 32'), (30585, 'Molcan A. - Rinderknech A.', 870792, 381648, '2022-10-26T16:30:00+00:00', 'Swiss Indoors Basel , Round of 16'), (30587, 'Alcaraz C. - Van De Zandschulp B.', 1655550, 614046, '2022-10-26T17:10:00+00:00', 'Swiss Indoors Basel , Round of 16'), (30588, 'Stricker D. - Carreño Busta P.', 1778226, 244812, '2022-10-26T18:30:00+00:00', 'Swiss Indoors Basel , Round of 16')]

# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
import pandas as pd
column_names=["id","match_name","first_player_id", "second_player_id", "match_date", "match_desc"]
df=pd.DataFrame(DataMatchList,columns=column_names)
print(df.head)
# Out:
# <bound method NDFrame.head of        id                         match_name  first_player_id  \
# 0   30547               Garín C. - Sinner J.           387432
# 1   30548           Griekspoor T. - Giron M.           734220
# 2   30550      Medvedev D. - Basilashvili N.           981036
# 3   30551            Novak D. - Tsitsipas S.           355836
# 4   30582            Evans D. - Khachanov K.            98262
# 5   30583           Shapovalov D. - Fritz T.           707508
# 6   30568     Auger-Aliassime F. - Hüsler M.          1152090
# 7   30571           Brooksby J. - Humbert U.          1151250
# 8   30574             de Minaur A. - Rune H.          1207446
# 9   30577      Ramos-Viñolas A. - Musetti L.           100944
# 10  30585         Molcan A. - Rinderknech A.           870792
# 11  30587  Alcaraz C. - Van De Zandschulp B.          1655550
# 12  30588     Stricker D. - Carreño Busta P.          1778226
#
#     second_player_id                 match_date  \
# 0            1239432  2022-10-26T12:00:00+00:00
# 1             254286  2022-10-26T11:00:00+00:00
# 2             157236  2022-10-26T15:30:00+00:00
# 3             734208  2022-10-26T13:30:00+00:00
# 4             540492  2022-10-26T12:35:00+00:00
# 5             816264  2022-10-26T16:50:00+00:00
# 6             870684  2022-10-26T15:30:00+00:00
# 7            1112340  2022-10-26T11:00:00+00:00
# 8            1698432  2022-10-26T11:00:00+00:00
# 9            1566102  2022-10-26T13:00:00+00:00
# 10            381648  2022-10-26T16:30:00+00:00
# 11            614046  2022-10-26T17:10:00+00:00
# 12            244812  2022-10-26T18:30:00+00:00
#
#                            match_desc
# 0       Erste Bank Open , Round of 32
# 1       Erste Bank Open , Round of 32
# 2       Erste Bank Open , Round of 32
# 3       Erste Bank Open , Round of 32
# 4       Erste Bank Open , Round of 16
# 5       Erste Bank Open , Round of 16
# 6   Swiss Indoors Basel , Round of 32
# 7   Swiss Indoors Basel , Round of 32
# 8   Swiss Indoors Basel , Round of 32
# 9   Swiss Indoors Basel , Round of 32
# 10  Swiss Indoors Basel , Round of 16
# 11  Swiss Indoors Basel , Round of 16
# 12  Swiss Indoors Basel , Round of 16  >

# %%
import cx_Oracle as orcCon
from cx_Oracle import DatabaseError
try:
    conn = orcCon.connect(user="system", password="ADMIN",
                               dsn="192.168.56.1:1521/xe",
                               encoding="UTF-8")
    if conn:
        print("cx_Oracle version:", orcCon.version)
        print("Database version:", conn.version)
        print("Client version:", orcCon.clientversion())
        
        # Now execute the sqlquery 
        cursor = conn.cursor()
        print("You're connected.................")
        
        # Drop table if exists
        print('Droping raw_players_from_live_api table if exists............')
        cursor.execute("BEGIN EXECUTE IMMEDIATE 'DROP TABLE raw_matches_from_live_api'; EXCEPTION WHEN OTHERS THEN NULL; END;")
        
        print('Creating table raw_players_from_live_api............')
        cursor.execute("CREATE TABLE raw_matches_from_live_api (id number, match_name varchar(500), first_player_id number, second_player_id number, match_date varchar(500),match_desc varchar(500))")
        print("raw_players_from_live_api table is created..............")
except DatabaseError as e:
    err, = e.args
    print("Oracle-Error-Code:", err.code)
    print("Oracle-Error-Message:", err.message)
finally:
    cursor.close()
    conn.close()
# Out:
# cx_Oracle version: 8.3.0
# Database version: 21.3.0.0.0
# Client version: (21, 3, 0, 0, 0)
# You're connected.................
# Droping raw_players_from_live_api table if exists............
# Creating table raw_players_from_live_api............
# raw_players_from_live_api table is created..............

# %%
import cx_Oracle as orcCon
from cx_Oracle import DatabaseError
try:
    #orcCon.connect('username/password@localhost')
    conn = orcCon.connect(user="system", password="ADMIN",
                               dsn="192.168.56.1:1521/xe",
                               encoding="UTF-8")
    if conn:
        print("cx_Oracle version:", orcCon.version)
        print("Database version:", conn.version)
        print("Client version:", orcCon.clientversion())
        cursor = conn.cursor()
        print("You're connected: ")
        print('Inserting data into table....')
        for i,row in df.iterrows():
            sql = "INSERT INTO raw_matches_from_live_api(id,match_name,first_player_id,second_player_id,match_date, match_desc) VALUES(:1,:2,:3,:4,:5, :6)"
            cursor.execute(sql, tuple(row))
        # the connection is not autocommitted by default, so we must commit to save our changes
        conn.commit()
        print("Record inserted succesfully")
except DatabaseError as e:
    err, = e.args
    print("Oracle-Error-Code:", err.code)
    print("Oracle-Error-Message:", err.message)
finally:
    cursor.close()
    conn.close()
# Out:
# cx_Oracle version: 8.3.0
# Database version: 21.3.0.0.0
# Client version: (21, 3, 0, 0, 0)
# You're connected:
# Inserting data into table....
# Record inserted succesfully

# %%
import numpy as np
import pandas as pd
import os
import eli5
from eli5.sklearn import PermutationImportance
import re
import datetime
import itertools

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100
# Out:
# Using TensorFlow backend.

# %%
def data_cleaning(df, 
                  tourneys_to_include = ['Grand Slams', 'Masters', '250 or 500', 'Tour Finals', 'Davis Cup'], 
                  start_year=2000 ):
    
    #Renaming columns
    new_cols = [
    'tourney_id', 'tourney_name', 'surface', 'draw_size',
       'tourney_level', 'match_num', 'winner_id', 'winner_seed',
       'winner_entry', 'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc',
       'winner_age', 'winner_rank', 'winner_rank_points', 'loser_id',
       'loser_seed', 'loser_entry', 'loser_name', 'loser_hand', 'loser_ht',
       'loser_ioc', 'loser_age', 'loser_rank', 'loser_rank_points', 'score',
       'best_of', 'round', 'minutes', 'winner_ace', 'winner_df', 'winner_svpt', 'winner_1stIn',
       'winner_1stWon', 'winner_2ndWon', 'winner_SvGms', 'winner_bpSaved', 'winner_bpFaced', 'loser_ace',
       'loser_df', 'loser_svpt', 'loser_1stIn', 'loser_1stWon', 'loser_2ndWon', 'loser_SvGms',
       'loser_bpSaved', 'loser_bpFaced', 'W1', 'W2', 'W3', 'W4', 'W5', 'L1', 'L2',
       'L3', 'L4', 'L5', 'retirement', 'WTB1', 'LTB1', 'WTB2', 'LTB2', 'WTB3',
       'LTB3', 'WTB4', 'LTB4', 'WTB5', 'LTB5', 'tourney_start_date', 'year',
       'match_id'
    ]
    
    df.columns = new_cols
    
    #You can change what matches to include. I've chosen to exclude Futures matches and the Challenger tour
    # tourney_levels = 'Grand Slams', '250 or 500', 'Davis Cup', 'Masters', 'Challenger', 'Tour Finals', 'Futures'
    df = df[(df['tourney_level'].isin(tourneys_to_include)) &\
            (df['year'] >= start_year) & (df['surface'] == 'Hard')&\
            (~df['round'].isin(['Q1', 'Q2', 'Q3', 'Q4']))
           ]

    #Converting dates to datetime
    df.loc[:,'tourney_start_date'] = pd.to_datetime(df['tourney_start_date'])
    df.loc[:,'year'] = pd.to_datetime(df['year'])
    
    #Parsing scores
    scores = df.loc[:,'score'].str.split(' ')
    scores = scores.fillna(0)     
    loser_total_games = []
    winner_total_games = []
    
    for index, value in scores.items():
        loser_game_score = 0
        winner_game_score = 0
        try:
            if value == 0 or value == ['W/O']:            
                loser_total_games.append(loser_game_score)
                winner_total_games.append(winner_game_score)

            else:
                loser_game_score = 0
                winner_game_score = 0

                for set_ in value:                
                    try:
                        text = re.match(r"(\d)\-(\d)",set_ )
                        loser_game_score += int(text.group(2))
                        winner_game_score += int(text.group(1))
                    except:
                        pass
                loser_total_games.append(loser_game_score)
                winner_total_games.append(winner_game_score)
        except:
            print(index, value)

    df.loc[:,'winner_total_games'] = winner_total_games
    df.loc[:,'loser_total_games'] = loser_total_games
    df.loc[:,'total_games'] = df['winner_total_games'] + df['loser_total_games']
    df.loc[:,'loser_RtGms'] = df['winner_SvGms']
    df.loc[:,'winner_RtGms'] = df['loser_SvGms']
    df.loc[:,'loser_bp'] = df['winner_bpFaced']
    df.loc[:,'winner_bp'] = df['loser_bpFaced']


    df.loc[:,'loser_bpWon'] = df['winner_bpFaced'] - df['winner_bpSaved'] 
    df.loc[:,'winner_bpWon'] = df['loser_bpFaced'] - df['loser_bpSaved'] 
    
    #Imputing returns data so we can construct features
    df.loc[:,'winner_2ndIn'] = df['winner_svpt'] - df['winner_1stIn'] - df['winner_df']
    df.loc[:,'loser_2ndIn'] = df['loser_svpt'] - df['loser_1stIn'] - df['loser_df']
    df.loc[:,'loser_rtpt'] = df['winner_svpt']
    df.loc[:,'winner_rtpt'] = df['loser_svpt']
    df.loc[:,'winner_rtptWon'] = df['loser_svpt'] -  df['loser_1stWon'] - df['loser_2ndWon']
    df.loc[:,'loser_rtptWon'] = df['winner_svpt'] -  df['winner_1stWon'] - df['winner_2ndWon']
    df.loc[:,'winner_svptWon'] = df['winner_1stWon'] + df['winner_2ndWon']
    df.loc[:,'loser_svptWon'] = df['loser_1stWon'] + df['loser_2ndWon']
    df.loc[:,'winner_total_points'] = df['winner_svptWon'] + df['winner_rtptWon']
    df.loc[:,'loser_total_points'] = df['loser_svptWon'] + df['loser_rtptWon']
    df.loc[:,'total_points'] = df['winner_total_points'] + df['loser_total_points']
    
    #Dropping columns
    cols_to_drop =[
        'draw_size',
        'winner_seed',
        'winner_entry',
        'loser_seed',
        'loser_entry',
        'score',
        'W1', 'W2', 'W3', 'W4', 'W5', 'L1', 'L2',
        'L3', 'L4', 'L5', 'WTB1', 'LTB1', 'WTB2', 'LTB2', 'WTB3',
        'LTB3', 'WTB4', 'LTB4', 'WTB5', 'LTB5'
        ]
    
    df.drop(cols_to_drop, axis=1, inplace=True)
    
    #Filling nans values
    df.loc[:,'loser_rank'] = df['loser_rank'].fillna(500)
    df.loc[:,'winner_rank'] = df['winner_rank'].fillna(500)
    df = df.fillna(df.mean())
    
    return(df)

def convert_long(df):
    
    #Separating features into winner and loser so we can create rolling averages for each major tournament
    winner_cols = [col for col in df.columns if col.startswith('w')]
    loser_cols = [col for col in df.columns if col.startswith('l')]
    common_cols = [
        'tourney_id', 'tourney_name', 'surface', 'tourney_level',
       'match_num','best_of', 'round',
       'minutes','retirement', 'tourney_start_date', 'year', 'match_id',
        'total_points', 'total_games'
    ]
    
    #Will also add opponent's rank
    df_winner = df[winner_cols + common_cols + ['loser_rank']]
    df_loser = df[loser_cols + common_cols + ['winner_rank']]
    
    df_winner['won'] = 1
    df_loser['won'] = 0
    
    #Renaming columns
    df_winner.columns = [col.replace('winner','player').replace('loser', 'opponent') for col in df_winner.columns]
    df_loser.columns = df_winner.columns
    
    df_long = df_winner.append(df_loser, ignore_index=True)
    
    return(df_long)

def get_new_features(df):
    
    #Creating new features we can play around with, note that not all features may be used
    df.loc[:,'player_serve_win_ratio'] = (df['player_1stWon'] + df['player_2ndWon'])/\
    (df['player_1stIn'] + df['player_2ndIn'] + df['player_df'] )
    
    df.loc[:,'player_return_win_ratio'] = df['player_rtptWon']/df['player_rtpt']
    
    df.loc[:,'player_bp_per_game'] = df['player_bp']/df['player_RtGms']
    
    df.loc[:,'player_bp_conversion_ratio'] = df['player_bpWon']/df['player_bp']
    
    #Setting nans to zero for breakpoint conversion ratio
    df.loc[:,'player_bp_conversion_ratio'].fillna(0, inplace=True)
    
    df.loc[:,'player_game_win_ratio'] = df['player_total_games']/df['total_games']
    
    df.loc[:,'player_point_win_ratio'] = df['player_total_points']/df['total_points']
    
    #df['player_set_Win_Ratio'] = df['Player_Sets_Won']/df['Total_Sets']
    
    df.loc[:,'player_clutch_factor'] = df['player_game_win_ratio'] - df['player_point_win_ratio']
    
    df.loc[:,'player_log_rank'] = np.log(df['player_rank'])
    
    df.loc[:,'player_win_weight'] = df['won'] * np.exp(-df['opponent_rank']/100)

    #Let's try weighting some of the features by the opponent's rank
    
    #df['Player_Set_Win_Ratio_Weighted'] = df['Player_Set_Win_Ratio']*np.exp((df['Player_Rank']-df['Opponent_Rank'])/500)
    df.loc[:,'player_game_win_ratio_weighted'] = df['player_game_win_ratio']*np.exp((df['player_rank']-df['opponent_rank'])/500)
    df.loc[:,'player_point_win_ratio_weighted'] = df['player_point_win_ratio']*np.exp((df['player_rank']-df['opponent_rank'])/500)
    
    return(df)

def get_rolling_features(df, date_df, rolling_cols, last_cols, window):
    
    #This code is basically copied straight from Qile Tan's notebook
    
    df = df.sort_values(['player_name', 'tourney_name', 'tourney_start_date'], ascending=True)
    
    for index, tournament_date in enumerate(date_df.tourney_start_date):
        print(index, tournament_date)
        
        #Subsetting to tournaments at most 1 year before tournament date to reduce computation time
        df_temp = df.loc[(df['tourney_start_date']< tournament_date) & (df['tourney_start_date'] > tournament_date - datetime.timedelta(days=365))]

        #Only taking the most recent value for the feature, if specified in last_cols
        if last_cols != None:
            df_temp_last = df_temp.groupby('player_name')[last_cols].last().reset_index()

        #Taking a rolling average of the x (window_length) most recent matches before specified tournament date,
        #for features specified in rolling_cols
        df_temp = df_temp.groupby('player_name')[rolling_cols].rolling(window,1).mean().reset_index()

        #Only taking the most recent rolling average
        df_temp = df_temp.groupby('player_name').tail(1)

        df_temp = df_temp.merge(df_temp_last, on = 'player_name', how='left')

        #Adding a column telling us what tournament the rolling average is for
        if index == 0:
            df_result = df_temp
            df_result['tournament_date_index'] = tournament_date

        else:
            df_temp['tournament_date_index'] = tournament_date
            df_result = df_result.append(df_temp)
        
    
    df_result.drop('level_1', axis=1, inplace=True)
    
    return(df_result)

def merge_data(df, df_rolling_atp):
    
    df_atp = df.copy()
    #Subsetting match data to Grand Slams and Masters
    df_atp = df_atp.loc[df_atp['tourney_level'].isin(['Grand Slams', 'Masters'])]

    #Removing unnecessary columns from match data
    cols_to_keep = ['winner_name','loser_name','tourney_name','tourney_start_date', 'tourney_level']

    df_atp = df_atp[cols_to_keep]
    df1 = df_atp.copy()
    df1.columns = ['player_1','player_2','tourney_name','tourney_start_date', 'tourney_level']
    df1['player_1_win'] = 1

    df2 = df_atp.copy()
    df2.columns = ['player_2','player_1','tourney_name','tourney_start_date', 'tourney_level']
    df2['player_1_win'] = 0

    df_atp = pd.concat([df1, df2], sort=False)
    df_atp.reset_index(drop=True, inplace=True)
    

    #Joining rolling features for p1 with match data
    df_atp = df_atp.merge(df_rolling_atp, how='left',
                         left_on = ['player_1', 'tourney_start_date'],
                         right_on = ['player_name', 'tournament_date_index'],
                         validate = 'm:1')


    df_atp = df_atp.merge(df_rolling_atp, how='left',
                         left_on = ['player_2', 'tourney_start_date'],
                         right_on = ['player_name', 'tournament_date_index'],
                         validate = 'm:1',
                         suffixes=('_p1', '_p2'))
    
    return(df_atp)

def get_player_difference(df, diff_cols = None):
    
    p1_cols = [i + '_p1' for i in diff_cols] # column names for player 1 stats
    p2_cols = [i + '_p2' for i in diff_cols] # column names for player 2 stats


    # Filling missing values
    df['player_rank_p1'] = df['player_rank_p1'].fillna(500)
    df['player_log_rank_p1'] = df['player_log_rank_p1'].fillna(np.log(500))
    df[p1_cols] = df[p1_cols].fillna(-1)
    
    df['player_rank_p2'] = df['player_rank_p2'].fillna(500)
    df['player_log_rank_p2'] = df['player_log_rank_p2'].fillna(np.log(500))
    df[p2_cols] = df[p2_cols].fillna(-1)

    
    new_column_name = [i + '_diff' for i in diff_cols]

    # Take the difference
    df_p1 = df[p1_cols]
    df_p2 = df[p2_cols]
    
    df_p1.columns=new_column_name
    df_p2.columns=new_column_name
    
    df_diff = df_p1 - df_p2
    df_diff.columns = new_column_name
    
    #Dropping spare columns
    df.drop(p1_cols + p2_cols, axis=1, inplace=True)
    
    # Concat the df_diff and raw_df
    df = pd.concat([df, df_diff], axis=1)
    
    return(df)

# %%
deuce_atp = pd.read_csv('Name.csv')
deuce_atp = data_cleaning(deuce_atp, ['Grand Slams', '250 or 500', 'Davis Cup', 'Masters', 'Challenger', 'Tour Finals'])
deuce_atp_long = convert_long(deuce_atp)
# Out:
# C:\Users\AntonHarkevich\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\AntonHarkevich\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
# C:\Users\AntonHarkevich\anaconda3\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# C:\Users\AntonHarkevich\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-2-28409ea4963f>:108: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df = df.fillna(df.mean())
# <ipython-input-2-28409ea4963f>:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_winner['won'] = 1
# <ipython-input-2-28409ea4963f>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loser['won'] = 0

# %%
deuce_atp_long = get_new_features(deuce_atp_long)

# %%
# These are the tournaments we want to get the rolling average of features for, they will then be used for training
roll_dates = deuce_atp.loc[deuce_atp['tourney_level'].isin(['Grand Slams'])].groupby(['tourney_name', 'tourney_start_date'])\
.size().reset_index()[['tourney_name', 'tourney_start_date']]

# We also want to aggregate matches just before the 2020 AO
roll_dates.loc[-1] = ['Australian Open', pd.to_datetime('2020-01-20')]

last_cols = ['player_rank', 'player_log_rank']
rolling_cols = [
    'player_serve_win_ratio', 'player_return_win_ratio',
    'player_bp_per_game', 'player_bp_conversion_ratio',
    'player_game_win_ratio', 'player_point_win_ratio',
    'player_clutch_factor', 'player_win_weight',
    'player_game_win_ratio_weighted', 'player_point_win_ratio_weighted'
]

rolling_features = get_rolling_features(deuce_atp_long, roll_dates, rolling_cols, last_cols, 21  )
# Out:
# 0 2000-01-17 00:00:00
# 1 2001-01-15 00:00:00
# 2 2002-01-14 00:00:00
# 3 2003-01-13 00:00:00
# 4 2004-01-19 00:00:00
# 5 2005-01-17 00:00:00
# 6 2006-01-16 00:00:00
# 7 2007-01-15 00:00:00
# 8 2008-01-14 00:00:00
# 9 2009-01-19 00:00:00
# 10 2010-01-18 00:00:00
# 11 2011-01-17 00:00:00
# 12 2012-01-16 00:00:00
# 13 2013-01-14 00:00:00
# 14 2014-01-13 00:00:00
# 15 2015-01-19 00:00:00
# 16 2016-01-18 00:00:00
# 17 2017-01-16 00:00:00
# 18 2018-01-15 00:00:00
# 19 2019-01-14 00:00:00
# 20 2000-08-28 00:00:00
# 21 2001-08-27 00:00:00
# 22 2002-08-26 00:00:00
# 23 2003-08-25 00:00:00
# 24 2004-08-30 00:00:00
# 25 2005-08-29 00:00:00
# 26 2006-08-28 00:00:00
# 27 2007-08-27 00:00:00
# 28 2008-08-25 00:00:00
# 29 2009-08-31 00:00:00
# 30 2010-08-30 00:00:00
# 31 2011-08-29 00:00:00
# 32 2012-08-27 00:00:00
# 33 2013-08-26 00:00:00
# 34 2014-08-25 00:00:00
# 35 2015-08-31 00:00:00
# 36 2016-08-29 00:00:00
# 37 2017-08-28 00:00:00
# 38 2018-08-27 00:00:00
# 39 2019-08-26 00:00:00
# 40 2020-01-20 00:00:00

# %%
deuce_atp_features = merge_data(deuce_atp, rolling_features)

# %%
diff_cols = [
    'player_rank', 'player_log_rank',
    'player_serve_win_ratio', 'player_return_win_ratio',
    'player_bp_per_game', 'player_bp_conversion_ratio',
    'player_game_win_ratio', 'player_point_win_ratio',
    'player_clutch_factor', 'player_win_weight',
    'player_game_win_ratio_weighted', 'player_point_win_ratio_weighted'
]

deuce_atp_final = get_player_difference(deuce_atp_features, diff_cols)

# %%
def train_val_split(df_atp_final, ML_cols):
    
    df_atp_train = df_atp_final.loc[(df_atp_final.tourney_start_date<'2018-01-15') &\
                                    (df_atp_final.tourney_level.isin(['Grand Slams'])), ML_cols]
    #df_atp_val = df_atp_final.loc[df_atp_final.tourney_start_date=='2018-01-15', ML_cols]
    df_atp_val = df_atp_final.loc[('2018-01-15' <= df_atp_final.tourney_start_date) &\
                                  (df_atp_final.tourney_start_date < '2019-12-31') &\
                                  (df_atp_final.tourney_level.isin(['Grand Slams'])), ML_cols]

    X_train = df_atp_train.drop('player_1_win', axis =1)
    y_train = df_atp_train['player_1_win']
    X_val = df_atp_val.drop('player_1_win', axis =1)
    y_val = df_atp_val['player_1_win']

    return(X_train, X_val, y_train, y_val)

# %%
ML_cols = [
       'player_1_win', 'player_rank_diff', 'player_log_rank_diff',
       'player_serve_win_ratio_diff', 'player_return_win_ratio_diff',
       'player_bp_per_game_diff', 'player_bp_conversion_ratio_diff',
       'player_game_win_ratio_diff', 'player_point_win_ratio_diff',
       'player_clutch_factor_diff', 'player_win_weight_diff',
       'player_game_win_ratio_weighted_diff',
       'player_point_win_ratio_weighted_diff'
]

ML_cols_subset = ['player_log_rank_diff',
 'player_rank_diff',
 'player_serve_win_ratio_diff',
 'player_return_win_ratio_diff',
 'player_game_win_ratio_diff',
 'player_point_win_ratio_weighted_diff',
 'player_1_win']

X_train, X_val, y_train, y_val = train_val_split(deuce_atp_final, ML_cols_subset)

# %%
from xgboost import XGBClassifier
#Changing some settings to prevent xgboost from killing the kernal
#see https://stackoverflow.com/questions/51164771/python-xgboost-kernel-died
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
model = XGBClassifier(
    objective = "binary:logistic",
    n_estimators = 300,
    learning_rate = 0.02,
    max_depth = 6
)

eval_set = [(X_val, y_val)]
model.fit(X_train,
          y_train,
         eval_set = eval_set,
         eval_metric="auc",
         early_stopping_rounds = 20)
# Out:
# [0]	validation_0-auc:0.76966
# [1]	validation_0-auc:0.77419
# [2]	validation_0-auc:0.77639
# [3]	validation_0-auc:0.77479
# [4]	validation_0-auc:0.77506
# [5]	validation_0-auc:0.77539
# [6]	validation_0-auc:0.77673
# [7]	validation_0-auc:0.77678
# [8]	validation_0-auc:0.77652
# [9]	validation_0-auc:0.77671
# [10]	validation_0-auc:0.77686
# [11]	validation_0-auc:0.77709
# [12]	validation_0-auc:0.77693
# [13]	validation_0-auc:0.77716
# [14]	validation_0-auc:0.77753
# [15]	validation_0-auc:0.77750
# [16]	validation_0-auc:0.77720
# [17]	validation_0-auc:0.77725
# [18]	validation_0-auc:0.77730
# [19]	validation_0-auc:0.77723
# [20]	validation_0-auc:0.77718
# [21]	validation_0-auc:0.77693
# [22]	validation_0-auc:0.77698
# [23]	validation_0-auc:0.77658
# [24]	validation_0-auc:0.77685
# [25]	validation_0-auc:0.77669
# [26]	validation_0-auc:0.77672
# [27]	validation_0-auc:0.77690
# [28]	validation_0-auc:0.77699
# [29]	validation_0-auc:0.77719
# C:\Users\AntonHarkevich\anaconda3\lib\site-packages\xgboost\sklearn.py:861: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\AntonHarkevich\anaconda3\lib\site-packages\xgboost\sklearn.py:861: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [30]	validation_0-auc:0.77729
# [31]	validation_0-auc:0.77715
# [32]	validation_0-auc:0.77737
# [33]	validation_0-auc:0.77764
# [34]	validation_0-auc:0.77770
# [35]	validation_0-auc:0.77750
# [36]	validation_0-auc:0.77799
# [37]	validation_0-auc:0.77790
# [38]	validation_0-auc:0.77778
# [39]	validation_0-auc:0.77818
# [40]	validation_0-auc:0.77843
# [41]	validation_0-auc:0.77856
# [42]	validation_0-auc:0.77897
# [43]	validation_0-auc:0.77909
# [44]	validation_0-auc:0.77929
# [45]	validation_0-auc:0.77923
# [46]	validation_0-auc:0.77949
# [47]	validation_0-auc:0.77973
# [48]	validation_0-auc:0.77984
# [49]	validation_0-auc:0.77997
# [50]	validation_0-auc:0.78002
# [51]	validation_0-auc:0.77995
# [52]	validation_0-auc:0.77982
# [53]	validation_0-auc:0.77998
# [54]	validation_0-auc:0.78014
# [55]	validation_0-auc:0.78008
# [56]	validation_0-auc:0.78017
# [57]	validation_0-auc:0.78010
# [58]	validation_0-auc:0.78009
# [59]	validation_0-auc:0.78020
# [60]	validation_0-auc:0.78032
# [61]	validation_0-auc:0.78046
# [62]	validation_0-auc:0.78066
# [63]	validation_0-auc:0.78070
# [64]	validation_0-auc:0.78075
# [65]	validation_0-auc:0.78090
# [66]	validation_0-auc:0.78092
# [67]	validation_0-auc:0.78095
# [68]	validation_0-auc:0.78100
# [69]	validation_0-auc:0.78117
# [70]	validation_0-auc:0.78108
# [71]	validation_0-auc:0.78121
# [72]	validation_0-auc:0.78141
# [73]	validation_0-auc:0.78144
# [74]	validation_0-auc:0.78150
# [75]	validation_0-auc:0.78154
# [76]	validation_0-auc:0.78131
# [77]	validation_0-auc:0.78136
# [78]	validation_0-auc:0.78144
# [79]	validation_0-auc:0.78154
# [80]	validation_0-auc:0.78155
# [81]	validation_0-auc:0.78148
# [82]	validation_0-auc:0.78155
# [83]	validation_0-auc:0.78162
# [84]	validation_0-auc:0.78167
# [85]	validation_0-auc:0.78155
# [86]	validation_0-auc:0.78157
# [87]	validation_0-auc:0.78163
# [88]	validation_0-auc:0.78162
# [89]	validation_0-auc:0.78151
# [90]	validation_0-auc:0.78145
# [91]	validation_0-auc:0.78160
# [92]	validation_0-auc:0.78153
# [93]	validation_0-auc:0.78151
# [94]	validation_0-auc:0.78156
# [95]	validation_0-auc:0.78147
# [96]	validation_0-auc:0.78144
# [97]	validation_0-auc:0.78149
# [98]	validation_0-auc:0.78156
# [99]	validation_0-auc:0.78155
# [100]	validation_0-auc:0.78164
# [101]	validation_0-auc:0.78170
# [102]	validation_0-auc:0.78170
# [103]	validation_0-auc:0.78166
# [104]	validation_0-auc:0.78172
# [105]	validation_0-auc:0.78191
# [106]	validation_0-auc:0.78191
# [107]	validation_0-auc:0.78185
# [108]	validation_0-auc:0.78186
# [109]	validation_0-auc:0.78188
# [110]	validation_0-auc:0.78188
# [111]	validation_0-auc:0.78185
# [112]	validation_0-auc:0.78183
# [113]	validation_0-auc:0.78180
# [114]	validation_0-auc:0.78175
# [115]	validation_0-auc:0.78179
# [116]	validation_0-auc:0.78191
# [117]	validation_0-auc:0.78200
# [118]	validation_0-auc:0.78202
# [119]	validation_0-auc:0.78195
# [120]	validation_0-auc:0.78202
# [121]	validation_0-auc:0.78202
# [122]	validation_0-auc:0.78205
# [123]	validation_0-auc:0.78200
# [124]	validation_0-auc:0.78217
# [125]	validation_0-auc:0.78219
# [126]	validation_0-auc:0.78211
# [127]	validation_0-auc:0.78212
# [128]	validation_0-auc:0.78211
# [129]	validation_0-auc:0.78217
# [130]	validation_0-auc:0.78236
# [131]	validation_0-auc:0.78230
# [132]	validation_0-auc:0.78230
# [133]	validation_0-auc:0.78232
# [134]	validation_0-auc:0.78235
# [135]	validation_0-auc:0.78234
# [136]	validation_0-auc:0.78244
# [137]	validation_0-auc:0.78242
# [138]	validation_0-auc:0.78242
# [139]	validation_0-auc:0.78245
# [140]	validation_0-auc:0.78240
# [141]	validation_0-auc:0.78243
# [142]	validation_0-auc:0.78241
# [143]	validation_0-auc:0.78247
# [144]	validation_0-auc:0.78253
# [145]	validation_0-auc:0.78254
# [146]	validation_0-auc:0.78245
# [147]	validation_0-auc:0.78250
# [148]	validation_0-auc:0.78247
# [149]	validation_0-auc:0.78242
# [150]	validation_0-auc:0.78250
# [151]	validation_0-auc:0.78239
# [152]	validation_0-auc:0.78233
# [153]	validation_0-auc:0.78226
# [154]	validation_0-auc:0.78223
# [155]	validation_0-auc:0.78222
# [156]	validation_0-auc:0.78218
# [157]	validation_0-auc:0.78211
# [158]	validation_0-auc:0.78200
# [159]	validation_0-auc:0.78206
# [160]	validation_0-auc:0.78202
# [161]	validation_0-auc:0.78198
# [162]	validation_0-auc:0.78199
# [163]	validation_0-auc:0.78197
# [164]	validation_0-auc:0.78196
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.02, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=300, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
import http.client

conn = http.client.HTTPSConnection("tennis-live-data.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "57fcc65541msh4841dc21fef332dp1f0486jsn7e8c59408325",
    'X-RapidAPI-Host': "tennis-live-data.p.rapidapi.com"
    }

conn.request("GET", "/players/ATP", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"meta":{"title":"Live Tennis API - Players By Tour: ATP","description":"List of Players in Specified Tour","fields":{"id":"Integer - player_id","first_name":"String","last_name":"String","full_name":"String","country":"String"}},"results":{"players":[{"id":89304,"first_name":"Novak","last_name":"Djokovic","full_name":"Novak Djokovic","country":"Serbia"},{"id":86928,"first_name":"Rafael","last_name":"Nadal","full_name":"Rafael Nadal","country":"Spain"},{"id":342990,"first_name":"Alexander","last_name":"Zverev","full_name":"Alexander Zverev","country":"Germany"},{"id":91668,"first_name":"Potro","last_name":"Del","full_name":"Potro Del","country":"Argentina"},{"id":93378,"first_name":"Kevin","last_name":"Anderson","full_name":"Kevin Anderson","country":"South Africa"},{"id":86064,"first_name":"Roger","last_name":"Federer","full_name":"Roger Federer","country":"Switzerland"},{"id":94410,"first_name":"Kei","last_name":"Nishikori","full_name":"Kei Nishikori","country":"Japan"},{"id":262500,"first_name":"Dominic","last_name":"Thiem","full_name":"Dominic Thiem","country":"Austria"},{"id":96732,"first_name":"John","last_name":"Isner","full_name":"John Isner","country":"USA"},{"id":92334,"first_name":"Marin","last_name":"Cilic","full_name":"Marin Cilic","country":"Croatia"},{"id":540492,"first_name":"Karen","last_name":"Khachanov","full_name":"Karen Khachanov","country":"Russia"},{"id":734208,"first_name":"Stefanos","last_name":"Tsitsipas","full_name":"Stefanos Tsitsipas","country":"Greece"},{"id":387492,"first_name":"Borna","last_name":"Coric","full_name":"Borna Coric","country":"Croatia"},{"id":108678,"first_name":"Milos","last_name":"Raonic","full_name":"Milos Raonic","country":"Canada"},{"id":92616,"first_name":"Fabio","last_name":"Fognini","full_name":"Fabio Fognini","country":"Italy"},{"id":981036,"first_name":"Daniil","last_name":"Medvedev","full_name":"Daniil Medvedev","country":"Russia"},{"id":346230,"first_name":"Lucas","last_name":"Pouille","full_name":"Lucas Pouille","country":"France"},{"id":100332,"first_name":"Agut","last_name":"Bautista","full_name":"Agut Bautista","country":"Spain"},{"id":267306,"first_name":"Marco","last_name":"Cecchinato","full_name":"Marco Cecchinato","country":"Italy"},{"id":291606,"first_name":"Diego","last_name":"Schwartzman","full_name":"Diego Schwartzman","country":"Argentina"},{"id":155040,"first_name":"David","last_name":"Goffin","full_name":"David Goffin","country":"Belgium"},{"id":157236,"first_name":"Nikoloz","last_name":"Basilashvili","full_name":"Nikoloz Basilashvili","country":"Georgia"},{"id":244812,"first_name":"Busta","last_name":"Carreno","full_name":"Busta Carreno","country":"Spain"},{"id":141498,"first_name":"Grigor","last_name":"Dimitrov","full_name":"Grigor Dimitrov","country":"Bulgaria"},{"id":707508,"first_name":"Denis","last_name":"Shapovalov","full_name":"Denis Shapovalov","country":"Canada"},{"id":86940,"first_name":"Fernando","last_name":"Verdasco","full_name":"Fernando Verdasco","country":"Spain"},{"id":86496,"first_name":"Richard","last_name":"Gasquet","full_name":"Richard Gasquet","country":"France"},{"id":1207446,"first_name":"Minaur","last_name":"De","full_name":"Minaur De","country":"Australia"},{"id":392304,"first_name":"Kyle","last_name":"Edmund","full_name":"Kyle Edmund","country":"United Kingdom"},{"id":606618,"first_name":"Frances","last_name":"Tiafoe","full_name":"Frances Tiafoe","country":"USA"},{"id":88428,"first_name":"Gilles","last_name":"Simon","full_name":"Gilles Simon","country":"France"},{"id":87756,"first_name":"Philipp","last_name":"Kohlschreiber","full_name":"Philipp Kohlschreiber","country":"Germany"},{"id":89076,"first_name":"Gael","last_name":"Monfils","full_name":"Gael Monfils","country":"France"},{"id":230970,"first_name":"Steve","last_name":"Johnson","full_name":"Steve Johnson","country":"USA"},{"id":94986,"first_name":"Jeremy","last_name":"Chardy","full_name":"Jeremy Chardy","country":"France"},{"id":198702,"first_name":"John","last_name":"Mil ...

# %%
import json
dictData = json.loads(data.decode("utf-8"))

print(dictData)
# Out:
# {'meta': {'title': 'Live Tennis API - Players By Tour: ATP', 'description': 'List of Players in Specified Tour', 'fields': {'id': 'Integer - player_id', 'first_name': 'String', 'last_name': 'String', 'full_name': 'String', 'country': 'String'}}, 'results': {'players': [{'id': 89304, 'first_name': 'Novak', 'last_name': 'Djokovic', 'full_name': 'Novak Djokovic', 'country': 'Serbia'}, {'id': 86928, 'first_name': 'Rafael', 'last_name': 'Nadal', 'full_name': 'Rafael Nadal', 'country': 'Spain'}, {'id': 342990, 'first_name': 'Alexander', 'last_name': 'Zverev', 'full_name': 'Alexander Zverev', 'country': 'Germany'}, {'id': 91668, 'first_name': 'Potro', 'last_name': 'Del', 'full_name': 'Potro Del', 'country': 'Argentina'}, {'id': 93378, 'first_name': 'Kevin', 'last_name': 'Anderson', 'full_name': 'Kevin Anderson', 'country': 'South Africa'}, {'id': 86064, 'first_name': 'Roger', 'last_name': 'Federer', 'full_name': 'Roger Federer', 'country': 'Switzerland'}, {'id': 94410, 'first_name': 'Kei', 'last_name': 'Nishikori', 'full_name': 'Kei Nishikori', 'country': 'Japan'}, {'id': 262500, 'first_name': 'Dominic', 'last_name': 'Thiem', 'full_name': 'Dominic Thiem', 'country': 'Austria'}, {'id': 96732, 'first_name': 'John', 'last_name': 'Isner', 'full_name': 'John Isner', 'country': 'USA'}, {'id': 92334, 'first_name': 'Marin', 'last_name': 'Cilic', 'full_name': 'Marin Cilic', 'country': 'Croatia'}, {'id': 540492, 'first_name': 'Karen', 'last_name': 'Khachanov', 'full_name': 'Karen Khachanov', 'country': 'Russia'}, {'id': 734208, 'first_name': 'Stefanos', 'last_name': 'Tsitsipas', 'full_name': 'Stefanos Tsitsipas', 'country': 'Greece'}, {'id': 387492, 'first_name': 'Borna', 'last_name': 'Coric', 'full_name': 'Borna Coric', 'country': 'Croatia'}, {'id': 108678, 'first_name': 'Milos', 'last_name': 'Raonic', 'full_name': 'Milos Raonic', 'country': 'Canada'}, {'id': 92616, 'first_name': 'Fabio', 'last_name': 'Fognini', 'full_name': 'Fabio Fognini', 'country': 'Italy'}, {'id': 981036, 'first_name': 'Daniil', 'last_name': 'Medvedev', 'full_name': 'Daniil Medvedev', 'country': 'Russia'}, {'id': 346230, 'first_name': 'Lucas', 'last_name': 'Pouille', 'full_name': 'Lucas Pouille', 'country': 'France'}, {'id': 100332, 'first_name': 'Agut', 'last_name': 'Bautista', 'full_name': 'Agut Bautista', 'country': 'Spain'}, {'id': 267306, 'first_name': 'Marco', 'last_name': 'Cecchinato', 'full_name': 'Marco Cecchinato', 'country': 'Italy'}, {'id': 291606, 'first_name': 'Diego', 'last_name': 'Schwartzman', 'full_name': 'Diego Schwartzman', 'country': 'Argentina'}, {'id': 155040, 'first_name': 'David', 'last_name': 'Goffin', 'full_name': 'David Goffin', 'country': 'Belgium'}, {'id': 157236, 'first_name': 'Nikoloz', 'last_name': 'Basilashvili', 'full_name': 'Nikoloz Basilashvili', 'country': 'Georgia'}, {'id': 244812, 'first_name': 'Busta', 'last_name': 'Carreno', 'full_name': 'Busta Carreno', 'country': 'Spain'}, {'id': 141498, 'first_name': 'Grigor', 'last_name': 'Dimitrov', 'full_name': 'Grigor Dimitrov', 'country': 'Bulgaria'}, {'id': 707508, 'first_name': 'Denis', 'last_name': 'Shapovalov', 'full_name': 'Denis Shapovalov', 'country': 'Canada'}, {'id': 86940, 'first_name': 'Fernando', 'last_name': 'Verdasco', 'full_name': 'Fernando Verdasco', 'country': 'Spain'}, {'id': 86496, 'first_name': 'Richard', 'last_name': 'Gasquet', 'full_name': 'Richard Gasquet', 'country': 'France'}, {'id': 1207446, 'first_name': 'Minaur', 'last_name': 'De', 'full_name': 'Minaur De', 'country': 'Australia'}, {'id': 392304, 'first_name': 'Kyle', 'last_name': 'Edmund', 'full_name': 'Kyle Edmund', 'country': 'United Kingdom'}, {'id': 606618, 'first_name': 'Frances', 'last_name': 'Tiafoe', 'full_name': 'Frances Tiafoe', 'country': 'USA'}, {'id': 88428, 'first_name': 'Gilles', 'last_name': 'Simon', 'full_name': 'Gilles Simon', 'country': 'France'}, {'id': 87756, 'first_name': 'Philipp', 'last_name': 'Kohlschreiber', 'full_name': 'Philipp Kohlschreiber', 'country': 'Germany'}, {'id': 89076, 'f ...

# %%
DataList = []
for i in dictData['results']['players']:
    DataList.append(i['full_name'])
print(DataList)
# Out:
# ['Novak Djokovic', 'Rafael Nadal', 'Alexander Zverev', 'Potro Del', 'Kevin Anderson', 'Roger Federer', 'Kei Nishikori', 'Dominic Thiem', 'John Isner', 'Marin Cilic', 'Karen Khachanov', 'Stefanos Tsitsipas', 'Borna Coric', 'Milos Raonic', 'Fabio Fognini', 'Daniil Medvedev', 'Lucas Pouille', 'Agut Bautista', 'Marco Cecchinato', 'Diego Schwartzman', 'David Goffin', 'Nikoloz Basilashvili', 'Busta Carreno', 'Grigor Dimitrov', 'Denis Shapovalov', 'Fernando Verdasco', 'Richard Gasquet', 'Minaur De', 'Kyle Edmund', 'Frances Tiafoe', 'Gilles Simon', 'Philipp Kohlschreiber', 'Gael Monfils', 'Steve Johnson', 'Jeremy Chardy', 'John Millman', 'Andreas Seppi', 'Martin Klizan', 'Joao Sousa', 'Taylor Fritz', 'Nicolas Jarry', 'Dusan Lajovic', 'Malek Jaziri', 'Pierre Herbert', 'Matthew Ebden', 'Adrian Mannarino', 'Marton Fucsovics', 'Sam Querrey', 'Leonardo Mayer', 'Hyeon Chung', 'Jan Struff', 'Damir Dzumhur', 'Matteo Berrettini', 'Robin Haase', 'Mikhail Kukushkin', 'Marius Copil', 'Stan Wawrinka', 'Benoit Paire', 'Denis Kudla', 'Guido Pella', 'Jordan Thompson', 'Peter Gojowczyk', 'Feliciano Lopez', 'Cameron Norrie', 'Aljaz Bedene', 'Yoshihito Nishioka', 'Nick Kyrgios', 'Mischa Zverev', 'Taro Daniel', 'Guido Andreozzi', 'Vinolas Ramos', 'Filip Krajinovic', 'Hubert Hurkacz', 'Baena Carballes', 'Tennys Sandgren', 'Maximilian Marterer', 'Federico Delbonis', 'Ivo Karlovic', 'Tomáš Berdych', 'Jaume Munar', 'Ilya Ivashka', 'Mackenzie Mcdonald', 'Pablo Andujar', 'Ernests Gulbis', 'Thomas Fabbiano', 'Bernard Tomic', 'Bradley Klahn', 'Laslo Djere', 'Jozef Kovalik', 'Radu Albot', 'Ugo Humbert', 'Pablo Cuevas', 'Ryan Harrison', 'Vasek Pospisil', 'Cristian Garin', 'Evgeny Donskoy', 'Jiri Vesely', 'Reilly Opelka', 'Mirza Basic', 'Andrey Rublev', 'Pedro Sousa', 'Prajnesh Gunneswaran', 'Lopez Garcia', 'Ricardas Berankis', 'Denis Istomin', 'Aliassime Auger', 'Thiago Monteiro', 'Jack Sock', 'Marcel Granollers', 'Michael Mmoh', 'Lloyd Harris', 'Juan Londero', 'Lorenzo Sonego', 'Paolo Lorenzi', 'Jason Jung', 'Elias Ymer', 'Marco Trungelliti', 'Miomir Kecmanovic', 'Hugo Dellien', 'Jared Donaldson', 'Peter Polansky', 'Yannick Maden', 'Stefano Travaglia', 'Alexei Popyrin', 'Maceiras Menendez', 'Casper Ruud', 'Lukas Lacko', 'Marcos Baghdatis', 'Alex Bolt', 'Jason Kubler', 'Bjorn Fratangelo', 'Ruben Bemelmans', 'Ramkumar Ramanathan', 'Thanasi Kokkinakis', 'Carlos Berlocq', 'Sergiy Stakhovsky', 'Quentin Halys', 'Simone Bolelli', 'Silva Dutra', 'Lukas Rosol', 'Tatsuma Ito', 'Henri Laaksonen', 'Corentin Moutet', 'Matthias Bachinger', 'Antoine Hoang', 'Constant Lestienne', 'Facundo Bagnis', 'David Ferrer', 'Jurgen Zopp', 'Noah Rubin', 'Yuki Bhambri', 'Gianluigi Quinzi', 'Luca Vanni', 'Dennis Novak', 'Gregoire Barrere', 'Kamil Majchrzak', 'Christopher Eubanks', 'Yuichi Sugita', 'Yannick Hanfmann', 'Dominik Koepfer', 'Egor Gerasimov', 'Pedro Martinez', 'Daniel Evans', 'Brayden Schnur', 'Oscar Otte', 'Filippo Baldi', 'Alessandro Giannessi', 'Marc Polmans', 'Salvatore Caruso', 'Yasutaka Uchiyama', 'Alexander Bublik', 'Darian King', 'Pedja Krstin', 'Nikola Milojevic', 'Andrea Arnaboldi', 'Sebastian Ofner', 'Hiroki Moriya', 'Roberto Quiroz', 'Alexey Vatutin', 'James Ward', 'Andrej Martin', 'Rudolf Molleker', 'Yosuke Watanuki', 'Gilles Müller', 'Daniel Brands', 'Viktor Troicki', 'Tim Smyczek', 'Mats Moraing', 'Traver Gimeno', 'Horacio Zeballos', 'Aleksandr Nedovyesov', 'Stefano Napolitano', 'Facundo Arguello', 'Mikael Ymer', 'Kimmer Coppejans', 'Nicolas Mahut', 'Jurij Rodionov', 'Tommy Paul', 'Adam Pavlasek', 'Mohamed Safwat', 'Stéphane Robert', 'Greef De', 'Donald Young', 'Tommy Robredo', 'Blaz Rola', 'Ernesto Escobedo', 'Matteo Donati', 'Ze Zhang', 'Mitchell Krueger', 'Jo Tsonga', 'Tallon Griekspoor', 'Jay Clarke', 'Joao Domingues', 'John Smith', 'Blaz Kavcic', 'Sergio Gutiérrez-Ferrol', 'Go Soeda', 'Tobias Kamke', 'Filip Horansky', 'Calvin Hemery', 'Marcelo Arevalo', 'Maxime Janvier', 'Thomaz Bellucci', 'Gianluca Mager', 'Andy Murray', 'Federico Gaio', 'Lorenzo Giustino', 'Da ...

# %%
players_df = pd.DataFrame(DataList)
players_df.to_csv('players_api.csv')

# %%
player_permutations = list(itertools.permutations(DataList, 2))
dummy_submission_df = pd.DataFrame(player_permutations, columns=['player_1','player_2'])
dummy_submission_df.loc[:,'player_1_win_probability'] = 0.5

# %%
dummy_submission_df.to_csv('dummy_submission_2022.csv')

# %%
dummy_submission_df
# Out:
#                player_1          player_2  player_1_win_probability
# 0        Novak Djokovic      Rafael Nadal                       0.5
# 1        Novak Djokovic  Alexander Zverev                       0.5
# 2        Novak Djokovic         Potro Del                       0.5
# 3        Novak Djokovic    Kevin Anderson                       0.5
# 4        Novak Djokovic     Roger Federer                       0.5
# ...                 ...               ...                       ...
# 818115  August Holmgren       Arthur Fery                       0.5
# 818116  August Holmgren    Philip Sekulic                       0.5
# 818117  August Holmgren    Sebastian Gima                       0.5
# 818118  August Holmgren       Sandro Kopp                       0.5
# 818119  August Holmgren     Alfredo Perez                       0.5
#
# [818120 rows x 3 columns]

# %%
df_predict_atp = pd.read_csv('dummy_submission_2022.csv')
df_predict_atp['player_1'] = df_predict_atp['player_1'].str.lower() 
df_predict_atp['player_2'] = df_predict_atp['player_2'].str.lower()

rolling_features['player_name'] = rolling_features['player_name'].str.lower() 

#Adding tournament date to prediction df
df_predict_atp['tourney_start_date'] = pd.to_datetime('2020-01-20')


df_predict_atp = df_predict_atp.merge(rolling_features, how='left',
                                     left_on = ['player_1', 'tourney_start_date'],
                                     right_on = ['player_name', 'tournament_date_index'],
                                     validate = 'm:1')

# %%
#Used to check for players who do not have rolling features to match or players whose names are spelt incorrectly
missing_names = df_predict_atp[df_predict_atp.isnull().any(axis=1)]['player_1'].unique()
missing_names.sort()
missing_names
# Out:
# array(['abedallah shelbayh', 'acosta diaz', 'adam moundir', 'adam walton',
#        'aguilar merida', 'agut bautista', 'alafia ayeni', 'alastair gray',
#        'albano olivetti', 'alejandro gomez', 'aleksandre metreveli',
#        'alessandro petrone', 'alexander igoshin',
#        'alexander pavlioutchenkov', 'alexander shevchenko',
#        'alexander ward', 'alexander weis', 'alexandr dolgopolov',
#        'alexandru jecan', 'alexis gautier', 'alfredo perez',
#        'aliassime auger', 'alves meligeni', 'andreas haider-maurer',
#        'andrej martin', 'andrew paulson', 'andrey chepelev',
#        'andrey kuznetsov', 'anis ghorbel', 'antoine bellier',
#        'antoine hoang', 'anton matusevich', 'arthur cazaux',
#        'arthur fery', 'arthur fils', 'assche van', 'august holmgren',
#        'austin krajicek', 'azorin vidal', 'baena carballes',
#        'bague toledo', 'bart stevens', 'bastian malla', 'batalla roca',
#        'ben patael', 'ben shelton', 'billy harris', 'bu yunchaokete',
#        'busta carreno', 'campos barroso', 'canas moro', 'carabelli ugo',
#        'carlos alcaraz', 'cedrik stebe', 'cezar cretu', 'charles broom',
#        'chauvinc cornut', 'cheong-eui kim', 'chien-hsun lo',
#        'christian lindell', 'chun tseng', 'clement chidekh',
#        'cobolli flavio', 'cosano barranco', 'courtney lock',
#        'cristian garin', 'cristian rodriguez', 'da dutra', 'da reis',
#        'dalibor svrcina', 'damien wenger', 'daniel cox', 'daniel galan',
#        'daniel michalski', 'daniel muñoz de la nava', 'daniel rincon',
#        'daniele capecchi', 'david guez', 'de moreno', 'de pucinelli',
#        'de van', 'del huertas', 'dias boscardin', 'diego schwartzman',
#        'dominic stricker', 'dominik palan', 'dragos madaras',
#        'duckhee lee', 'duje ajdukovic', 'edoardo eremin',
#        'edoardo lavagno', 'eduardo ribeiro', 'eduardo struvay',
#        'eliakim coulibaly', 'elmar ejupovic', 'eric vanshelboim',
#        'ethan quinn', 'evgenii tiurnev', 'ezekiel clark',
#        'fabian marozsan', 'facundo arguello', 'facundo bagnis',
#        'facundo juarez', 'federico coria', 'felix gill',
#        'fernandez hernandez', 'filip bergevi', 'filip jianu',
#        'filip misolic', 'florian lakat', 'fokina davidovich',
#        'frances tiafoe', 'francesco forti', 'francesco maestrelli',
#        'francesco passaro', 'francisco cabral', 'francisco comesana',
#        'franco agamenone', 'franco feitt', 'frank dancevic',
#        'franko škugor', 'gabriel decamps', 'gabriel diallo',
#        'gauthier onclin', 'genaro olivieri', 'george goldhoff',
#        'georgii kravchenko', 'gerald melzer', 'gergely madarasz',
#        'gian moroni', 'gianmarco ferrari', 'giles hussey',
#        'gilles müller', 'giovanni oradini', 'glenn smits',
#        'goncalo falcao', 'gonzalez vivero', 'gonzalo lama',
#        'gornes martos', 'greef de', 'guillermo olaso', 'gustavo heide',
#        'hady habib', 'hamad mededovic', 'harold mayot', 'hawkins findel',
#        'henri squire', 'henry patten', 'hernan casanova',
#        'hernandez alex', 'herrera gomez', 'hoang ly', 'holger rune',
#        'horacio zeballos', 'ignacio monzon', 'igor marcondes',
#        'inigo cervantes', 'ivan liutarevich', 'izquierdo sanchez',
#        'jacopo berrettini', 'jaimee angele', 'jakub paul',
#        'james frawley', 'james mccabe', 'jan satral', 'jan struff',
#        'jan zielinski', 'jeffrey wolf', 'jeroen vanneste', 'jerome kym',
#        'jerzy janowicz', 'ji nam', 'jo tsonga', 'joao menezes',
#        'johan nikles', 'johan tatlot', 'john smith', 'jonathan eysseric',
#        'jones pinnington', 'jong de', 'jordan correia',
#        'jordi samper-montaña', 'jorge panta', 'jose bendeck',
#        'jose pereira', 'jover sanchez', 'joão monteiro', 'joão souza',
#        'jr damm', 'juan cerundolo', 'juan ficovich',
#        'juan ignacio galarza', 'juan londero', 'juan otegui', 'juan paz',
#        'juan torres', 'juan varillas', 'jules marie', 'jules okala',
#        'julian bradley', 'juncheng shang', 'junior klier',
#        'jurgen briand', 'jurgen melzer', 'justin butsch', 'kai wehnelt',
#        'karim maamoun', 'karl friberg', 'karue sell', 'khumoyun sultanov',
#        'kirill kivattsev', 'kyrian jacquet', 'lamine ouahab',
#        'lara ojeda', 'lavallen lingua', 'leandro riedi',
#        'leonardo aboian', 'li tu', 'lloyd harris', 'lobato esteve',
#        'loore de', 'lopez garcia', 'lopez pena', 'lopez winter',
#        'luca gelhardt', 'luca giacomini', 'luca nardi', 'luca potenza',
#        'lucas poullain', 'luciano darderi', 'lukas neumayer',
#        'maceiras menendez', 'maks kasnikowski', 'malfeito pla',
#        'manuel sánchez', 'mao gong', 'marc huesler', 'marc sieber',
#        'marcello serafini', 'mariano kestelboim', 'mariano navone',
#        'mark lajal', 'marko miladinovic', 'marko tepavac', 'marko topo',
#        'martin cuevas', 'martin krumich', 'martinavarro artunedo',
#        'martinez vilella', 'martins podzus', 'marvin moller',
#        'marvin netuschil', 'mateus alves', 'mathieu perchicot',
#        'mathys erhard', 'matias descotte', 'matija pecotic',
#        'mats hermans', 'matteo arnaldi', 'matteo gigante',
#        'mattia bellucci', 'max houkes', 'max rehberg', 'maxim ratniuk',
#        'maxime chazal', 'maxime tchoutakian', 'maximiliano estevez',
#        'mili poljicak', 'min song', 'minaur de', 'miralles zapata',
#        'moez echargui', 'montagud lopez', 'máximo gonzalez', 'n balaji',
#        'n prashanth', 'naoki nakagawa', 'nicholas ionel',
#        'nicolae frunza', 'nicolas arreche', 'nicolas kicker',
#        'niels lootsma', 'nuno borges', 'oleg prihodko',
#        'oleksandr ovcharenko', 'oleksii krutykh', 'olmedo ortega',
#        'omar jasika', 'oscar gutierrez', 'ouden den', 'patricio heras',
#        'patrik rikl', 'paul jubb', 'pavel nejedly', 'pawel cias',
#        'pedro martinez', 'pedro sakamoto', 'perez lopez',
#        'perricard mpetshi', 'peter bothwell', 'peter fajta',
#        'peter torebko', 'petr nouza', 'philip sekulic', 'pierre herbert',
#        'pietro rondoni', 'piotr matuszewski', 'potro del',
#        'pujolras marti', 'purkiss boluda', 'quentin folliot',
#        'quentin robert', 'raphael collignon', 'remy bertola',
#        'ricardo rodríguez', 'riccardo bellotti', 'rigele te',
#        'rijthoven van', 'rimpei kawakami', 'robin bertrand', 'robin kern',
#        'roman burruchaga', 'ronald slobodchikov', 'ronnie schneider',
#        'rubin statham', 'ruggeri vincent', 'ruiz llamas', 'ryan nijboer',
#        'salminen niklas', 'san lopez', 'sanchis jorda', 'sandro kopp',
#        'sanz perez', 'sasikumar mukund', 'schepper de',
#        'scott puodziunas', 'sebastian baez', 'sebastian gima',
#        'seong hong', 'sergey betov', 'sergio gutiérrez-ferrol',
#        'shintaro mochizuki', 'silva dutra', 'silva ferreira',
#        'simon freund', 'soonwoo kwon', 'stefan palosi', 'stuart parker',
#        'stéphane robert', 'subervi cid', 'szymon walkow',
#        'taverna rodriguez', 'taylor fritz', 'teimuraz gabashvili',
#        'terence atmane', 'thai kwiatkowski', 'thiago tirante',
#        'thomas laurent', 'ti chen', 'tiago cacao', 'tiffon martin',
#        'tim puetz', 'timo legout', 'timo stodder', 'timofey skatov',
#        'titouan droguet', 'toby kodat', 'tom fawcett', 'tomas etcheverry',
#        'tomáš berdych', 'traver gimeno', 'tsung yang', 'tung wu',
#        'ugo blanchet', 'valentin vacherot', 'valerio aboian',
#        'valero gimeno', 'valle dalla', 'varona alvarez',
#        'velasco dellien', 'vera barrios', 'victor cornea',
#        'victor estrella burgos', 'vinolas ramos', 'wayenburg gueymard',
#        'wild seyboth', 'yan bondarevskiy', 'yanki erel',
#        'yannick jankovits', 'yen-hsun lu', 'youssef hossam', 'yu hsu',
#        'yuki bhambri', 'zizou bergs'], dtype=object)

# %%
all_players = deuce_atp_final.player_1.unique()
all_players.sort()
all_players
# Out:
# array(['Adam Pavlasek', 'Adrian Mannarino', 'Adrian Menendez Maceiras',
#        'Adrian Ungur', 'Adrian Voinea', 'Agustin Calleri',
#        'Aisam Ul Haq Qureshi', 'Alan Mackin', 'Albano Olivetti',
#        'Albert Costa', 'Albert Montanes', 'Albert Portas', 'Albert Ramos',
#        'Alberto Berasategui', 'Alberto Martin', 'Alejandro Falla',
#        'Alejandro Gonzalez', 'Aleksandr Nedovyesov',
#        'Alessandro Giannessi', 'Alessio Di Mauro', 'Alex Bogdanovic',
#        'Alex Bogomolov Jr', 'Alex Bolt', 'Alex Calatrava',
#        'Alex Corretja', 'Alex De Minaur', 'Alex Kim', 'Alex Kuznetsov',
#        'Alex Lopez Moron', 'Alex Obrien', 'Alexander Bublik',
#        'Alexander Kudryavtsev', 'Alexander Peya', 'Alexander Popp',
#        'Alexander Sarkissian', 'Alexander Waske', 'Alexander Zverev',
#        'Alexandr Dolgopolov', 'Alexandre Simoni', 'Alexei Popyrin',
#        'Aljaz Bedene', 'Alun Jones', 'Amer Delic', 'Amir Weintraub',
#        'Andre Agassi', 'Andre Sa', 'Andrea Gaudenzi', 'Andrea Stoppini',
#        'Andreas Beck', 'Andreas Haider Maurer', 'Andreas Seppi',
#        'Andreas Vinciguerra', 'Andrei Medvedev', 'Andrei Pavel',
#        'Andrei Stoliarov', 'Andrej Martin', 'Andrew Ilie',
#        'Andrew Whittington', 'Andrey Golubev', 'Andrey Kuznetsov',
#        'Andrey Rublev', 'Andy Murray', 'Andy Roddick', 'Antonie Hoang',
#        'Antonio Veic', 'Antony Dupuis', 'Arnau Brugues Davi',
#        'Arnaud Clement', 'Arnaud Di Pasquale', 'Arvind Parmar',
#        'Attila Savolt', 'Augustin Gensse', 'Austin Krajicek',
#        'Axel Pretzsch', 'Barry Cowan', 'Benjamin Becker',
#        'Benjamin Mitchell', 'Benoit Paire', 'Bernard Tomic',
#        'Bernd Karbacher', 'Bjorn Fratangelo', 'Bjorn Phau',
#        'Bjorn Rehnquist', 'Blake Mott', 'Blaz Kavcic', 'Blaz Rola',
#        'Bob Bryan', 'Bobby Reynolds', 'Bohdan Ulihrach',
#        'Boris Pashanski', 'Borna Coric', 'Bradley Klahn',
#        'Brayden Schnur', 'Brendan Evans', 'Brian Baker', 'Brian Dabul',
#        'Brian Vahaly', 'Brian Wilson', 'Bruno Agostinelli',
#        'Bruno Echagaray', 'Brydan Klein', 'Byron Black', 'Calvin Hemery',
#        'Cameron Norrie', 'Carlos Berlocq', 'Carlos Moya', 'Carsten Ball',
#        'Casper Ruud', 'Cecil Mamiit', 'Cedric Kauffmann',
#        'Cedric Pioline', 'Cedrik Marcel Stebe', 'Chase Buchanan',
#        'Chris Guccione', 'Chris Woodruff', 'Christian Garin',
#        'Christian Harrison', 'Christian Ruud', 'Christian Vinck',
#        'Christophe Rochus', 'Christopher Eubanks', 'Christopher Oconnell',
#        'Chuhan Wang', 'Chun Hsin Tseng', 'Colin Ebelthite',
#        'Collin Altamirano', 'Conor Niland', 'Corentin Moutet',
#        'Cristiano Caratti', 'Cyril Saulnier', 'Damir Dzumhur',
#        'Danai Udomchoke', 'Daniel Brands', 'Daniel Elsner',
#        'Daniel Evans', 'Daniel Gimeno Traver', 'Daniel Koellerer',
#        'Daniel Kosakowski', 'Daniel Munoz De La Nava', 'Daniel Nestor',
#        'Daniel Vacek', 'Daniele Bracciali', 'Daniil Medvedev',
#        'Darian King', 'David Ferrer', 'David Goffin', 'David Guez',
#        'David Nalbandian', 'David Prinosil', 'David Sanchez',
#        'David Wheaton', 'Davide Sanguinetti', 'Dejan Petrovic',
#        'Denis Gremelmayr', 'Denis Istomin', 'Denis Kudla',
#        'Denis Shapovalov', 'Dennis Novak', 'Dennis Novikov',
#        'Dennis Van Scheppingen', 'Devin Britton', 'Di Wu', 'Dick Norman',
#        'Diego Hartfield', 'Diego Junqueira',
#        'Diego Sebastian Schwartzman', 'Dieter Kindlmann',
#        'Dmitry Tursunov', 'Dominic Thiem', 'Dominik Hrbaty',
#        'Dominik Koepfer', 'Dominik Meffert', 'Donald Young', 'Dudi Sela',
#        'Dusan Lajovic', 'Dusan Lojda', 'Dusan Vemic', 'Dustin Brown',
#        'Edouard Roger Vasselin', 'Eduardo Schwank', 'Edwin Kempes',
#        'Egor Gerasimov', 'Elias Ymer', 'Elliot Benchetrit',
#        'Emilio Benfele Alvarez', 'Emilio Gomez', 'Eric Prodon',
#        'Eric Taino', 'Erik Chvojka', 'Ernesto Escobedo', 'Ernests Gulbis',
#        'Evan King', 'Evgeny Donskoy', 'Evgeny Korolev', 'Fabio Fognini',
#        'Fabrice Santoro', 'Facundo Bagnis', 'Federico Browne',
#        'Federico Delbonis', 'Federico Gaio', 'Federico Luzzi',
#        'Feliciano Lopez', 'Felix Auger Aliassime', 'Felix Mantilla',
#        'Fernando Gonzalez', 'Fernando Meligeni', 'Fernando Verdasco',
#        'Fernando Vicente', 'Filip Krajinovic', 'Filip Peliwo',
#        'Filippo Volandri', 'Flavio Cipolla', 'Flavio Saretta',
#        'Florent Serra', 'Florian Mayer', 'Francis Tiafoe',
#        'Francisco Clavet', 'Franco Squillari', 'Frank Dancevic',
#        'Frederic Niemeyer', 'Frederico Gil', 'Frederik Nielsen',
#        'Fredrik Jonsson', 'Gael Monfils', 'Galo Blanco', 'Gastao Elias',
#        'Gaston Etlis', 'Gaston Gaudio', 'Geoffrey Blancaneaux',
#        'George Bastl', 'Gerald Melzer', 'German Puentes',
#        'Gianluca Pozzi', 'Gilles Elseneer', 'Gilles Muller',
#        'Gilles Simon', 'Giorgio Galimberti', 'Giovanni Lapentti',
#        'Gleb Sakharov', 'Glenn Weiner', 'Go Soeda', 'Goran Ivanisevic',
#        'Gorka Fraile', 'Gouichi Motomura', 'Grant Stafford', 'Greg Jones',
#        'Greg Rusedski', 'Grega Zemlja', 'Gregoire Barrere',
#        'Gregory Carraz', 'Grigor Dimitrov', 'Guido Andreozzi',
#        'Guido Pella', 'Guilherme Clezar', 'Guillaume Rufin',
#        'Guillermo Canas', 'Guillermo Coria', 'Guillermo Garcia Lopez',
#        'Gustavo Kuerten', 'Harel Levy', 'Henri Laaksonen', 'Hernan Gumy',
#        'Hicham Arazi', 'Hiroki Moriya', 'Horacio Zeballos',
#        'Hubert Hurkacz', 'Hugo Armando', 'Hugo Dellien', 'Hyeon Chung',
#        'Hyung Taik Lee', 'Igor Andreev', 'Igor Kunitsyn', 'Igor Sijsling',
#        'Ilija Bozoljac', 'Illya Marchenko', 'Ilya Ivashka',
#        'Inigo Cervantes Huegun', 'Irakli Labadze', 'Ivan Dodig',
#        'Ivan Ljubicic', 'Ivan Miranda', 'Ivan Navarro', 'Ivan Sergeyev',
#        'Ivo Heuberger', 'Ivo Karlovic', 'Ivo Minar', 'Jack Brasington',
#        'Jack Sock', 'Jacob Adaktusson', 'Jacobo Diaz', 'James Blake',
#        'James Duckworth', 'James Mcgee', 'James Sekulov', 'James Ward',
#        'Jamie Baker', 'Jamie Delgado', 'Jan Hajek', 'Jan Hernych',
#        'Jan Kroslak', 'Jan Lennard Struff', 'Jan Michael Gambill',
#        'Jan Minar', 'Jan Satral', 'Jan Siemerink', 'Jan Vacek',
#        'Janko Tipsarevic', 'Jannik Sinner', 'Jared Donaldson',
#        'Jarkko Nieminen', 'Jason Kubler', 'Jason Stoltenberg',
#        'Jaume Munar', 'Jaymon Crabb', 'Jc Aragone',
#        'Jean Christophe Faurel', 'Jean Francois Bachelot',
#        'Jean Rene Lisnard', 'Jeff Morrison', 'Jeff Salzenstein',
#        'Jeff Tarango', 'Jens Knippschild', 'Jenson Brooksby',
#        'Jeremy Chardy', 'Jerome Golmard', 'Jerome Haehnel',
#        'Jerzy Janowicz', 'Jesse Huta Galung', 'Jesse Levine',
#        'Jesse Witten', 'Jim Courier', 'Jimmy Wang', 'Jiri Novak',
#        'Jiri Vanek', 'Jiri Vesely', 'Jo Wilfried Tsonga',
#        'Joachim Johansson', 'Joao Sousa', 'John Isner', 'John Millman',
#        'John Patrick Smith', 'John Van Lottum', 'Jonas Bjorkman',
#        'Jonathan Dasnieres De Veigy', 'Jordan Thompson', 'Jose Acasuso',
#        'Joseph Sirianni', 'Joshua Goodall', 'Josselin Ouanna',
#        'Jozef Kovalik', 'Juan Albert Viloca Puig', 'Juan Antonio Marin',
#        'Juan Balcells', 'Juan Carlos Ferrero', 'Juan Ignacio Chela',
#        'Juan Ignacio Londero', 'Juan Luis Tati Rascon',
#        'Juan Martin Del Potro', 'Juan Monaco', 'Juan Pablo Brzezicki',
#        'Juan Pablo Guzman', 'Julian Alonso', 'Julian Knowle',
#        'Julian Reister', 'Julien Benneteau', 'Julien Boutter',
#        'Julien Varlet', 'Julio Silva', 'Jurgen Melzer', 'Jurgen Zopp',
#        'Justin Gimelstob', 'Kamil Majchrzak', 'Karen Khachanov',
#        'Karim Alami', 'Karol Beck', 'Karol Kucera', 'Kei Nishikori',
#        'Kenneth Carlsen', 'Kenny De Schepper', 'Kevin Anderson',
#        'Kevin Kim', 'Kevin King', 'Kevin Ullyett', 'Kj Hippensteel',
#        'Konstantin Kravchuk', 'Konstantinos Economidis', 'Kristian Pless',
#        'Kristof Vliegen', 'Kyle Edmund', 'Ladislav Svarc',
#        'Lamine Ouahab', 'Lars Burgsmuller', 'Laslo Djere',
#        'Laurence Tieleman', 'Laurent Lokoli', 'Laurent Recouderc',
#        'Leander Paes', 'Leonardo Mayer', 'Levar Harper Griffith',
#        'Liam Broady', 'Lionel Roux', 'Lleyton Hewitt',
#        'Lloyd George Muirhead Harris', 'Lorenzo Manta', 'Lorenzo Sonego',
#        'Louk Sorensen', 'Luca Vanni', 'Lucas Pouille', 'Luis Horna',
#        'Lukas Dlouhy', 'Lukas Lacko', 'Lukas Rosol', 'Lukasz Kubot',
#        'Luke Saville', 'Mackenzie Mcdonald', 'Magnus Gustafsson',
#        'Magnus Larsson', 'Magnus Norman', 'Malek Jaziri', 'Mao Xin Gong',
#        'Marat Safin', 'Marc Gicquel', 'Marc Kimmich', 'Marc Polmans',
#        'Marc Rosset', 'Marcel Granollers', 'Marcelo Rios',
#        'Marco Cecchinato', 'Marco Chiudinelli', 'Marco Crugnola',
#        'Marco Trungelliti', 'Marcos Baghdatis', 'Marcos Daniel',
#        'Marcos Giron', 'Marcos Ondruska', 'Mardy Fish', 'Mariano Puerta',
#        'Mariano Zabaleta', 'Marin Cilic', 'Marinko Matosevic',
#        'Mario Ancic', 'Marius Copil', 'Mark Philippoussis',
#        'Mark Woodforde', 'Markus Hantschk', 'Markus Hipfl',
#        'Marsel Ilhan', 'Martin Damm', 'Martin Klizan', 'Martin Lee',
#        'Martin Rodriguez', 'Martin Slanar', 'Martin Vassallo Arguello',
#        'Martin Verkerk', 'Marton Fucsovics', 'Mathieu Montcourt',
#        'Matias Boeker', 'Matteo Berrettini', 'Matteo Viola',
#        'Matthew Breen', 'Matthew Ebden', 'Matthias Bachinger',
#        'Max Mirnyi', 'Maxime Authom', 'Maximilian Abel',
#        'Maximilian Marterer', 'Maximo Gonzalez', 'Melle Van Gemerden',
#        'Michael Berrer', 'Michael Chang', 'Michael Hill',
#        'Michael Kohlmann', 'Michael Lammer', 'Michael Llodra',
#        'Michael Mcclune', 'Michael Mmoh', 'Michael Russell',
#        'Michael Yani', 'Michal Przysiezny', 'Michal Tabara',
#        'Michel Kratochvil', 'Mikael Tillstrom', 'Mikael Ymer',
#        'Mike Bryan', 'Mikhail Kukushkin', 'Mikhail Youzhny',
#        'Milos Raonic', 'Miomir Kecmanovic', 'Mirza Basic',
#        'Mischa Zverev', 'Mitchell Krueger', 'Nathan Healey',
#        'Nenad Zimonjic', 'Neville Godwin', 'Nick Kyrgios', 'Nick Lindahl',
#        'Nicklas Kulti', 'Nicola Kuhn', 'Nicolas Almagro',
#        'Nicolas Coutelot', 'Nicolas Devilder', 'Nicolas Escude',
#        'Nicolas Jarry', 'Nicolas Kicker', 'Nicolas Kiefer',
#        'Nicolas Lapentti', 'Nicolas Mahut', 'Nicolas Massu',
#        'Nicolas Thomann', 'Niels Desein', 'Nikolay Davydenko',
#        'Nikoloz Basilashvili', 'Noah Rubin', 'Noam Behr', 'Noam Okun',
#        'Norbert Gombos', 'Novak Djokovic', 'Oliver Marach',
#        'Olivier Mutis', 'Olivier Patience', 'Olivier Rochus',
#        'Omar Jasika', 'Orlin Stanoytchev', 'Oscar Hernandez',
#        'Ota Fukarek', 'Pablo Andujar', 'Pablo Carreno Busta',
#        'Pablo Cuevas', 'Paolo Lorenzi', 'Paradorn Srichaphan',
#        'Patrick Kypson', 'Patrick Rafter', 'Paul Baccanello',
#        'Paul Capdeville', 'Paul Goldstein', 'Paul Henri Mathieu',
#        'Pavel Snobel', 'Pedro Sousa', 'Pere Riba', 'Pete Sampras',
#        'Peter Gojowczyk', 'Peter Luczak', 'Peter Polansky',
#        'Peter Tramacchi', 'Peter Wessels', 'Petr Kralert',
#        'Philip Bester', 'Philipp Kohlschreiber', 'Philipp Petzschner',
#        'Phillip King', 'Phillip Simmonds', 'Pierre Hugues Herbert',
#        'Pierre Ludovic Duclos', 'Potito Starace', 'Prajnesh Gunneswaran',
#        'Prakash Amritraj', 'Quentin Halys', 'Radek Stepanek',
#        'Radoslav Lukaev', 'Radu Albot', 'Raemon Sluiter', 'Rafael Nadal',
#        'Rainer Schuettler', 'Rajeev Ram', 'Ramkumar Ramanathan',
#        'Ramon Delgado', 'Razvan Sabau', 'Reilly Opelka', 'Renzo Furlan',
#        'Renzo Olivo', 'Rhyne Williams', 'Ricardas Berankis',
#        'Ricardo Hocevar', 'Ricardo Mello', 'Richard Fromberg',
#        'Richard Gasquet', 'Richard Krajicek', 'Rik De Voest',
#        'Rob Steckley', 'Robby Ginepri', 'Robert Farah', 'Robert Kendrick',
#        'Robert Smeets', 'Robert Yim', 'Roberto Bautista Agut',
#        'Roberto Carballes Baena', 'Robin Haase', 'Robin Soderling',
#        'Robin Vik', 'Rodolphe Cadart', 'Roger Federer',
#        'Rogerio Dutra Silva', 'Rohan Bopanna', 'Roko Karanusic',
#        'Romain Jouan', 'Ronald Agenor', 'Ruben Bemelmans',
#        'Ruben Ramirez Hidalgo', 'Rudolf Molleker', 'Rui Machado',
#        'Ryan Harrison', 'Ryan Henry', 'Ryan Shane', 'Ryan Sweeting',
#        'Ryler Deheart', 'Saketh Myneni', 'Salvatore Caruso',
#        'Sam Querrey', 'Sam Warburg', 'Samuel Groth', 'Santiago Giraldo',
#        'Santiago Ventura', 'Sargis Sargsian', 'Scott Draper',
#        'Scoville Jenkins', 'Sebastien De Chaunac', 'Sebastien Grosjean',
#        'Sebastien Lareau', 'Sergei Bubka', 'Sergi Bruguera',
#        'Sergio Roitman', 'Sergiy Stakhovsky', 'Shao Xuan Zeng',
#        'Simon Greul', 'Simon Larose', 'Simon Stadler', 'Simone Bolelli',
#        'Sjeng Schalken', 'Slava Dosedel', 'Slimane Saoudi',
#        'Somdev Devvarman', 'Soon Woo Kwon', 'Stan Wawrinka',
#        'Stefan Koubek', 'Stefan Kozlov', 'Stefano Galvani',
#        'Stefano Travaglia', 'Stefanos Tsitsipas', 'Stephane Bohli',
#        'Stephane Huet', 'Stephane Robert', 'Steve Darcis',
#        'Steve Johnson', 'Steven Diez', 'Sumit Nagal', 'Takao Suzuki',
#        'Taro Daniel', 'Tatsuma Ito', 'Taylor Dent', 'Taylor Harry Fritz',
#        'Tennys Sandgren', 'Teymuraz Gabashvili', 'Thai Son Kwiatkowski',
#        'Thanasi Kokkinakis', 'Thiago Alves', 'Thiago Monteiro',
#        'Thiemo De Bakker', 'Thierry Ascione', 'Thierry Guardiola',
#        'Thomas Enqvist', 'Thomas Fabbiano', 'Thomas Johansson',
#        'Thomaz Bellucci', 'Tim Henman', 'Tim Puetz', 'Tim Smyczek',
#        'Tobias Kamke', 'Tobias Summerer', 'Todd Larkham', 'Todd Martin',
#        'Todd Perry', 'Todd Reid', 'Todd Widom', 'Todd Woodbridge',
#        'Tomas Behrend', 'Tomas Berdych', 'Tomas Zib', 'Tommy Haas',
#        'Tommy Paul', 'Tommy Robredo', 'Tsung Hua Yang', 'Tuomas Ketola',
#        'Ugo Humbert', 'Vaclav Safranek', 'Vadim Kutsenko',
#        'Vasek Pospisil', 'Vasilis Mazarakis', 'Victor Crivoi',
#        'Victor Estrella', 'Victor Hanescu', 'Viktor Troicki',
#        'Vincent Millot', 'Vincent Spadea', 'Vladimir Voltchkov',
#        'Wayne Arthurs', 'Wayne Black', 'Wayne Ferreira', 'Wayne Odesnik',
#        'Werner Eschauer', 'Wesley Moodie', 'Woong Sun Jun',
#        'Xavier Malisse', 'Yan Bai', 'Yannick Hanfmann', 'Yannick Maden',
#        'Yen Hsun Lu', 'Yevgeny Kafelnikov', 'Yibing Wu',
#        'Yoshihito Nishioka', 'Younes El Aynaoui', 'Yuichi Sugita',
#        'Yuki Bhambri', 'Yuri Schukin', 'Zachary Svajda', 'Zack Fleishman',
#        'Ze Zhang', 'Zeljko Krajan', 'Zhe Li', 'Zhizhen Zhang'],
#       dtype=object)

# %%
df_predict_atp = df_predict_atp.merge(rolling_features, how='left',
                                     left_on = ['player_2', 'tourney_start_date'],
                                     right_on = ['player_name', 'tournament_date_index'],
                                     validate = 'm:1',
                                     suffixes = ('_p1','_p2'))

# %%
#Filling in missing values for players with no aggregates prior to 2020 AO
df_predict_atp.loc[:,'player_rank_p1'].fillna(500, inplace=True)
df_predict_atp.loc[:,'player_rank_p2'].fillna(500, inplace=True)
df_predict_atp.loc[:,'player_log_rank_p1'].fillna(np.log(500), inplace=True)
df_predict_atp.loc[:,'player_log_rank_p2'].fillna(np.log(500), inplace=True)
df_predict_atp.loc[:,['player_log_rank_p1','player_log_rank_p2']].fillna(np.log(500), inplace=True)
df_predict_atp.fillna(-1, inplace=True) ##### <- important

#These players with no previous match history are slightly suspect, good to check if we have filled in their values correctly
df_predict_atp[(df_predict_atp.player_1.isin(['alejandro fokina', 'andrew harris', 'christopher oconnell',
       'hugo gaston', 'james duckworth', 'john patrick smith',
       'michael mmoh', 'yen hsun lu']))]
# Out:
#         Unnamed: 0              player_1          player_2  \
# 98536        98536          michael mmoh    novak djokovic
# 98537        98537          michael mmoh      rafael nadal
# 98538        98538          michael mmoh  alexander zverev
# 98539        98539          michael mmoh         potro del
# 98540        98540          michael mmoh    kevin anderson
# ...            ...                   ...               ...
# 501715      501715  christopher oconnell    philip sekulic
# 501716      501716  christopher oconnell    sebastian gima
# 501717      501717  christopher oconnell       sandro kopp
# 501718      501718  christopher oconnell     alfredo perez
# 501719      501719  christopher oconnell   august holmgren
#
#         player_1_win_probability tourney_start_date        player_name_p1  \
# 98536                        0.5         2020-01-20          michael mmoh
# 98537                        0.5         2020-01-20          michael mmoh
# 98538                        0.5         2020-01-20          michael mmoh
# 98539                        0.5         2020-01-20          michael mmoh
# 98540                        0.5         2020-01-20          michael mmoh
# ...                          ...                ...                   ...
# 501715                       0.5         2020-01-20  christopher oconnell
# 501716                       0.5         2020-01-20  christopher oconnell
# 501717                       0.5         2020-01-20  christopher oconnell
# 501718                       0.5         2020-01-20  christopher oconnell
# 501719                       0.5         2020-01-20  christopher oconnell
#
#         player_serve_win_ratio_p1  player_return_win_ratio_p1  \
# 98536                    0.621964                    0.392531
# 98537                    0.621964                    0.392531
# 98538                    0.621964                    0.392531
# 98539                    0.621964                    0.392531
# 98540                    0.621964                    0.392531
# ...                           ...                         ...
# 501715                   0.686896                    0.408094
# 501716                   0.686896                    0.408094
# 501717                   0.686896                    0.408094
# 501718                   0.686896                    0.408094
# 501719                   0.686896                    0.408094
#
#         player_bp_per_game_p1  player_bp_conversion_ratio_p1  \
# 98536                0.679286                       0.460622
# 98537                0.679286                       0.460622
# 98538                0.679286                       0.460622
# 98539                0.679286                       0.460622
# 98540                0.679286                       0.460622
# ...                       ...                            ...
# 501715               0.693553                       0.415291
# 501716               0.693553                       0.415291
# 501717               0.693553                       0.415291
# 501718               0.693553                       0.415291
# 501719               0.693553                       0.415291
#
#         player_game_win_ratio_p1  player_point_win_ratio_p1  \
# 98536                   0.523931                   0.506639
# 98537                   0.523931                   0.506639
# 98538                   0.523931                   0.506639
# 98539                   0.523931                   0.506639
# 98540                   0.523931                   0.506639
# ...                          ...                        ...
# 501715                  0.583213                   0.545209
# 501716                  0.583213                   0.545209
# 501717                  0.583213                   0.545209
# 501718                  0.583213                   0.545209
# 501719                  0.583213                   0.545209
#
#         player_clutch_factor_p1  player_win_weight_p1  \
# 98536                  0.017292              0.074843
# 98537                  0.017292              0.074843
# 98538                  0.017292              0.074843
# 98539                  0.017292              0.074843
# 98540                  0.017292              0.074843
# ...                         ...                   ...
# 501715                 0.038004              0.095245
# 501716                 0.038004              0.095245
# 501717                 0.038004              0.095245
# 501718                 0.038004              0.095245
# 501719                 0.038004              0.095245
#
#         player_game_win_ratio_weighted_p1  player_point_win_ratio_weighted_p1  \
# 98536                            0.488298                            0.476068
# 98537                            0.488298                            0.476068
# 98538                            0.488298                            0.476068
# 98539                            0.488298                            0.476068
# 98540                            0.488298                            0.476068
# ...                                   ...                                 ...
# 501715                           0.506093                            0.478462
# 501716                           0.506093                            0.478462
# 501717                           0.506093                            0.478462
# 501718                           0.506093                            0.478462
# 501719                           0.506093                            0.478462
#
#         player_rank_p1  player_log_rank_p1 tournament_date_index_p1  \
# 98536            152.0            5.023881      2020-01-20 00:00:00
# 98537            152.0            5.023881      2020-01-20 00:00:00
# 98538            152.0            5.023881      2020-01-20 00:00:00
# 98539            152.0            5.023881      2020-01-20 00:00:00
# 98540            152.0            5.023881      2020-01-20 00:00:00
# ...                ...                 ...                      ...
# 501715           596.0            6.390241      2020-01-20 00:00:00
# 501716           596.0            6.390241      2020-01-20 00:00:00
# 501717           596.0            6.390241      2020-01-20 00:00:00
# 501718           596.0            6.390241      2020-01-20 00:00:00
# 501719           596.0            6.390241      2020-01-20 00:00:00
#
#           player_name_p2  player_serve_win_ratio_p2  \
# 98536     novak djokovic                   0.722207
# 98537       rafael nadal                   0.701927
# 98538   alexander zverev                   0.669859
# 98539                 -1                  -1.000000
# 98540     kevin anderson                   0.646510
# ...                  ...                        ...
# 501715                -1                  -1.000000
# 501716                -1                  -1.000000
# 501717                -1                  -1.000000
# 501718                -1                  -1.000000
# 501719                -1                  -1.000000
#
#         player_return_win_ratio_p2  player_bp_per_game_p2  \
# 98536                     0.412843               0.670426
# 98537                     0.395480               0.639543
# 98538                     0.377520               0.666958
# 98539                    -1.000000              -1.000000
# 98540                     0.347592               0.392992
# ...                            ...                    ...
# 501715                   -1.000000              -1.000000
# 501716                   -1.000000              -1.000000
# 501717                   -1.000000              -1.000000
# 501718                   -1.000000              -1.000000
# 501719                   -1.000000              -1.000000
#
#         player_bp_conversion_ratio_p2  player_game_win_ratio_p2  \
# 98536                        0.492210                  0.613324
# 98537                        0.442393                  0.622003
# 98538                        0.388043                  0.529257
# 98539                       -1.000000                 -1.000000
# 98540                        0.526786                  0.483566
# ...                               ...                       ...
# 501715                      -1.000000                 -1.000000
# 501716                      -1.000000                 -1.000000
# 501717                      -1.000000                 -1.000000
# 501718                      -1.000000                 -1.000000
# 501719                      -1.000000                 -1.000000
#
#         player_point_win_ratio_p2  player_clutch_factor_p2  \
# 98536                    0.560366                 0.052957
# 98537                    0.542192                 0.070236
# 98538                    0.517622                 0.011636
# 98539                   -1.000000                -1.000000
# 98540                    0.500116                -0.016550
# ...                           ...                      ...
# 501715                  -1.000000                -1.000000
# 501716                  -1.000000                -1.000000
# 501717                  -1.000000                -1.000000
# 501718                  -1.000000                -1.000000
# 501719                  -1.000000                -1.000000
#
#         player_win_weight_p2  player_game_win_ratio_weighted_p2  \
# 98536               0.470841                           0.561517
# 98537               0.567970                           0.567058
# 98538               0.380498                           0.458381
# 98539              -1.000000                          -1.000000
# 98540               0.417504                           0.441765
# ...                      ...                                ...
# 501715             -1.000000                          -1.000000
# 501716             -1.000000                          -1.000000
# 501717             -1.000000                          -1.000000
# 501718             -1.000000                          -1.000000
# 501719             -1.000000                          -1.000000
#
#         player_point_win_ratio_weighted_p2  player_rank_p2  \
# 98536                             0.513802             1.0
# 98537                             0.492981             2.0
# 98538                             0.452615             6.0
# 98539                            -1.000000           500.0
# 98540                             0.461121             7.0
# ...                                    ...             ...
# 501715                           -1.000000           500.0
# 501716                           -1.000000           500.0
# 501717                           -1.000000           500.0
# 501718                           -1.000000           500.0
# 501719                           -1.000000           500.0
#
#         player_log_rank_p2 tournament_date_index_p2
# 98536             0.000000      2020-01-20 00:00:00
# 98537             0.693147      2020-01-20 00:00:00
# 98538             1.791759      2020-01-20 00:00:00
# 98539             6.214608                       -1
# 98540             1.945910      2020-01-20 00:00:00
# ...                    ...                      ...
# 501715            6.214608                       -1
# 501716            6.214608                       -1
# 501717            6.214608                       -1
# 501718            6.214608                       -1
# 501719            6.214608                       -1
#
# [4520 rows x 33 columns]

# %%
df_predict_atp
# Out:
#         Unnamed: 0         player_1          player_2  \
# 0                0   novak djokovic      rafael nadal
# 1                1   novak djokovic  alexander zverev
# 2                2   novak djokovic         potro del
# 3                3   novak djokovic    kevin anderson
# 4                4   novak djokovic     roger federer
# ...            ...              ...               ...
# 818115      818115  august holmgren       arthur fery
# 818116      818116  august holmgren    philip sekulic
# 818117      818117  august holmgren    sebastian gima
# 818118      818118  august holmgren       sandro kopp
# 818119      818119  august holmgren     alfredo perez
#
#         player_1_win_probability tourney_start_date  player_name_p1  \
# 0                            0.5         2020-01-20  novak djokovic
# 1                            0.5         2020-01-20  novak djokovic
# 2                            0.5         2020-01-20  novak djokovic
# 3                            0.5         2020-01-20  novak djokovic
# 4                            0.5         2020-01-20  novak djokovic
# ...                          ...                ...             ...
# 818115                       0.5         2020-01-20              -1
# 818116                       0.5         2020-01-20              -1
# 818117                       0.5         2020-01-20              -1
# 818118                       0.5         2020-01-20              -1
# 818119                       0.5         2020-01-20              -1
#
#         player_serve_win_ratio_p1  player_return_win_ratio_p1  \
# 0                        0.722207                    0.412843
# 1                        0.722207                    0.412843
# 2                        0.722207                    0.412843
# 3                        0.722207                    0.412843
# 4                        0.722207                    0.412843
# ...                           ...                         ...
# 818115                  -1.000000                   -1.000000
# 818116                  -1.000000                   -1.000000
# 818117                  -1.000000                   -1.000000
# 818118                  -1.000000                   -1.000000
# 818119                  -1.000000                   -1.000000
#
#         player_bp_per_game_p1  player_bp_conversion_ratio_p1  \
# 0                    0.670426                        0.49221
# 1                    0.670426                        0.49221
# 2                    0.670426                        0.49221
# 3                    0.670426                        0.49221
# 4                    0.670426                        0.49221
# ...                       ...                            ...
# 818115              -1.000000                       -1.00000
# 818116              -1.000000                       -1.00000
# 818117              -1.000000                       -1.00000
# 818118              -1.000000                       -1.00000
# 818119              -1.000000                       -1.00000
#
#         player_game_win_ratio_p1  player_point_win_ratio_p1  \
# 0                       0.613324                   0.560366
# 1                       0.613324                   0.560366
# 2                       0.613324                   0.560366
# 3                       0.613324                   0.560366
# 4                       0.613324                   0.560366
# ...                          ...                        ...
# 818115                 -1.000000                  -1.000000
# 818116                 -1.000000                  -1.000000
# 818117                 -1.000000                  -1.000000
# 818118                 -1.000000                  -1.000000
# 818119                 -1.000000                  -1.000000
#
#         player_clutch_factor_p1  player_win_weight_p1  \
# 0                      0.052957              0.470841
# 1                      0.052957              0.470841
# 2                      0.052957              0.470841
# 3                      0.052957              0.470841
# 4                      0.052957              0.470841
# ...                         ...                   ...
# 818115                -1.000000             -1.000000
# 818116                -1.000000             -1.000000
# 818117                -1.000000             -1.000000
# 818118                -1.000000             -1.000000
# 818119                -1.000000             -1.000000
#
#         player_game_win_ratio_weighted_p1  player_point_win_ratio_weighted_p1  \
# 0                                0.561517                            0.513802
# 1                                0.561517                            0.513802
# 2                                0.561517                            0.513802
# 3                                0.561517                            0.513802
# 4                                0.561517                            0.513802
# ...                                   ...                                 ...
# 818115                          -1.000000                           -1.000000
# 818116                          -1.000000                           -1.000000
# 818117                          -1.000000                           -1.000000
# 818118                          -1.000000                           -1.000000
# 818119                          -1.000000                           -1.000000
#
#         player_rank_p1  player_log_rank_p1 tournament_date_index_p1  \
# 0                  1.0            0.000000      2020-01-20 00:00:00
# 1                  1.0            0.000000      2020-01-20 00:00:00
# 2                  1.0            0.000000      2020-01-20 00:00:00
# 3                  1.0            0.000000      2020-01-20 00:00:00
# 4                  1.0            0.000000      2020-01-20 00:00:00
# ...                ...                 ...                      ...
# 818115           500.0            6.214608                       -1
# 818116           500.0            6.214608                       -1
# 818117           500.0            6.214608                       -1
# 818118           500.0            6.214608                       -1
# 818119           500.0            6.214608                       -1
#
#           player_name_p2  player_serve_win_ratio_p2  \
# 0           rafael nadal                   0.701927
# 1       alexander zverev                   0.669859
# 2                     -1                  -1.000000
# 3         kevin anderson                   0.646510
# 4          roger federer                   0.712826
# ...                  ...                        ...
# 818115                -1                  -1.000000
# 818116                -1                  -1.000000
# 818117                -1                  -1.000000
# 818118                -1                  -1.000000
# 818119                -1                  -1.000000
#
#         player_return_win_ratio_p2  player_bp_per_game_p2  \
# 0                         0.395480               0.639543
# 1                         0.377520               0.666958
# 2                        -1.000000              -1.000000
# 3                         0.347592               0.392992
# 4                         0.416138               0.731101
# ...                            ...                    ...
# 818115                   -1.000000              -1.000000
# 818116                   -1.000000              -1.000000
# 818117                   -1.000000              -1.000000
# 818118                   -1.000000              -1.000000
# 818119                   -1.000000              -1.000000
#
#         player_bp_conversion_ratio_p2  player_game_win_ratio_p2  \
# 0                            0.442393                  0.622003
# 1                            0.388043                  0.529257
# 2                           -1.000000                 -1.000000
# 3                            0.526786                  0.483566
# 4                            0.448214                  0.596273
# ...                               ...                       ...
# 818115                      -1.000000                 -1.000000
# 818116                      -1.000000                 -1.000000
# 818117                      -1.000000                 -1.000000
# 818118                      -1.000000                 -1.000000
# 818119                      -1.000000                 -1.000000
#
#         player_point_win_ratio_p2  player_clutch_factor_p2  \
# 0                        0.542192                 0.070236
# 1                        0.517622                 0.011636
# 2                       -1.000000                -1.000000
# 3                        0.500116                -0.016550
# 4                        0.553153                 0.042751
# ...                           ...                      ...
# 818115                  -1.000000                -1.000000
# 818116                  -1.000000                -1.000000
# 818117                  -1.000000                -1.000000
# 818118                  -1.000000                -1.000000
# 818119                  -1.000000                -1.000000
#
#         player_win_weight_p2  player_game_win_ratio_weighted_p2  \
# 0                   0.567970                           0.567058
# 1                   0.380498                           0.458381
# 2                  -1.000000                          -1.000000
# 3                   0.417504                           0.441765
# 4                   0.539403                           0.555605
# ...                      ...                                ...
# 818115             -1.000000                          -1.000000
# 818116             -1.000000                          -1.000000
# 818117             -1.000000                          -1.000000
# 818118             -1.000000                          -1.000000
# 818119             -1.000000                          -1.000000
#
#         player_point_win_ratio_weighted_p2  player_rank_p2  \
# 0                                 0.492981             2.0
# 1                                 0.452615             6.0
# 2                                -1.000000           500.0
# 3                                 0.461121             7.0
# 4                                 0.518114             3.0
# ...                                    ...             ...
# 818115                           -1.000000           500.0
# 818116                           -1.000000           500.0
# 818117                           -1.000000           500.0
# 818118                           -1.000000           500.0
# 818119                           -1.000000           500.0
#
#         player_log_rank_p2 tournament_date_index_p2
# 0                 0.693147      2020-01-20 00:00:00
# 1                 1.791759      2020-01-20 00:00:00
# 2                 6.214608                       -1
# 3                 1.945910      2020-01-20 00:00:00
# 4                 1.098612      2020-01-20 00:00:00
# ...                    ...                      ...
# 818115            6.214608                       -1
# 818116            6.214608                       -1
# 818117            6.214608                       -1
# 818118            6.214608                       -1
# 818119            6.214608                       -1
#
# [818120 rows x 33 columns]

# %%
X_train.columns
# Out:
# Index(['player_log_rank_diff', 'player_rank_diff',
#        'player_serve_win_ratio_diff', 'player_return_win_ratio_diff',
#        'player_game_win_ratio_diff', 'player_point_win_ratio_weighted_diff'],
#       dtype='object')

# %%
df_predict_atp['player_1']
# Out:
# 0          novak djokovic
# 1          novak djokovic
# 2          novak djokovic
# 3          novak djokovic
# 4          novak djokovic
#                ...
# 818115    august holmgren
# 818116    august holmgren
# 818117    august holmgren
# 818118    august holmgren
# 818119    august holmgren
# Name: player_1, Length: 818120, dtype: object

# %%
pd.Series(model.feature_importances_, index=X_train.columns).sort_values(ascending=False)
# Out:
# player_log_rank_diff                    0.619010
# player_game_win_ratio_diff              0.108943
# player_point_win_ratio_weighted_diff    0.080545
# player_serve_win_ratio_diff             0.075001
# player_rank_diff                        0.060340
# player_return_win_ratio_diff            0.056161
# dtype: float32

# %%
perm = PermutationImportance(model).fit(X_val, y_val)
eli5.show_weights(perm, feature_names = X_val.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1610
#
#                     &plusmn; 0.0164
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_log_rank_diff
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0163
#
#                     &plusmn; 0.0176
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_game_win_ratio_diff
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0136
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_rank_diff
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0024
#
#                     &plusmn; 0.0078
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_point_win_ratio_weighted_diff
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0012
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_return_win_ratio_diff
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.31%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0047
#
#                     &plusmn; 0.0076
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_serve_win_ratio_diff
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
df_predict_atp = get_player_difference(df_predict_atp, diff_cols=diff_cols)


atp_preds = model.predict_proba(df_predict_atp[X_train.columns])
df_predict_atp['player_1_win_probability'] = atp_preds[:,1]

atp_pred_submission = df_predict_atp[['player_1', 'player_2', 'player_1_win_probability']]
atp_pred_submission.to_csv('submission_from_api.csv')
atp_pred_submission
# Out:
#                player_1          player_2  player_1_win_probability
# 0        novak djokovic      rafael nadal                  0.606594
# 1        novak djokovic  alexander zverev                  0.836237
# 2        novak djokovic         potro del                  0.838423
# 3        novak djokovic    kevin anderson                  0.860619
# 4        novak djokovic     roger federer                  0.446737
# ...                 ...               ...                       ...
# 818115  august holmgren       arthur fery                  0.503162
# 818116  august holmgren    philip sekulic                  0.503162
# 818117  august holmgren    sebastian gima                  0.503162
# 818118  august holmgren       sandro kopp                  0.503162
# 818119  august holmgren     alfredo perez                  0.503162
#
# [818120 rows x 3 columns]

# %%
atp_pred_submission.groupby('player_1')['player_1_win_probability'].agg('mean').sort_values(ascending=False).head(10)
# Out:
# player_1
# alexander zverev    0.889402
# rafael nadal        0.885930
# novak djokovic      0.884984
# roger federer       0.880868
# kei nishikori       0.874128
# daniil medvedev     0.862569
# karen khachanov     0.860125
# gael monfils        0.855037
# dominic thiem       0.854107
# david goffin        0.848131
# Name: player_1_win_probability, dtype: float32

# %%
atp_pred_submission.groupby('player_1')['player_1_win_probability'].agg('mean').sort_values(ascending=False).tail(30)
# Out:
# player_1
# minaur de               0.380043
# min song                0.380043
# juan londero            0.380043
# juan otegui             0.380043
# baena carballes         0.380043
# joão monteiro           0.380043
# jonathan eysseric       0.380043
# nicolas arreche         0.380043
# omar jasika             0.380043
# olmedo ortega           0.380043
# daniel cox              0.380043
# oleksii krutykh         0.380043
# oleksandr ovcharenko    0.380043
# oleg prihodko           0.380043
# nuno borges             0.380043
# assche van              0.380043
# jones pinnington        0.380043
# jong de                 0.380043
# jordan correia          0.380043
# august holmgren         0.380043
# jordi samper-montaña    0.380043
# austin krajicek         0.380043
# jorge panta             0.380043
# niels lootsma           0.380043
# jose bendeck            0.380043
# jose pereira            0.380043
# nicolas kicker          0.380043
# azorin vidal            0.380043
# jover sanchez           0.380043
# abedallah shelbayh      0.380043
# Name: player_1_win_probability, dtype: float32
